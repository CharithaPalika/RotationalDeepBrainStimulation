# %%
from basal_ganglia import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from basal_ganglia import *
#
# File ~/Desktop/Lab projects/Decision Making/Light_House_DBS/light_house_DBS_decision_making/basal_ganglia/__init__.py:8
#       1 # stn_gpe/__init__.py
#       2 """
#       3 basal_ganglia model package
#       4 Contains BG network model, train loop
#       5 for studying decision-making under different conditions
#       6 """
# ----> 8 from .BGNetwork import BGNetwork
#       9 from .train import train
#      12 # Define what should be accessible when importing `stn_gpe`
#
# ModuleNotFoundError: No module named 'basal_ganglia.BGNetwork'

# %%
from envs import *
