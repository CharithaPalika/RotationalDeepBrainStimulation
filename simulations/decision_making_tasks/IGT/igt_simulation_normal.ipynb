# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import torch.nn as nn
import torch
from tqdm.autonotebook import tqdm
import seaborn as sns
import os, sys

from matplotlib.lines import Line2D
from collections import defaultdict
from matplotlib.colors import LinearSegmentedColormap
# Root project
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to sys.path:", project_root)

from envs import *
from basal_ganglia import *
from stn_gpe import *

# filter warnings
import warnings
warnings.filterwarnings("ignore")
import pickle
# Out:
# C:\Users\Sandeep\AppData\Local\Temp\ipykernel_668\768709351.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Project root added to sys.path: d:\charitha\projects\STN-GPe_spiking\light_house_DBS_decision_making

# %% [markdown]
# ## Hyperparameters

# %%
TRAILS = 100
EPOCHS = 10 #100
NUM_BINS = 5
LR = 0.1 #0.00075
NUM_ARMS = 4
SCALING_FACTOR = 100
REW_STD = 0
LOSS_STD = 0
VAR = 0.1

# %% [markdown]
# ## Simulation

# %%
env = IGTEnv(mean_reward=np.array([100,100,50,50])/SCALING_FACTOR,
             std_reward=np.array([REW_STD,REW_STD,REW_STD,REW_STD])/SCALING_FACTOR,
             mean_loss=np.array([-250,-1250,-50,-250])/SCALING_FACTOR,
             std_loss=np.array([LOSS_STD,LOSS_STD,LOSS_STD,LOSS_STD])/SCALING_FACTOR)

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor, ep_monitor, _= train(env, 
                                                      trails = TRAILS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = NUM_BINS,
                                                      STN_data = None, #Taking noise
                                                      d1_amp=0.5,
                                                      d2_amp=0.1, #1
                                                      gpi_threshold=0.15,#0.18,
                                                      max_gpi_iters=50,
                                                      del_lim=None, train_IP = False, 
                                                      del_med = None, printing = True,
                                                      gpi_mean= 1, ep_0 = 0.1,
                                                      alpha_ep = 0.001,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.02, ep_lim=0.25)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.1208963692188263
# 1: dp: tensor([[0.2937, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7937], grad_fn=<RsubBackward1>), epsilon: 0.1417754739522934
# 2: dp: tensor([[0.2714, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7714], grad_fn=<RsubBackward1>), epsilon: 0.16263368725776672
# 3: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2504], grad_fn=<RsubBackward1>), epsilon: 0.18293678760528564
# 4: dp: tensor([[0.2500, 0.2504, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.20375384390354156
# 5: dp: tensor([[0.2500, 0.2504, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2500], grad_fn=<RsubBackward1>), epsilon: 0.22401481866836548
# 6: dp: tensor([[0.2500, 0.2504, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.24478718638420105
# 7: dp: tensor([[0.2500, 0.2504, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 8: dp: tensor([[0.2500, 0.2504, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.25
# 9: dp: tensor([[0.2500, 0.2687, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7313], grad_fn=<RsubBackward1>), epsilon: 0.25
# 10: dp: tensor([[0.2500, 0.2927, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7073], grad_fn=<RsubBackward1>), epsilon: 0.25
# 11: dp: tensor([[0.2500, 0.3196, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6804], grad_fn=<RsubBackward1>), epsilon: 0.25
# 12: dp: tensor([[0.2500, 0.3507, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6493], grad_fn=<RsubBackward1>), epsilon: 0.25
# 13: dp: tensor([[0.2500, 0.3847, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6153], grad_fn=<RsubBackward1>), epsilon: 0.25
# 14: dp: tensor([[0.2500, 0.4180, 0.2500, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9180], grad_fn=<RsubBackward1>), epsilon: 0.25
# 15: dp: tensor([[0.2500, 0.4037, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5963], grad_fn=<RsubBackward1>), epsilon: 0.25
# 16: dp: tensor([[0.2500, 0.3910, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6090], grad_fn=<RsubBackward1>), epsilon: 0.25
# 17: dp: tensor([[0.2500, 0.3803, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6197], grad_fn=<RsubBackward1>), epsilon: 0.25
# 18: dp: tensor([[0.2500, 0.3719, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6281], grad_fn=<RsubBackward1>), epsilon: 0.25
# 19: dp: tensor([[0.2500, 0.3683, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6317], grad_fn=<RsubBackward1>), epsilon: 0.25
# 20: dp: tensor([[0.2500, 0.3662, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6338], grad_fn=<RsubBackward1>), epsilon: 0.25
# 21: dp: tensor([[0.2500, 0.3652, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6348], grad_fn=<RsubBackward1>), epsilon: 0.25
# 22: dp: tensor([[0.2500, 0.3652, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6348], grad_fn=<RsubBackward1>), epsilon: 0.25
# 23: dp: tensor([[0.2500, 0.3662, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6338], grad_fn=<RsubBackward1>), epsilon: 0.25
# 24: dp: tensor([[0.2500, 0.3684, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8684], grad_fn=<RsubBackward1>), epsilon: 0.25
# 25: dp: tensor([[0.2500, 0.3572, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6428], grad_fn=<RsubBackward1>), epsilon: 0.25
# 26: dp: tensor([[0.2500, 0.3475, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6525], grad_fn=<RsubBackward1>), epsilon: 0.25
# 27: dp: tensor([[0.2500, 0.3393, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6607], grad_fn=<RsubBackward1>), epsilon: 0.25
# 28: dp: tensor([[0.2500, 0.3324, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6676], grad_fn=<RsubBackward1>), epsilon: 0.25
# 29: dp: tensor([[0.2500, 0.3269, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6731], grad_fn=<RsubBackward1>), epsilon: 0.25
# 30: dp: tensor([[0.2500, 0.3229, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6771], grad_fn=<RsubBackward1>), epsilon: 0.25
# 31: dp: tensor([[0.2500, 0.3201, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6799], grad_fn=<RsubBackward1>), epsilon: 0.25
# 32: dp: tensor([[0.2500, 0.3186, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6814], grad_fn=<RsubBackward1>), epsilon: 0.25
# 33: dp: tensor([[0.2500, 0.3183, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6817], grad_fn=<RsubBackward1>), epsilon: 0.25
# 34: dp: tensor([[0.2500, 0.3191, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6809], grad_fn=<RsubBackward1>), epsilon: 0.25
# 35: dp: tensor([[0.2500, 0.3208, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6792], grad_fn=<RsubBackward1>), epsilon: 0.25
# 36: dp: tensor([[0.2500, 0.3234, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8234], grad_fn=<RsubBackward1>), epsilon: 0.25
# 37: dp: tensor([[0.2500, 0.3112, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6888], grad_fn=<RsubBackward1>), epsilon: 0.25
# 38: dp: tensor([[0.2500, 0.3007, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6993], grad_fn=<RsubBackward1>), epsilon: 0.25
# 39: dp: tensor([[0.2500, 0.2919, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7081], grad_fn=<RsubBackward1>), epsilon: 0.25
# 40: dp: tensor([[0.2500, 0.2848, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7152], grad_fn=<RsubBackward1>), epsilon: 0.25
# 41: dp: tensor([[0.2500, 0.2793, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7207], grad_fn=<RsubBackward1>), epsilon: 0.25
# 42: dp: tensor([[0.2500, 0.2753, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7247], grad_fn=<RsubBackward1>), epsilon: 0.25
# 43: dp: tensor([[0.2500, 0.2727, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7727], grad_fn=<RsubBackward1>), epsilon: 0.25
# 44: dp: tensor([[0.2500, 0.2565, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7435], grad_fn=<RsubBackward1>), epsilon: 0.25
# 45: dp: tensor([[0.2500, 0.2516, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 46: dp: tensor([[0.2552, 0.2500, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7552], grad_fn=<RsubBackward1>), epsilon: 0.25
# 47: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 48: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.25
# 49: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2764]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2236], grad_fn=<RsubBackward1>), epsilon: 0.25
# 50: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3104]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1896], grad_fn=<RsubBackward1>), epsilon: 0.25
# 51: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3470]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1530], grad_fn=<RsubBackward1>), epsilon: 0.25
# 52: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3815]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3815], grad_fn=<RsubBackward1>), epsilon: 0.25
# 53: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3685]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1315], grad_fn=<RsubBackward1>), epsilon: 0.25
# 54: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3572]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1428], grad_fn=<RsubBackward1>), epsilon: 0.25
# 55: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3480]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1520], grad_fn=<RsubBackward1>), epsilon: 0.25
# 56: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3411]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1589], grad_fn=<RsubBackward1>), epsilon: 0.25
# 57: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3367]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1633], grad_fn=<RsubBackward1>), epsilon: 0.25
# 58: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3347]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1653], grad_fn=<RsubBackward1>), epsilon: 0.25
# 59: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3349]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1651], grad_fn=<RsubBackward1>), epsilon: 0.25
# 60: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3371]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1629], grad_fn=<RsubBackward1>), epsilon: 0.25
# 61: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3411]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1589], grad_fn=<RsubBackward1>), epsilon: 0.25
# 62: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3466]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1534], grad_fn=<RsubBackward1>), epsilon: 0.25
# 63: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3532]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3532], grad_fn=<RsubBackward1>), epsilon: 0.25
# 64: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3389]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1611], grad_fn=<RsubBackward1>), epsilon: 0.25
# 65: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3267]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1733], grad_fn=<RsubBackward1>), epsilon: 0.25
# 66: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3170]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1830], grad_fn=<RsubBackward1>), epsilon: 0.25
# 67: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3098]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1902], grad_fn=<RsubBackward1>), epsilon: 0.25
# 68: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3051]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1949], grad_fn=<RsubBackward1>), epsilon: 0.25
# 69: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3029]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1971], grad_fn=<RsubBackward1>), epsilon: 0.25
# 70: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3030]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1970], grad_fn=<RsubBackward1>), epsilon: 0.25
# 71: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3051]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1949], grad_fn=<RsubBackward1>), epsilon: 0.25
# 72: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3090]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1910], grad_fn=<RsubBackward1>), epsilon: 0.25
# 73: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3145]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1855], grad_fn=<RsubBackward1>), epsilon: 0.25
# 74: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3213]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1787], grad_fn=<RsubBackward1>), epsilon: 0.25
# 75: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3291]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1709], grad_fn=<RsubBackward1>), epsilon: 0.25
# 76: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3377]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1623], grad_fn=<RsubBackward1>), epsilon: 0.25
# 77: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3468]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3468], grad_fn=<RsubBackward1>), epsilon: 0.25
# 78: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3364]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1636], grad_fn=<RsubBackward1>), epsilon: 0.25
# 79: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3282]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3282], grad_fn=<RsubBackward1>), epsilon: 0.25
# 80: dp: tensor([[0.2500, 0.2500, 0.2500, 0.3055]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1945], grad_fn=<RsubBackward1>), epsilon: 0.25
# 81: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2856]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2144], grad_fn=<RsubBackward1>), epsilon: 0.25
# 82: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2689]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2311], grad_fn=<RsubBackward1>), epsilon: 0.25
# 83: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2556]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 84: dp: tensor([[0.2500, 0.2510, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 85: dp: tensor([[0.2500, 0.2519, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7481], grad_fn=<RsubBackward1>), epsilon: 0.25
# 86: dp: tensor([[0.2500, 0.2540, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 87: dp: tensor([[0.2500, 0.2559, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7441], grad_fn=<RsubBackward1>), epsilon: 0.25
# 88: dp: tensor([[0.2500, 0.2589, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7411], grad_fn=<RsubBackward1>), epsilon: 0.25
# 89: dp: tensor([[0.2500, 0.2629, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7371], grad_fn=<RsubBackward1>), epsilon: 0.25
# 90: dp: tensor([[0.2500, 0.2678, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7322], grad_fn=<RsubBackward1>), epsilon: 0.25
# 91: dp: tensor([[0.2500, 0.2735, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7265], grad_fn=<RsubBackward1>), epsilon: 0.25
# 92: dp: tensor([[0.2500, 0.2799, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7201], grad_fn=<RsubBackward1>), epsilon: 0.25
# 93: dp: tensor([[0.2500, 0.2868, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7132], grad_fn=<RsubBackward1>), epsilon: 0.25
# 94: dp: tensor([[0.2500, 0.2944, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7944], grad_fn=<RsubBackward1>), epsilon: 0.25
# 95: dp: tensor([[0.2500, 0.2828, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7172], grad_fn=<RsubBackward1>), epsilon: 0.25
# 96: dp: tensor([[0.2500, 0.2733, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7267], grad_fn=<RsubBackward1>), epsilon: 0.25
# 97: dp: tensor([[0.2500, 0.2658, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7658], grad_fn=<RsubBackward1>), epsilon: 0.25
# 98: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 99: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.1208963692188263
# 1: dp: tensor([[0.2504, 0.2937, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7063], grad_fn=<RsubBackward1>), epsilon: 0.1417686641216278
# 2: dp: tensor([[0.2505, 0.3417, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6583], grad_fn=<RsubBackward1>), epsilon: 0.16261376440525055
# 3: dp: tensor([[0.2505, 0.3884, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6116], grad_fn=<RsubBackward1>), epsilon: 0.18342739343643188
# 4: dp: tensor([[0.2506, 0.4267, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5733], grad_fn=<RsubBackward1>), epsilon: 0.20420658588409424
# 5: dp: tensor([[0.2506, 0.4535, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5465], grad_fn=<RsubBackward1>), epsilon: 0.22495190799236298
# 6: dp: tensor([[0.2506, 0.4705, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9705], grad_fn=<RsubBackward1>), epsilon: 0.24572695791721344
# 7: dp: tensor([[0.2506, 0.4673, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5327], grad_fn=<RsubBackward1>), epsilon: 0.25
# 8: dp: tensor([[0.2506, 0.4646, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5354], grad_fn=<RsubBackward1>), epsilon: 0.25
# 9: dp: tensor([[0.2506, 0.4625, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5375], grad_fn=<RsubBackward1>), epsilon: 0.25
# 10: dp: tensor([[0.2506, 0.4611, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5389], grad_fn=<RsubBackward1>), epsilon: 0.25
# 11: dp: tensor([[0.2506, 0.4602, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9602], grad_fn=<RsubBackward1>), epsilon: 0.25
# 12: dp: tensor([[0.2506, 0.4516, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5484], grad_fn=<RsubBackward1>), epsilon: 0.25
# 13: dp: tensor([[0.2506, 0.4429, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5571], grad_fn=<RsubBackward1>), epsilon: 0.25
# 14: dp: tensor([[0.2506, 0.4348, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5652], grad_fn=<RsubBackward1>), epsilon: 0.25
# 15: dp: tensor([[0.2506, 0.4276, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5724], grad_fn=<RsubBackward1>), epsilon: 0.25
# 16: dp: tensor([[0.2506, 0.4216, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5784], grad_fn=<RsubBackward1>), epsilon: 0.25
# 17: dp: tensor([[0.2505, 0.4172, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5828], grad_fn=<RsubBackward1>), epsilon: 0.25
# 18: dp: tensor([[0.2505, 0.4143, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5857], grad_fn=<RsubBackward1>), epsilon: 0.25
# 19: dp: tensor([[0.2505, 0.4131, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5869], grad_fn=<RsubBackward1>), epsilon: 0.25
# 20: dp: tensor([[0.2505, 0.4133, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5867], grad_fn=<RsubBackward1>), epsilon: 0.25
# 21: dp: tensor([[0.2506, 0.4149, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5851], grad_fn=<RsubBackward1>), epsilon: 0.25
# 22: dp: tensor([[0.2506, 0.4176, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5824], grad_fn=<RsubBackward1>), epsilon: 0.25
# 23: dp: tensor([[0.2506, 0.4213, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5787], grad_fn=<RsubBackward1>), epsilon: 0.25
# 24: dp: tensor([[0.2506, 0.4257, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5743], grad_fn=<RsubBackward1>), epsilon: 0.25
# 25: dp: tensor([[0.2506, 0.4305, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9305], grad_fn=<RsubBackward1>), epsilon: 0.25
# 26: dp: tensor([[0.2506, 0.4193, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5807], grad_fn=<RsubBackward1>), epsilon: 0.25
# 27: dp: tensor([[0.2506, 0.4089, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5911], grad_fn=<RsubBackward1>), epsilon: 0.25
# 28: dp: tensor([[0.2505, 0.3998, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 29: dp: tensor([[0.2505, 0.3922, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6078], grad_fn=<RsubBackward1>), epsilon: 0.25
# 30: dp: tensor([[0.2505, 0.3863, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6137], grad_fn=<RsubBackward1>), epsilon: 0.25
# 31: dp: tensor([[0.2505, 0.3824, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6176], grad_fn=<RsubBackward1>), epsilon: 0.25
# 32: dp: tensor([[0.2505, 0.3802, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6198], grad_fn=<RsubBackward1>), epsilon: 0.25
# 33: dp: tensor([[0.2505, 0.3797, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8797], grad_fn=<RsubBackward1>), epsilon: 0.25
# 34: dp: tensor([[0.2505, 0.3585, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6415], grad_fn=<RsubBackward1>), epsilon: 0.25
# 35: dp: tensor([[0.2505, 0.3395, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6605], grad_fn=<RsubBackward1>), epsilon: 0.25
# 36: dp: tensor([[0.2505, 0.3233, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6767], grad_fn=<RsubBackward1>), epsilon: 0.25
# 37: dp: tensor([[0.2505, 0.3102, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6898], grad_fn=<RsubBackward1>), epsilon: 0.25
# 38: dp: tensor([[0.2505, 0.2999, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 39: dp: tensor([[0.2504, 0.2922, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7078], grad_fn=<RsubBackward1>), epsilon: 0.25
# 40: dp: tensor([[0.2504, 0.2868, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7868], grad_fn=<RsubBackward1>), epsilon: 0.25
# 41: dp: tensor([[0.2504, 0.2654, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7346], grad_fn=<RsubBackward1>), epsilon: 0.25
# 42: dp: tensor([[0.2504, 0.2552, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7448], grad_fn=<RsubBackward1>), epsilon: 0.25
# 43: dp: tensor([[0.2504, 0.2506, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7494], grad_fn=<RsubBackward1>), epsilon: 0.25
# 44: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7504], grad_fn=<RsubBackward1>), epsilon: 0.25
# 45: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.25
# 46: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2756]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2244], grad_fn=<RsubBackward1>), epsilon: 0.25
# 47: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3088]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1912], grad_fn=<RsubBackward1>), epsilon: 0.25
# 48: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3447]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1553], grad_fn=<RsubBackward1>), epsilon: 0.25
# 49: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3787]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1213], grad_fn=<RsubBackward1>), epsilon: 0.25
# 50: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4078]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0922], grad_fn=<RsubBackward1>), epsilon: 0.25
# 51: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4308]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0692], grad_fn=<RsubBackward1>), epsilon: 0.25
# 52: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4481]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0519], grad_fn=<RsubBackward1>), epsilon: 0.25
# 53: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4607]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4607], grad_fn=<RsubBackward1>), epsilon: 0.25
# 54: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4590]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0410], grad_fn=<RsubBackward1>), epsilon: 0.25
# 55: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4574]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4574], grad_fn=<RsubBackward1>), epsilon: 0.25
# 56: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0500], grad_fn=<RsubBackward1>), epsilon: 0.25
# 57: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4424]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0576], grad_fn=<RsubBackward1>), epsilon: 0.25
# 58: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4350]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0650], grad_fn=<RsubBackward1>), epsilon: 0.25
# 59: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4279]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0721], grad_fn=<RsubBackward1>), epsilon: 0.25
# 60: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4214]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0786], grad_fn=<RsubBackward1>), epsilon: 0.25
# 61: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4157]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0843], grad_fn=<RsubBackward1>), epsilon: 0.25
# 62: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4110]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0890], grad_fn=<RsubBackward1>), epsilon: 0.25
# 63: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4074]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0926], grad_fn=<RsubBackward1>), epsilon: 0.25
# 64: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4049]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0951], grad_fn=<RsubBackward1>), epsilon: 0.25
# 65: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4036]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0964], grad_fn=<RsubBackward1>), epsilon: 0.25
# 66: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4034]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0966], grad_fn=<RsubBackward1>), epsilon: 0.25
# 67: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4042]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0958], grad_fn=<RsubBackward1>), epsilon: 0.25
# 68: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4059]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0941], grad_fn=<RsubBackward1>), epsilon: 0.25
# 69: dp: tensor([[0.2500, 0.2500, 0.2504, 0.4084]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4084], grad_fn=<RsubBackward1>), epsilon: 0.25
# 70: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3945]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1055], grad_fn=<RsubBackward1>), epsilon: 0.25
# 71: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3814]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1186], grad_fn=<RsubBackward1>), epsilon: 0.25
# 72: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3699]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1301], grad_fn=<RsubBackward1>), epsilon: 0.25
# 73: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3601]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1399], grad_fn=<RsubBackward1>), epsilon: 0.25
# 74: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3526]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1474], grad_fn=<RsubBackward1>), epsilon: 0.25
# 75: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3474]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1526], grad_fn=<RsubBackward1>), epsilon: 0.25
# 76: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3446]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3446], grad_fn=<RsubBackward1>), epsilon: 0.25
# 77: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3216]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1784], grad_fn=<RsubBackward1>), epsilon: 0.25
# 78: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3015]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1985], grad_fn=<RsubBackward1>), epsilon: 0.25
# 79: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2849]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2151], grad_fn=<RsubBackward1>), epsilon: 0.25
# 80: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2722]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2278], grad_fn=<RsubBackward1>), epsilon: 0.25
# 81: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2633]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2367], grad_fn=<RsubBackward1>), epsilon: 0.25
# 82: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2581]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2419], grad_fn=<RsubBackward1>), epsilon: 0.25
# 83: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2563]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2437], grad_fn=<RsubBackward1>), epsilon: 0.25
# 84: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2576]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2424], grad_fn=<RsubBackward1>), epsilon: 0.25
# 85: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2618]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2382], grad_fn=<RsubBackward1>), epsilon: 0.25
# 86: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2684]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2316], grad_fn=<RsubBackward1>), epsilon: 0.25
# 87: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2771]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2229], grad_fn=<RsubBackward1>), epsilon: 0.25
# 88: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2876]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2124], grad_fn=<RsubBackward1>), epsilon: 0.25
# 89: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2994]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2994], grad_fn=<RsubBackward1>), epsilon: 0.25
# 90: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2870]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2130], grad_fn=<RsubBackward1>), epsilon: 0.25
# 91: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2776]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2224], grad_fn=<RsubBackward1>), epsilon: 0.25
# 92: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2712]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2288], grad_fn=<RsubBackward1>), epsilon: 0.25
# 93: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2676]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2324], grad_fn=<RsubBackward1>), epsilon: 0.25
# 94: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2666]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2334], grad_fn=<RsubBackward1>), epsilon: 0.25
# 95: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2680]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2320], grad_fn=<RsubBackward1>), epsilon: 0.25
# 96: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2716]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2284], grad_fn=<RsubBackward1>), epsilon: 0.25
# 97: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2770]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2230], grad_fn=<RsubBackward1>), epsilon: 0.25
# 98: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2840]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2160], grad_fn=<RsubBackward1>), epsilon: 0.25
# 99: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2924]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2076], grad_fn=<RsubBackward1>), epsilon: 0.25
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.12036372721195221
# 1: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2937]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2063], grad_fn=<RsubBackward1>), epsilon: 0.14059008657932281
# 2: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3416]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1584], grad_fn=<RsubBackward1>), epsilon: 0.16067145764827728
# 3: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3877]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1123], grad_fn=<RsubBackward1>), epsilon: 0.18062923848628998
# 4: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4246]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0754], grad_fn=<RsubBackward1>), epsilon: 0.20050391554832458
# 5: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4499]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0501], grad_fn=<RsubBackward1>), epsilon: 0.220328226685524
# 6: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4660]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0340], grad_fn=<RsubBackward1>), epsilon: 0.24011938273906708
# 7: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4762]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4762], grad_fn=<RsubBackward1>), epsilon: 0.25
# 8: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4745]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0255], grad_fn=<RsubBackward1>), epsilon: 0.25
# 9: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4730]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0270], grad_fn=<RsubBackward1>), epsilon: 0.25
# 10: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4717]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0283], grad_fn=<RsubBackward1>), epsilon: 0.25
# 11: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4705]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0295], grad_fn=<RsubBackward1>), epsilon: 0.25
# 12: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4695]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0305], grad_fn=<RsubBackward1>), epsilon: 0.25
# 13: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4687]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0313], grad_fn=<RsubBackward1>), epsilon: 0.25
# 14: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4680]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0320], grad_fn=<RsubBackward1>), epsilon: 0.25
# 15: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4676]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0324], grad_fn=<RsubBackward1>), epsilon: 0.25
# 16: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4672]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0328], grad_fn=<RsubBackward1>), epsilon: 0.25
# 17: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4671]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0329], grad_fn=<RsubBackward1>), epsilon: 0.25
# 18: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4671]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0329], grad_fn=<RsubBackward1>), epsilon: 0.25
# 19: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4672]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4672], grad_fn=<RsubBackward1>), epsilon: 0.25
# 20: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4603]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0397], grad_fn=<RsubBackward1>), epsilon: 0.25
# 21: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4532]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0468], grad_fn=<RsubBackward1>), epsilon: 0.25
# 22: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4459]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0541], grad_fn=<RsubBackward1>), epsilon: 0.25
# 23: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4389]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0611], grad_fn=<RsubBackward1>), epsilon: 0.25
# 24: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4325]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0675], grad_fn=<RsubBackward1>), epsilon: 0.25
# 25: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4269]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0731], grad_fn=<RsubBackward1>), epsilon: 0.25
# 26: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4223]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0777], grad_fn=<RsubBackward1>), epsilon: 0.25
# 27: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4190]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0810], grad_fn=<RsubBackward1>), epsilon: 0.25
# 28: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4170]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0830], grad_fn=<RsubBackward1>), epsilon: 0.25
# 29: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4163]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4163], grad_fn=<RsubBackward1>), epsilon: 0.25
# 30: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3968]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1032], grad_fn=<RsubBackward1>), epsilon: 0.25
# 31: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3780]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1220], grad_fn=<RsubBackward1>), epsilon: 0.25
# 32: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3611]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1389], grad_fn=<RsubBackward1>), epsilon: 0.25
# 33: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3471]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3471], grad_fn=<RsubBackward1>), epsilon: 0.25
# 34: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3161]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1839], grad_fn=<RsubBackward1>), epsilon: 0.25
# 35: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2906]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2094], grad_fn=<RsubBackward1>), epsilon: 0.25
# 36: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2710]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2290], grad_fn=<RsubBackward1>), epsilon: 0.25
# 37: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2602]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2398], grad_fn=<RsubBackward1>), epsilon: 0.25
# 38: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2571]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2429], grad_fn=<RsubBackward1>), epsilon: 0.25
# 39: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2551]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2449], grad_fn=<RsubBackward1>), epsilon: 0.25
# 40: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2540]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.25
# 41: dp: tensor([[0.2504, 0.2744, 0.2504, 0.2530]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7256], grad_fn=<RsubBackward1>), epsilon: 0.25
# 42: dp: tensor([[0.2504, 0.3062, 0.2504, 0.2521]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6938], grad_fn=<RsubBackward1>), epsilon: 0.25
# 43: dp: tensor([[0.2504, 0.3415, 0.2504, 0.2513]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6585], grad_fn=<RsubBackward1>), epsilon: 0.25
# 44: dp: tensor([[0.2504, 0.3803, 0.2504, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6197], grad_fn=<RsubBackward1>), epsilon: 0.25
# 45: dp: tensor([[0.2504, 0.4191, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5809], grad_fn=<RsubBackward1>), epsilon: 0.25
# 46: dp: tensor([[0.2505, 0.4517, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5483], grad_fn=<RsubBackward1>), epsilon: 0.25
# 47: dp: tensor([[0.2505, 0.4737, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5263], grad_fn=<RsubBackward1>), epsilon: 0.25
# 48: dp: tensor([[0.2505, 0.4862, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9862], grad_fn=<RsubBackward1>), epsilon: 0.25
# 49: dp: tensor([[0.2505, 0.4861, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5139], grad_fn=<RsubBackward1>), epsilon: 0.25
# 50: dp: tensor([[0.2505, 0.4863, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5137], grad_fn=<RsubBackward1>), epsilon: 0.25
# 51: dp: tensor([[0.2505, 0.4866, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9866], grad_fn=<RsubBackward1>), epsilon: 0.25
# 52: dp: tensor([[0.2505, 0.4820, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5180], grad_fn=<RsubBackward1>), epsilon: 0.25
# 53: dp: tensor([[0.2505, 0.4769, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5231], grad_fn=<RsubBackward1>), epsilon: 0.25
# 54: dp: tensor([[0.2504, 0.4717, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5283], grad_fn=<RsubBackward1>), epsilon: 0.25
# 55: dp: tensor([[0.2504, 0.4671, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5329], grad_fn=<RsubBackward1>), epsilon: 0.25
# 56: dp: tensor([[0.2504, 0.4636, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5364], grad_fn=<RsubBackward1>), epsilon: 0.25
# 57: dp: tensor([[0.2504, 0.4616, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5384], grad_fn=<RsubBackward1>), epsilon: 0.25
# 58: dp: tensor([[0.2504, 0.4612, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5388], grad_fn=<RsubBackward1>), epsilon: 0.25
# 59: dp: tensor([[0.2504, 0.4622, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5378], grad_fn=<RsubBackward1>), epsilon: 0.25
# 60: dp: tensor([[0.2504, 0.4645, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5355], grad_fn=<RsubBackward1>), epsilon: 0.25
# 61: dp: tensor([[0.2504, 0.4676, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5324], grad_fn=<RsubBackward1>), epsilon: 0.25
# 62: dp: tensor([[0.2504, 0.4712, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5288], grad_fn=<RsubBackward1>), epsilon: 0.25
# 63: dp: tensor([[0.2504, 0.4749, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5251], grad_fn=<RsubBackward1>), epsilon: 0.25
# 64: dp: tensor([[0.2505, 0.4784, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5216], grad_fn=<RsubBackward1>), epsilon: 0.25
# 65: dp: tensor([[0.2505, 0.4816, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5184], grad_fn=<RsubBackward1>), epsilon: 0.25
# 66: dp: tensor([[0.2505, 0.4844, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5156], grad_fn=<RsubBackward1>), epsilon: 0.25
# 67: dp: tensor([[0.2505, 0.4868, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5132], grad_fn=<RsubBackward1>), epsilon: 0.25
# 68: dp: tensor([[0.2505, 0.4888, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9888], grad_fn=<RsubBackward1>), epsilon: 0.25
# 69: dp: tensor([[0.2505, 0.4874, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5126], grad_fn=<RsubBackward1>), epsilon: 0.25
# 70: dp: tensor([[0.2505, 0.4861, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5139], grad_fn=<RsubBackward1>), epsilon: 0.25
# 71: dp: tensor([[0.2505, 0.4850, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5150], grad_fn=<RsubBackward1>), epsilon: 0.25
# 72: dp: tensor([[0.2505, 0.4843, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9843], grad_fn=<RsubBackward1>), epsilon: 0.25
# 73: dp: tensor([[0.2505, 0.4781, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5219], grad_fn=<RsubBackward1>), epsilon: 0.25
# 74: dp: tensor([[0.2505, 0.4711, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5289], grad_fn=<RsubBackward1>), epsilon: 0.25
# 75: dp: tensor([[0.2504, 0.4641, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5359], grad_fn=<RsubBackward1>), epsilon: 0.25
# 76: dp: tensor([[0.2504, 0.4578, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5422], grad_fn=<RsubBackward1>), epsilon: 0.25
# 77: dp: tensor([[0.2504, 0.4527, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5473], grad_fn=<RsubBackward1>), epsilon: 0.25
# 78: dp: tensor([[0.2504, 0.4492, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5508], grad_fn=<RsubBackward1>), epsilon: 0.25
# 79: dp: tensor([[0.2504, 0.4476, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5524], grad_fn=<RsubBackward1>), epsilon: 0.25
# 80: dp: tensor([[0.2504, 0.4477, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9477], grad_fn=<RsubBackward1>), epsilon: 0.25
# 81: dp: tensor([[0.2504, 0.4300, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5700], grad_fn=<RsubBackward1>), epsilon: 0.25
# 82: dp: tensor([[0.2504, 0.4185, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5815], grad_fn=<RsubBackward1>), epsilon: 0.25
# 83: dp: tensor([[0.2504, 0.4079, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5921], grad_fn=<RsubBackward1>), epsilon: 0.25
# 84: dp: tensor([[0.2504, 0.3986, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6014], grad_fn=<RsubBackward1>), epsilon: 0.25
# 85: dp: tensor([[0.2504, 0.3911, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6089], grad_fn=<RsubBackward1>), epsilon: 0.25
# 86: dp: tensor([[0.2504, 0.3857, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6143], grad_fn=<RsubBackward1>), epsilon: 0.25
# 87: dp: tensor([[0.2504, 0.3823, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6177], grad_fn=<RsubBackward1>), epsilon: 0.25
# 88: dp: tensor([[0.2504, 0.3811, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6189], grad_fn=<RsubBackward1>), epsilon: 0.25
# 89: dp: tensor([[0.2504, 0.3818, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6182], grad_fn=<RsubBackward1>), epsilon: 0.25
# 90: dp: tensor([[0.2504, 0.3842, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6158], grad_fn=<RsubBackward1>), epsilon: 0.25
# 91: dp: tensor([[0.2504, 0.3880, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6120], grad_fn=<RsubBackward1>), epsilon: 0.25
# 92: dp: tensor([[0.2504, 0.3935, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6065], grad_fn=<RsubBackward1>), epsilon: 0.25
# 93: dp: tensor([[0.2504, 0.4003, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5997], grad_fn=<RsubBackward1>), epsilon: 0.25
# 94: dp: tensor([[0.2504, 0.4081, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5919], grad_fn=<RsubBackward1>), epsilon: 0.25
# 95: dp: tensor([[0.2504, 0.4167, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9167], grad_fn=<RsubBackward1>), epsilon: 0.25
# 96: dp: tensor([[0.2504, 0.4003, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5997], grad_fn=<RsubBackward1>), epsilon: 0.25
# 97: dp: tensor([[0.2504, 0.3893, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6107], grad_fn=<RsubBackward1>), epsilon: 0.25
# 98: dp: tensor([[0.2504, 0.3799, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6201], grad_fn=<RsubBackward1>), epsilon: 0.25
# 99: dp: tensor([[0.2504, 0.3723, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6277], grad_fn=<RsubBackward1>), epsilon: 0.25
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.12036372721195221
# 1: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2937]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2937], grad_fn=<RsubBackward1>), epsilon: 0.1412433683872223
# 2: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2631]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2369], grad_fn=<RsubBackward1>), epsilon: 0.16153167188167572
# ...
# 99: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2642]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2358], grad_fn=<RsubBackward1>), epsilon: 0.25
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.12036372721195221
# 1: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2937]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2063], grad_fn=<RsubBackward1>), epsilon: 0.14059008657932281
# 2: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3416]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1584], grad_fn=<RsubBackward1>), epsilon: 0.16067145764827728
# 3: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3877]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1123], grad_fn=<RsubBackward1>), epsilon: 0.18062923848628998
# 4: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4246]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0754], grad_fn=<RsubBackward1>), epsilon: 0.20050391554832458
# 5: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4499]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0501], grad_fn=<RsubBackward1>), epsilon: 0.220328226685524
# 6: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4660]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0340], grad_fn=<RsubBackward1>), epsilon: 0.24011938273906708
# 7: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4762]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0238], grad_fn=<RsubBackward1>), epsilon: 0.25
# 8: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4827]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4827], grad_fn=<RsubBackward1>), epsilon: 0.25
# 9: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4822]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0178], grad_fn=<RsubBackward1>), epsilon: 0.25
# 10: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4818]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0182], grad_fn=<RsubBackward1>), epsilon: 0.25
# 11: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4814]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0186], grad_fn=<RsubBackward1>), epsilon: 0.25
# 12: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4811]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0189], grad_fn=<RsubBackward1>), epsilon: 0.25
# 13: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4808]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0192], grad_fn=<RsubBackward1>), epsilon: 0.25
# 14: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4806]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0194], grad_fn=<RsubBackward1>), epsilon: 0.25
# 15: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4805]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4805], grad_fn=<RsubBackward1>), epsilon: 0.25
# 16: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4769]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0231], grad_fn=<RsubBackward1>), epsilon: 0.25
# 17: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4732]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0268], grad_fn=<RsubBackward1>), epsilon: 0.25
# 18: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4695]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0305], grad_fn=<RsubBackward1>), epsilon: 0.25
# 19: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4657]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0343], grad_fn=<RsubBackward1>), epsilon: 0.25
# 20: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4621]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4621], grad_fn=<RsubBackward1>), epsilon: 0.25
# 21: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4515]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0485], grad_fn=<RsubBackward1>), epsilon: 0.25
# 22: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4399]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0601], grad_fn=<RsubBackward1>), epsilon: 0.25
# 23: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4279]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0721], grad_fn=<RsubBackward1>), epsilon: 0.25
# 24: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4162]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0838], grad_fn=<RsubBackward1>), epsilon: 0.25
# 25: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4055]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0945], grad_fn=<RsubBackward1>), epsilon: 0.25
# 26: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3964]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1036], grad_fn=<RsubBackward1>), epsilon: 0.25
# 27: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3894]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1106], grad_fn=<RsubBackward1>), epsilon: 0.25
# 28: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3849]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1151], grad_fn=<RsubBackward1>), epsilon: 0.25
# 29: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3829]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1171], grad_fn=<RsubBackward1>), epsilon: 0.25
# 30: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3833]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1167], grad_fn=<RsubBackward1>), epsilon: 0.25
# 31: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3860]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1140], grad_fn=<RsubBackward1>), epsilon: 0.25
# 32: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3905]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1095], grad_fn=<RsubBackward1>), epsilon: 0.25
# 33: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3964]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1036], grad_fn=<RsubBackward1>), epsilon: 0.25
# 34: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4033]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0967], grad_fn=<RsubBackward1>), epsilon: 0.25
# 35: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4107]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0893], grad_fn=<RsubBackward1>), epsilon: 0.25
# 36: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4182]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4182], grad_fn=<RsubBackward1>), epsilon: 0.25
# 37: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4036]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0964], grad_fn=<RsubBackward1>), epsilon: 0.25
# 38: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3897]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1103], grad_fn=<RsubBackward1>), epsilon: 0.25
# 39: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3774]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1226], grad_fn=<RsubBackward1>), epsilon: 0.25
# 40: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3673]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1327], grad_fn=<RsubBackward1>), epsilon: 0.25
# 41: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3597]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1403], grad_fn=<RsubBackward1>), epsilon: 0.25
# 42: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3547]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1453], grad_fn=<RsubBackward1>), epsilon: 0.25
# 43: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3525]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1475], grad_fn=<RsubBackward1>), epsilon: 0.25
# 44: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3529]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3529], grad_fn=<RsubBackward1>), epsilon: 0.25
# 45: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3270]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1730], grad_fn=<RsubBackward1>), epsilon: 0.25
# 46: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3049]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1951], grad_fn=<RsubBackward1>), epsilon: 0.25
# 47: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2873]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2127], grad_fn=<RsubBackward1>), epsilon: 0.25
# 48: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2743]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2257], grad_fn=<RsubBackward1>), epsilon: 0.25
# 49: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2656]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2344], grad_fn=<RsubBackward1>), epsilon: 0.25
# 50: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2646]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2646], grad_fn=<RsubBackward1>), epsilon: 0.25
# 51: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2581]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2419], grad_fn=<RsubBackward1>), epsilon: 0.25
# 52: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2529]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2471], grad_fn=<RsubBackward1>), epsilon: 0.25
# 53: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7495], grad_fn=<RsubBackward1>), epsilon: 0.25
# 54: dp: tensor([[0.2505, 0.2836, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7164], grad_fn=<RsubBackward1>), epsilon: 0.25
# 55: dp: tensor([[0.2505, 0.3266, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6734], grad_fn=<RsubBackward1>), epsilon: 0.25
# 56: dp: tensor([[0.2505, 0.3748, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6252], grad_fn=<RsubBackward1>), epsilon: 0.25
# 57: dp: tensor([[0.2505, 0.4208, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5792], grad_fn=<RsubBackward1>), epsilon: 0.25
# 58: dp: tensor([[0.2505, 0.4555, 0.2505, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5445], grad_fn=<RsubBackward1>), epsilon: 0.25
# 59: dp: tensor([[0.2506, 0.4766, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5234], grad_fn=<RsubBackward1>), epsilon: 0.25
# 60: dp: tensor([[0.2506, 0.4877, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5123], grad_fn=<RsubBackward1>), epsilon: 0.25
# 61: dp: tensor([[0.2506, 0.4933, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5067], grad_fn=<RsubBackward1>), epsilon: 0.25
# 62: dp: tensor([[0.2506, 0.4962, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9962], grad_fn=<RsubBackward1>), epsilon: 0.25
# 63: dp: tensor([[0.2506, 0.4973, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5027], grad_fn=<RsubBackward1>), epsilon: 0.25
# 64: dp: tensor([[0.2506, 0.4980, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5020], grad_fn=<RsubBackward1>), epsilon: 0.25
# 65: dp: tensor([[0.2506, 0.4985, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5015], grad_fn=<RsubBackward1>), epsilon: 0.25
# 66: dp: tensor([[0.2506, 0.4988, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5012], grad_fn=<RsubBackward1>), epsilon: 0.25
# 67: dp: tensor([[0.2506, 0.4991, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5009], grad_fn=<RsubBackward1>), epsilon: 0.25
# 68: dp: tensor([[0.2506, 0.4993, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5007], grad_fn=<RsubBackward1>), epsilon: 0.25
# 69: dp: tensor([[0.2506, 0.4994, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5006], grad_fn=<RsubBackward1>), epsilon: 0.25
# 70: dp: tensor([[0.2506, 0.4995, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5005], grad_fn=<RsubBackward1>), epsilon: 0.25
# 71: dp: tensor([[0.2506, 0.4996, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9996], grad_fn=<RsubBackward1>), epsilon: 0.25
# 72: dp: tensor([[0.2506, 0.4996, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5004], grad_fn=<RsubBackward1>), epsilon: 0.25
# 73: dp: tensor([[0.2506, 0.4997, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5003], grad_fn=<RsubBackward1>), epsilon: 0.25
# 74: dp: tensor([[0.2506, 0.4997, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5003], grad_fn=<RsubBackward1>), epsilon: 0.25
# 75: dp: tensor([[0.2506, 0.4997, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5003], grad_fn=<RsubBackward1>), epsilon: 0.25
# 76: dp: tensor([[0.2506, 0.4997, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9997], grad_fn=<RsubBackward1>), epsilon: 0.25
# 77: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 78: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 79: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 80: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 81: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 82: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 83: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 84: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9998], grad_fn=<RsubBackward1>), epsilon: 0.25
# 85: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 86: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 87: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 88: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 89: dp: tensor([[0.2506, 0.4998, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5002], grad_fn=<RsubBackward1>), epsilon: 0.25
# 90: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 91: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 92: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 93: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 94: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9999], grad_fn=<RsubBackward1>), epsilon: 0.25
# 95: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 96: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 97: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 98: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25
# 99: dp: tensor([[0.2506, 0.4999, 0.2506, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5001], grad_fn=<RsubBackward1>), epsilon: 0.25

# %% [markdown]
# ## Analysis

# %%
A_picks = avg_counts[0]
B_picks = avg_counts[1]
C_picks = avg_counts[2]
D_picks = avg_counts[3]

Avg_A_picks = torch.mean(A_picks, dim = 0)
Avg_B_picks = torch.mean(B_picks, dim = 0)
Avg_C_picks = torch.mean(C_picks, dim = 0)
Avg_D_picks = torch.mean(D_picks, dim = 0)

IGT_score = torch.mean(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0).squeeze().numpy()
IGT_dev = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)/torch.sqrt(torch.tensor(EPOCHS, dtype = torch.float32))
IGT_dev = IGT_dev.squeeze().numpy()

print(f'IGT score: {IGT_score} with SE of {IGT_dev}')
# Out:
# IGT score: [-0.2  3.4  5.8 10.8  1.6] with SE of [5.4360933 5.5541778 4.0819387 5.1742954 5.7100306]

# %%
A_picks = avg_counts[0]
B_picks = avg_counts[1]
C_picks = avg_counts[2]
D_picks = avg_counts[3]

Avg_A_picks = torch.mean(A_picks, dim = 0)
Avg_B_picks = torch.mean(B_picks, dim = 0)
Avg_C_picks = torch.mean(C_picks, dim = 0)
Avg_D_picks = torch.mean(D_picks, dim = 0)

IP_A = torch.mean(ip_monitor[0], dim = 0).detach().numpy()
IP_B = torch.mean(ip_monitor[1], dim = 0).detach().numpy()
IP_C = torch.mean(ip_monitor[2], dim = 0).detach().numpy()
IP_D = torch.mean(ip_monitor[3], dim = 0).detach().numpy()

DP_A = torch.mean(dp_monitor[0], dim = 0).detach().numpy()
DP_B = torch.mean(dp_monitor[1], dim = 0).detach().numpy()
DP_C = torch.mean(dp_monitor[2], dim = 0).detach().numpy()
DP_D = torch.mean(dp_monitor[3], dim = 0).detach().numpy()

IGT_score = torch.mean(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)
IGT_dev = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)/torch.sqrt(torch.tensor(EPOCHS, dtype = torch.float32))

IP_all = np.array([IP_A[:,0],IP_B[:,0],IP_C[:,0],IP_D[:,0]])
IP_Var = np.std(IP_all,axis = 0 )

# %% [markdown]
# ## Results

# %%
random_pick = np.random.choice(np.arange(EPOCHS), size = 9)

plt.figure(figsize=(10,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    colors = np.where(np.isin(arm_chosen_monitor[random_pick[i]],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRAILS), arm_chosen_monitor[random_pick[i]], c = colors, s = 10)
    plt.ylim(-1,4)
plt.xlabel('trails', fontsize = 9)
# Out:
# Text(0.5, 0, 'trails')

# %%
BINS = np.arange(5) + 1

plt.figure(figsize=(10,8))

plt.subplot(321)
plt.plot(np.arange(100), DP_A, label = 'A', color = 'red')
plt.plot(np.arange(100), DP_B, label = 'B', color = 'red')
plt.plot(np.arange(100), DP_C, label = 'C', color = 'green')
plt.plot(np.arange(100), DP_D, label = 'D', color = 'green')
plt.xlabel('trails')
plt.title('Avg DP with trails')
plt.legend(loc = 'upper right')

plt.subplot(322)
plt.plot(np.arange(100), IP_A, label = 'A', color = 'red')
plt.plot(np.arange(100), IP_B, label = 'B', color = 'red')
plt.plot(np.arange(100), IP_C, label = 'C', color = 'green')
plt.plot(np.arange(100), IP_D, label = 'D', color = 'green')
plt.xlabel('trails')
plt.title('Avg IP with trails')
plt.legend(loc = 'upper right')

plt.subplot(323)
plt.plot(BINS,Avg_A_picks, label = 'A', color = 'red', marker = 'o')
plt.plot(BINS,Avg_B_picks, label = 'B', color = 'red', marker = 's')
plt.plot(BINS,Avg_C_picks, label = 'C', color = 'green', marker = 'D')
plt.plot(BINS,Avg_D_picks, label = 'D', color = 'green', marker = '^')
plt.title('Avg card picks with trails')
plt.legend(loc = 'upper right')

plt.subplot(324)
plt.bar(BINS, IGT_score.reshape(5))
print(IGT_score, IGT_dev)
plt.errorbar(BINS, IGT_score.reshape(5), yerr= IGT_dev.reshape(5), fmt='o', color = 'black')
plt.title(f'IGT score')
plt.xlabel('BINS')
plt.ylabel('IGT Score')

plt.subplot(325)
plt.plot(IP_Var)
# plt.ylim(0.0,0.0025)
plt.title('IP variance', fontsize = 9)
plt.xticks(fontsize = 9)
plt.yticks(fontsize = 9)
plt.tight_layout()

plt.tight_layout()
# Out:
# tensor([[-0.2000],
#         [ 3.4000],
#         [ 5.8000],
#         [10.8000],
#         [ 1.6000]]) tensor([[5.4361],
#         [5.5542],
#         [4.0819],
#         [5.1743],
#         [5.7100]])

# %%
IGT_expt= np.array([-1.83,1.5,2.6,4.59,3.9])
IGT_Simulated = IGT_score.reshape(5)

# %%
# Plotting bar for IGT
plt.figure(figsize=(7,5))
plt.bar(BINS, IGT_Simulated, width=0.3, color = 'red', label = 'simulated')
plt.bar(BINS+0.3, IGT_expt, width=0.3, color = 'green', label = 'Experimental')
plt.ylim(-20,20)
plt.title(f'IGT score')
plt.xlabel('BINS')
plt.ylabel('IGT Score')
plt.legend()
plt.tight_layout()

# %%
# Comparison each card pick wise
A_experimental = torch.tensor([4.42,4.12,4.1,4.5,3.68])
A_simulated = Avg_A_picks.squeeze()

B_experimental = torch.tensor([6.74,5.35,4.59,3.3,4.57])
B_simulated = Avg_B_picks.squeeze()

C_experimental = torch.tensor([4.28,4.34, 4.63,6.64, 5.63])
C_simulated = Avg_C_picks.squeeze()

D_experimental = torch.tensor([4.83, 6.48, 6.87, 5.68, 6.39])
D_simulated = Avg_D_picks.squeeze()

# Plotting bar chart for card picks
plt.figure(figsize=(7,5))
plt.subplot(221)
plt.bar(BINS, A_experimental, width=0.3, color = 'red', label = 'exp')
plt.bar(BINS+0.3, A_simulated, width=0.3, color = 'green', label = 'sim')
plt.ylim(0,15)
plt.title('Card: A')
plt.xlabel('BINS')
plt.ylabel('Card picks')
plt.legend()

plt.subplot(222)
plt.bar(BINS, B_experimental, width=0.3, color = 'red', label = 'exp')
plt.bar(BINS+0.3, B_simulated, width=0.3, color = 'green', label = 'sim')
plt.ylim(0,15)
plt.title('Card: B')
plt.xlabel('BINS')
plt.ylabel('Card picks')
plt.legend()

plt.subplot(223)
plt.bar(BINS, C_experimental, width=0.3, color = 'red', label = 'exp')
plt.bar(BINS+0.3, C_simulated, width=0.3, color = 'green', label = 'sim')
plt.ylim(0,15)
plt.title('Card: C')
plt.xlabel('BINS')
plt.ylabel('Card picks')
plt.legend()

plt.subplot(224)
plt.bar(BINS, D_experimental, width=0.3, color = 'red', label = 'exp')
plt.bar(BINS+0.3, D_simulated, width=0.3, color = 'green', label = 'sim')
plt.ylim(0,15)
plt.title('Card: D')
plt.xlabel('BINS')
plt.ylabel('Card picks')
plt.legend()

plt.tight_layout()

# %% [markdown]
# ## Statistical testing

# %%
mean_sim = IGT_score.squeeze().detach().numpy()
mean_expt = IGT_expt
std_sim = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0).squeeze().detach().numpy()
std_expt = std_sim
n_sim = 100
n_expt = 20

# %%
import math
from scipy.stats import t
import pandas as pd

def compare_multiple_pairs(mean_exp, std_exp, n_exp, mean_sim, std_sim, n_sim):
    results = []

    for i in range(len(mean_exp)):
        m1, s1 = mean_exp[i], std_exp[i]
        m2, s2 = mean_sim[i], std_sim[i]

        # Standard error
        se = math.sqrt((s1**2)/n_exp + (s2**2)/n_sim)

        # t-statistic
        t_stat = (m1 - m2) / se

        # Degrees of freedom (Welch-Satterthwaite)
        df_num = (s1**2/n_exp + s2**2/n_sim)**2
        df_den = ((s1**2/n_exp)**2 / (n_exp - 1)) + ((s2**2/n_sim)**2 / (n_sim - 1))
        df = df_num / df_den

        # Two-tailed p-value
        p_val = 2 * (1 - t.cdf(abs(t_stat), df))
        conclusion = "Statistically different" if p_val < 0.05 else "Not statistically different"

        results.append({
            "Index": i+1,
            "Exp Mean": m1,
            "Sim Mean": m2,
            "t-stat": round(t_stat, 3),
            "p-value": round(p_val, 4),
            "Significant": p_val < 0.05,
            "Conclusion": conclusion

        })

    return pd.DataFrame(results)

# Run comparison
df_results_IGT_mean = compare_multiple_pairs(mean_expt, std_expt, n_expt, mean_sim, std_sim, n_sim)

# Show results
# import ace_tools as tools; tools.display_dataframe_to_user(name="Significance Comparison Results", dataframe=df_results)

# %%
df_results_IGT_mean
# Out:
#    Index  Exp Mean  Sim Mean  t-stat  p-value  Significant  \
# 0      1     -1.83       1.2  -0.759   0.4547        False
# 1      2      1.50       8.0  -1.529   0.1379        False
# 2      3      2.60       8.8  -1.449   0.1587        False
# 3      4      4.59       6.4  -0.560   0.5800        False
# 4      5      3.90       3.8   0.026   0.9791        False
#
#                     Conclusion
# 0  Not statistically different
# 1  Not statistically different
# 2  Not statistically different
# 3  Not statistically different
# 4  Not statistically different

# %% [markdown]
# ## Saving data

# %%
data_normal = {'IGT_sim': mean_sim,
               'IGT_sim_std': std_sim,
               'IGT_exp': mean_expt,
               'IGT_exp_std': std_expt,
               'n_expt': n_expt,
               'n_sim': n_sim,
               'article': 'Gescheidt',
               'condition': 'normal',
               'A_experimental': A_experimental,
               'B_experimental': B_experimental,
               'C_experimental': C_experimental,
               'D_experimental': D_experimental,
               'A_simulated': A_simulated,
               'B_simulated': B_simulated,
               'C_simulated': C_simulated,
               'D_simulated': D_simulated,
               'statistical test': df_results_IGT_mean}

# %%
# # saving as pickle file

# with open('data_normal_igt.pkl', 'wb') as f:
#     pickle.dump(data_normal, f)
