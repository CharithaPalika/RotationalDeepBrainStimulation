# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
import os, sys
import torch
from matplotlib.lines import Line2D
from tqdm.autonotebook import tqdm
from matplotlib.colors import LinearSegmentedColormap
# Root project
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to sys.path:", project_root)

from envs import *
from basal_ganglia import *
from stn_gpe import *

# filter warnings
import warnings
warnings.filterwarnings("ignore")



plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman"],  # Times for publication
    "font.size": 8,                    # Base font size
    "axes.labelsize": 8,              # Axis label font size
    "axes.labelweight": "bold",
    "font.weight": "bold",   
    "axes.titlesize":8,              # Axis title (not fig title)
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize":8,              # Legend font size

    "figure.dpi": 300,                 # Display resolution
    "savefig.dpi": 300,                # Save resolution
    "figure.constrained_layout.use": True,  # Better spacing than tight_layout

    "axes.linewidth": 0.8,             # Thin but clear axes lines
    "lines.linewidth": 1.2,
    "lines.markersize": 5,

    "axes.spines.top": False,
    "axes.spines.right": False,

    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.major.size": 4,
    "ytick.major.size": 4,
    "xtick.minor.size": 2,
    "ytick.minor.size": 2,

    "legend.frameon": False,
    "legend.handlelength": 2.0,        # Slightly longer legend lines
    "legend.handletextpad": 0.5,

    "pdf.fonttype": 42,                # Embed editable fonts in PDF
    "ps.fonttype": 42
})
# Out:
# Project root added to sys.path: /Users/charithapalika/Desktop/Lab projects/Decision Making/Light_House_DBS/light_house_DBS_decision_making

# %%
yaml_path = os.path.join(project_root, 'params', 'decision_making_task_params', 'non_stationary_bandits', 'params.yaml')
params = load_yaml(yaml_path)
STN_DATA_path = os.path.join(project_root, 'params', 'stn_gpe_params', 'params_PD.yaml')

# %%
TRIALS = params['TRIALS']
EPOCHS = params['EPOCHS']
BINS = params['NUM_BINS']
LR = params['LR'] 
NUM_ARMS =params['NUM_ARMS']
SCALING_FACTOR = params['SCALING_FACTOR']   
TIME_STAMP_CHANGE = params['TIME_STAMP_CHANGE']
BIN_SIZE = TRIALS//BINS
BIN_CHANGE = TIME_STAMP_CHANGE // BIN_SIZE

# %%
env = NonStationaryEnv(
    num_arms = NUM_ARMS, 
    mean_reward = np.array([20, 40, 25])/SCALING_FACTOR, #np.array([5,40,10])/SCALING_FACTOR, (20,40,10)
    std = np.array([2,2,2])/SCALING_FACTOR, 
    mean_rew_change = np.array([25, 30, 50])/SCALING_FACTOR, #np.array([10,20,60])/SCALING_FACTOR, (10,20,60)
    std_change = np.array([2,2,2])/SCALING_FACTOR, 
    time_stamp_change = TIME_STAMP_CHANGE)

BEST_ARM_BEFORE = 1
BEST_ARM_AFTER = 2

BEST_ARM = torch.zeros((EPOCHS,TRIALS), dtype=int)
BEST_ARM[:,:TIME_STAMP_CHANGE] = BEST_ARM_BEFORE
BEST_ARM[:,TIME_STAMP_CHANGE:] = BEST_ARM_AFTER

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor,ep_monitor, _= train(env, 
                                                      trails = TRIALS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = BINS,
                                                      STN_data = STN_DATA_path, #'rossler',
                                                      d1_amp=0.5, #0.5,
                                                      d2_amp=0.45, #0.0029, 
                                                      gpi_threshold=0.1,
                                                      max_gpi_iters=50,
                                                      del_lim=0.125, train_IP = False, 
                                                      del_med = None, printing = True,
                                                      gpi_mean= 1, ep_0 = 0.3,
                                                      alpha_ep = 0.0,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.0)
# Out:
# Running STN-GPe system
#   0%|          | 0/50000 [00:00<?, ?it/s]
# StdDev of STN: 0.11214268029706471, Mean of STN: 1.0
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.3000]]), gpi: tensor([[-0.1910, -0.1870, -0.1725]], grad_fn=<NegBackward0>), arm_chosen:2
# 1: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.3900, 0.4700]]), gpi: tensor([[-0.1991, -0.1955, -0.2084]], grad_fn=<NegBackward0>), arm_chosen:1
# 2: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4600, 0.4400]]), gpi: tensor([[-0.1908, -0.1992, -0.2009]], grad_fn=<NegBackward0>), arm_chosen:0
# 3: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4800, 0.4400]]), gpi: tensor([[-0.1909, -0.1957, -0.2053]], grad_fn=<NegBackward0>), arm_chosen:0
# 4: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4900, 0.4000]]), gpi: tensor([[-0.2135, -0.1996, -0.1957]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4400, 0.4500]]), gpi: tensor([[-0.2154, -0.1944, -0.2000]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4700]]), gpi: tensor([[-0.2031, -0.1913, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:1
# 7: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.5700]]), gpi: tensor([[-0.1906, -0.2015, -0.2120]], grad_fn=<NegBackward0>), arm_chosen:0
# 8: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4300, 0.4900]]), gpi: tensor([[-0.1881, -0.2009, -0.2021]], grad_fn=<NegBackward0>), arm_chosen:0
# 9: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.5500, 0.3900]]), gpi: tensor([[-0.1954, -0.2094, -0.1965]], grad_fn=<NegBackward0>), arm_chosen:0
# 10: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.3900, 0.4000]]), gpi: tensor([[-0.2119, -0.1860, -0.1881]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4700]]), gpi: tensor([[-0.2146, -0.1956, -0.1938]], grad_fn=<NegBackward0>), arm_chosen:2
# 12: dp: tensor([[0.2500, 0.2503, 0.2514]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4600, 0.4400]]), gpi: tensor([[-0.2023, -0.2094, -0.2094]], grad_fn=<NegBackward0>), arm_chosen:0
# 13: dp: tensor([[0.2500, 0.2503, 0.2526]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4200]]), gpi: tensor([[-0.2026, -0.2087, -0.1875]], grad_fn=<NegBackward0>), arm_chosen:2
# 14: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4900, 0.3500]]), gpi: tensor([[-0.1974, -0.2132, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:2
# 15: dp: tensor([[0.2500, 0.2503, 0.2587]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5000, 0.4400]]), gpi: tensor([[-0.1933, -0.2002, -0.2041]], grad_fn=<NegBackward0>), arm_chosen:0
# 16: dp: tensor([[0.2500, 0.2503, 0.2666]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4800, 0.4400]]), gpi: tensor([[-0.2001, -0.2070, -0.1805]], grad_fn=<NegBackward0>), arm_chosen:2
# 17: dp: tensor([[0.2500, 0.2503, 0.2670]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.4300, 0.4600]]), gpi: tensor([[-0.2122, -0.2015, -0.1896]], grad_fn=<NegBackward0>), arm_chosen:2
# 18: dp: tensor([[0.2500, 0.2503, 0.2556]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5400, 0.3700]]), gpi: tensor([[-0.1989, -0.1986, -0.1938]], grad_fn=<NegBackward0>), arm_chosen:2
# 19: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4600]]), gpi: tensor([[-0.1910, -0.1909, -0.1903]], grad_fn=<NegBackward0>), arm_chosen:2
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.3000]]), gpi: tensor([[-0.1913, -0.1870, -0.1728]], grad_fn=<NegBackward0>), arm_chosen:2
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.3600, 0.4200]]), gpi: tensor([[-0.1911, -0.1760, -0.1919]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4700, 0.5100]]), gpi: tensor([[-0.1845, -0.2044, -0.2126]], grad_fn=<NegBackward0>), arm_chosen:0
# 23: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4800, 0.4000]]), gpi: tensor([[-0.1919, -0.2072, -0.1805]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.3900, 0.4300]]), gpi: tensor([[-0.2215, -0.1992, -0.1783]], grad_fn=<NegBackward0>), arm_chosen:2
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5200, 0.4600]]), gpi: tensor([[-0.2113, -0.1926, -0.1954]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4100, 0.4900]]), gpi: tensor([[-0.2060, -0.2142, -0.2223]], grad_fn=<NegBackward0>), arm_chosen:0
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4200]]), gpi: tensor([[-0.2102, -0.2028, -0.1812]], grad_fn=<NegBackward0>), arm_chosen:2
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4400, 0.4800]]), gpi: tensor([[-0.2006, -0.2043, -0.1922]], grad_fn=<NegBackward0>), arm_chosen:2
# 29: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4500, 0.4400]]), gpi: tensor([[-0.2050, -0.1812, -0.1988]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5000, 0.5300]]), gpi: tensor([[-0.1905, -0.1683, -0.2110]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4900, 0.4000]]), gpi: tensor([[-0.2165, -0.2067, -0.1779]], grad_fn=<NegBackward0>), arm_chosen:2
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5000, 0.4200]]), gpi: tensor([[-0.1966, -0.2121, -0.1767]], grad_fn=<NegBackward0>), arm_chosen:2
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4700, 0.4800]]), gpi: tensor([[-0.2159, -0.2034, -0.1888]], grad_fn=<NegBackward0>), arm_chosen:2
# 34: dp: tensor([[0.2500, 0.2503, 0.2591]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4800, 0.4700]]), gpi: tensor([[-0.2034, -0.2017, -0.2032]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.2503, 0.2674]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4900, 0.4800]]), gpi: tensor([[-0.1993, -0.2145, -0.1919]], grad_fn=<NegBackward0>), arm_chosen:2
# 36: dp: tensor([[0.2500, 0.2503, 0.2724]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.4700]]), gpi: tensor([[-0.2078, -0.1807, -0.1789]], grad_fn=<NegBackward0>), arm_chosen:2
# 37: dp: tensor([[0.2500, 0.2503, 0.2766]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.5400, 0.4600]]), gpi: tensor([[-0.1700, -0.2048, -0.1914]], grad_fn=<NegBackward0>), arm_chosen:0
# 38: dp: tensor([[0.2500, 0.2503, 0.2805]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4300, 0.4300]]), gpi: tensor([[-0.1948, -0.2075, -0.1786]], grad_fn=<NegBackward0>), arm_chosen:2
# 39: dp: tensor([[0.2500, 0.2503, 0.2786]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4900, 0.4500]]), gpi: tensor([[-0.1922, -0.2115, -0.1677]], grad_fn=<NegBackward0>), arm_chosen:2
# 40: dp: tensor([[0.2500, 0.2503, 0.2684]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4800]]), gpi: tensor([[-0.2121, -0.2016, -0.1902]], grad_fn=<NegBackward0>), arm_chosen:2
# 41: dp: tensor([[0.2500, 0.2503, 0.2571]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5100, 0.5000]]), gpi: tensor([[-0.2089, -0.2052, -0.1991]], grad_fn=<NegBackward0>), arm_chosen:2
# 42: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.5000, 0.4700]]), gpi: tensor([[-0.2034, -0.1773, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4000, 0.5200]]), gpi: tensor([[-0.2009, -0.1886, -0.2037]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4700, 0.4200]]), gpi: tensor([[-0.2193, -0.2002, -0.2011]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.3800, 0.3700]]), gpi: tensor([[-0.2077, -0.2006, -0.2060]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.5000, 0.3700]]), gpi: tensor([[-0.1864, -0.2055, -0.1979]], grad_fn=<NegBackward0>), arm_chosen:0
# 47: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5100, 0.5100]]), gpi: tensor([[-0.1948, -0.1949, -0.2112]], grad_fn=<NegBackward0>), arm_chosen:0
# 48: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3500, 0.4500]]), gpi: tensor([[-0.2058, -0.1955, -0.1849]], grad_fn=<NegBackward0>), arm_chosen:2
# 49: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4700]]), gpi: tensor([[-0.2003, -0.1942, -0.2008]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.3900, 0.4300]]), gpi: tensor([[-0.2215, -0.1992, -0.1783]], grad_fn=<NegBackward0>), arm_chosen:2
# 51: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4700]]), gpi: tensor([[-0.1916, -0.2057, -0.1986]], grad_fn=<NegBackward0>), arm_chosen:0
# 52: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.3900]]), gpi: tensor([[-0.1918, -0.2165, -0.1960]], grad_fn=<NegBackward0>), arm_chosen:0
# 53: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4200]]), gpi: tensor([[-0.2116, -0.2018, -0.1920]], grad_fn=<NegBackward0>), arm_chosen:2
# 54: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5600, 0.4200, 0.3900]]), gpi: tensor([[-0.2020, -0.2120, -0.1899]], grad_fn=<NegBackward0>), arm_chosen:2
# 55: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4500, 0.3900]]), gpi: tensor([[-0.1834, -0.2034, -0.1956]], grad_fn=<NegBackward0>), arm_chosen:0
# 56: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.3800, 0.4300]]), gpi: tensor([[-0.2014, -0.1980, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:2
# 57: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4400, 0.4100]]), gpi: tensor([[-0.2142, -0.2051, -0.1922]], grad_fn=<NegBackward0>), arm_chosen:2
# 58: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4500]]), gpi: tensor([[-0.2001, -0.2131, -0.2044]], grad_fn=<NegBackward0>), arm_chosen:0
# 59: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.4700, 0.4600]]), gpi: tensor([[-0.2016, -0.1910, -0.1878]], grad_fn=<NegBackward0>), arm_chosen:2
# 60: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4600, 0.4500]]), gpi: tensor([[-0.2061, -0.2039, -0.1993]], grad_fn=<NegBackward0>), arm_chosen:2
# 61: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4500, 0.4400]]), gpi: tensor([[-0.1894, -0.1981, -0.2005]], grad_fn=<NegBackward0>), arm_chosen:0
# 62: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4400, 0.4400]]), gpi: tensor([[-0.1876, -0.2121, -0.2090]], grad_fn=<NegBackward0>), arm_chosen:0
# 63: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4400, 0.4500]]), gpi: tensor([[-0.1994, -0.1839, -0.1971]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.2749, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5200, 0.4300]]), gpi: tensor([[-0.1857, -0.1752, -0.1944]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.3042, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4200, 0.4300]]), gpi: tensor([[-0.2207, -0.1337, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2500, 0.3208, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4600]]), gpi: tensor([[-0.2095, -0.1217, -0.1943]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.3321, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4100, 0.4500]]), gpi: tensor([[-0.2030, -0.1116, -0.2056]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2500, 0.3189, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4100, 0.4700]]), gpi: tensor([[-0.2004, -0.1428, -0.2015]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.2996, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4900, 0.5100]]), gpi: tensor([[-0.1992, -0.1690, -0.2067]], grad_fn=<NegBackward0>), arm_chosen:1
# 70: dp: tensor([[0.2500, 0.2878, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4200, 0.4300]]), gpi: tensor([[-0.2033, -0.1577, -0.2034]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2500, 0.2768, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5200, 0.4900]]), gpi: tensor([[-0.1942, -0.1881, -0.2014]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2500, 0.2796, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4800, 0.4800]]), gpi: tensor([[-0.2075, -0.1566, -0.1861]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2500, 0.2876, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4500]]), gpi: tensor([[-0.1966, -0.1592, -0.1905]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2500, 0.2960, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4100, 0.4400]]), gpi: tensor([[-0.2170, -0.1615, -0.2177]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2500, 0.2931, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4600]]), gpi: tensor([[-0.2114, -0.1479, -0.2027]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2500, 0.2957, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.4900]]), gpi: tensor([[-0.1861, -0.1528, -0.2021]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2500, 0.2975, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4600]]), gpi: tensor([[-0.1865, -0.1538, -0.1911]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2500, 0.3008, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5000, 0.4600]]), gpi: tensor([[-0.1862, -0.1363, -0.2068]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2500, 0.3038, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.5200, 0.4700]]), gpi: tensor([[-0.2179, -0.1460, -0.2031]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2500, 0.3118, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4600, 0.5400]]), gpi: tensor([[-0.1947, -0.1325, -0.2208]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2500, 0.3193, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4600, 0.4100]]), gpi: tensor([[-0.2246, -0.1226, -0.1911]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2500, 0.3245, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4600, 0.4500]]), gpi: tensor([[-0.2160, -0.1178, -0.2050]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2500, 0.3225, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5100, 0.4500]]), gpi: tensor([[-0.2134, -0.1261, -0.1997]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2500, 0.3153, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.3800]]), gpi: tensor([[-0.2040, -0.1155, -0.1887]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2500, 0.3067, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.5000, 0.4400]]), gpi: tensor([[-0.2145, -0.1364, -0.2069]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2500, 0.2994, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.4200]]), gpi: tensor([[-0.1978, -0.1489, -0.1990]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2500, 0.2929, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.3900]]), gpi: tensor([[-0.2004, -0.1556, -0.1980]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2500, 0.2899, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4800, 0.4600]]), gpi: tensor([[-0.2073, -0.1688, -0.2035]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2500, 0.2861, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4900, 0.4700]]), gpi: tensor([[-0.2016, -0.1685, -0.2059]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2500, 0.2859, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4000, 0.5300]]), gpi: tensor([[-0.2070, -0.1716, -0.2129]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2500, 0.2844, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4300, 0.4600]]), gpi: tensor([[-0.1872, -0.1567, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2500, 0.2746, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.3800, 0.4800]]), gpi: tensor([[-0.1914, -0.1566, -0.2090]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2500, 0.2628, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.5400, 0.4600]]), gpi: tensor([[-0.2013, -0.1897, -0.2044]], grad_fn=<NegBackward0>), arm_chosen:1
# 94: dp: tensor([[0.2500, 0.2606, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.3800]]), gpi: tensor([[-0.2161, -0.1927, -0.2042]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2500, 0.2659, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4400]]), gpi: tensor([[-0.1792, -0.1865, -0.1873]], grad_fn=<NegBackward0>), arm_chosen:0
# 96: dp: tensor([[0.2500, 0.2707, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3900, 0.4100]]), gpi: tensor([[-0.1952, -0.1742, -0.1887]], grad_fn=<NegBackward0>), arm_chosen:1
# 97: dp: tensor([[0.2500, 0.2773, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.5200, 0.4100]]), gpi: tensor([[-0.2017, -0.1909, -0.1921]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2500, 0.2959, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5900, 0.4100, 0.4700]]), gpi: tensor([[-0.1926, -0.1491, -0.1941]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2500, 0.3054, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.5200, 0.4600]]), gpi: tensor([[-0.2186, -0.1374, -0.1893]], grad_fn=<NegBackward0>), arm_chosen:1
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4300, 0.4900]]), gpi: tensor([[-0.1969, -0.2012, -0.2002]], grad_fn=<NegBackward0>), arm_chosen:0
# 1: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3300, 0.4700]]), gpi: tensor([[-0.1946, -0.1975, -0.1990]], grad_fn=<NegBackward0>), arm_chosen:0
# 2: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.5100, 0.4900]]), gpi: tensor([[-0.1713, -0.1975, -0.2043]], grad_fn=<NegBackward0>), arm_chosen:0
# 3: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4800, 0.5400]]), gpi: tensor([[-0.2000, -0.2085, -0.2057]], grad_fn=<NegBackward0>), arm_chosen:0
# 4: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3900, 0.4400]]), gpi: tensor([[-0.2200, -0.1993, -0.2032]], grad_fn=<NegBackward0>), arm_chosen:1
# 5: dp: tensor([[0.2500, 0.2680, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.3700]]), gpi: tensor([[-0.1985, -0.1801, -0.1868]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2500, 0.2925, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3900, 0.5500]]), gpi: tensor([[-0.2117, -0.1320, -0.2158]], grad_fn=<NegBackward0>), arm_chosen:1
# 7: dp: tensor([[0.2500, 0.3225, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4300, 0.3800]]), gpi: tensor([[-0.1991, -0.1153, -0.1804]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.3552, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4800, 0.3700]]), gpi: tensor([[-0.1942, -0.1109, -0.1886]], grad_fn=<NegBackward0>), arm_chosen:1
# 9: dp: tensor([[0.2500, 0.3860, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4600]]), gpi: tensor([[-0.2071, -0.0562, -0.2015]], grad_fn=<NegBackward0>), arm_chosen:1
# 10: dp: tensor([[0.2500, 0.4127, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4400]]), gpi: tensor([[-0.2053, -0.0481, -0.1990]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.4316, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4200, 0.4300]]), gpi: tensor([[-0.2154, -0.0225, -0.2169]], grad_fn=<NegBackward0>), arm_chosen:1
# 12: dp: tensor([[0.2500, 0.4434, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.4800, 0.5700]]), gpi: tensor([[-0.1992, -0.0046, -0.2182]], grad_fn=<NegBackward0>), arm_chosen:1
# 13: dp: tensor([[0.2500, 0.4518, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.5400, 0.4600]]), gpi: tensor([[-0.1935, -0.0058, -0.1895]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.4574, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.4500, 0.5000]]), gpi: tensor([[-0.2051,  0.0075, -0.1919]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.4611, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.3900]]), gpi: tensor([[-0.2078,  0.0112, -0.1927]], grad_fn=<NegBackward0>), arm_chosen:1
# 16: dp: tensor([[0.2500, 0.4633, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5200, 0.4400]]), gpi: tensor([[-0.2027,  0.0032, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.4643, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4900, 0.4100]]), gpi: tensor([[-0.2067,  0.0125, -0.1931]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.4644, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.5000]]), gpi: tensor([[-0.1859,  0.0247, -0.2078]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.4639, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3900, 0.4200]]), gpi: tensor([[-0.1991,  0.0260, -0.1971]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.4627, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4900, 0.4100]]), gpi: tensor([[-0.2067,  0.0109, -0.1931]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.4605, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4000]]), gpi: tensor([[-0.2042,  0.0140, -0.1884]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.4570, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4900, 0.4300]]), gpi: tensor([[-0.2149,  0.0014, -0.1871]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.4518, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.4600]]), gpi: tensor([[-0.2129, -0.0044, -0.2090]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.4445, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4300, 0.5000]]), gpi: tensor([[-0.2128, -0.0045, -0.1850]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.4356, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4900]]), gpi: tensor([[-0.2085, -0.0122, -0.2084]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.4240, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5100, 0.4400]]), gpi: tensor([[-0.2100, -0.0337, -0.1913]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.4107, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.5000, 0.4100]]), gpi: tensor([[-0.1845, -0.0333, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.3977, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4600]]), gpi: tensor([[-0.1914, -0.0554, -0.2011]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.3838, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4900, 0.4100]]), gpi: tensor([[-0.1947, -0.0728, -0.1961]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.3773, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4100]]), gpi: tensor([[-0.1992, -0.0729, -0.1986]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.3714, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4100, 0.4800]]), gpi: tensor([[-0.2136, -0.0747, -0.1972]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.3675, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.4700]]), gpi: tensor([[-0.1865, -0.0800, -0.1883]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.3644, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.5400]]), gpi: tensor([[-0.1952, -0.0842, -0.2083]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.3632, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4700]]), gpi: tensor([[-0.2064, -0.0632, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.3630, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4100, 0.4700]]), gpi: tensor([[-0.2120, -0.0705, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.3671, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4100, 0.4900]]), gpi: tensor([[-0.1984, -0.0724, -0.2005]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.3736, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4800, 0.4300]]), gpi: tensor([[-0.1971, -0.0960, -0.2017]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3794, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4600]]), gpi: tensor([[-0.1903, -0.0743, -0.2186]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.3874, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.5300]]), gpi: tensor([[-0.2111, -0.0525, -0.2019]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.3976, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4800, 0.4700]]), gpi: tensor([[-0.2076, -0.0391, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.4066, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4100, 0.3700]]), gpi: tensor([[-0.1986, -0.0438, -0.1852]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4159, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4100, 0.4300]]), gpi: tensor([[-0.1871, -0.0409, -0.1997]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4232, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.5100]]), gpi: tensor([[-0.1918, -0.0288, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4281, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5400, 0.5500]]), gpi: tensor([[-0.2008, -0.0347, -0.2136]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4293, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4900, 0.3600]]), gpi: tensor([[-0.2122, -0.0299, -0.1845]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4303, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.5300, 0.5200]]), gpi: tensor([[-0.1914, -0.0182, -0.2196]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4289, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4300, 0.5600]]), gpi: tensor([[-0.1966, -0.0286, -0.2114]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4279, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.3900, 0.4700]]), gpi: tensor([[-0.1944, -0.0155, -0.2067]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.4254, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.3900, 0.4400]]), gpi: tensor([[-0.1797,  0.0067, -0.1828]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.4225, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4500]]), gpi: tensor([[-0.1966, -0.0250, -0.1901]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.4142, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4600, 0.4600]]), gpi: tensor([[-0.2020, -0.0449, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.4004, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4100]]), gpi: tensor([[-0.1935, -0.0468, -0.1849]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3805, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.4800, 0.4900]]), gpi: tensor([[-0.2056, -0.0684, -0.2019]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3549, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4900, 0.4300]]), gpi: tensor([[-0.2149, -0.1002, -0.1872]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3282, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4400, 0.4100]]), gpi: tensor([[-0.2008, -0.1061, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.3044, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.5100, 0.4400]]), gpi: tensor([[-0.2047, -0.1540, -0.2064]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.2965, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4500]]), gpi: tensor([[-0.2075, -0.1430, -0.2076]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.2886, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.4300]]), gpi: tensor([[-0.2059, -0.1557, -0.2060]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.2813, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.5000]]), gpi: tensor([[-0.2006, -0.1692, -0.2219]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.2764, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4800, 0.4400]]), gpi: tensor([[-0.2163, -0.1662, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2500, 0.2721, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.5000, 0.4700]]), gpi: tensor([[-0.1899, -0.1767, -0.2001]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2500, 0.2690, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4600, 0.5000]]), gpi: tensor([[-0.2071, -0.1909, -0.2008]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2500, 0.2681, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4800]]), gpi: tensor([[-0.2011, -0.1827, -0.2119]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.2683, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.5400]]), gpi: tensor([[-0.2152, -0.1794, -0.1984]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.2696, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4300, 0.4600]]), gpi: tensor([[-0.1982, -0.1772, -0.1892]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2500, 0.2704, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4100, 0.5100]]), gpi: tensor([[-0.1968, -0.1745, -0.2027]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.2743, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5000, 0.4300]]), gpi: tensor([[-0.1969, -0.1960, -0.2022]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2500, 0.2817, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4000, 0.5000]]), gpi: tensor([[-0.2005, -0.1613, -0.1933]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.2881, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.5100, 0.4000]]), gpi: tensor([[-0.2078, -0.1872, -0.1785]], grad_fn=<NegBackward0>), arm_chosen:2
# 70: dp: tensor([[0.2500, 0.2938, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.3800, 0.4900]]), gpi: tensor([[-0.2102, -0.1535, -0.2189]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2500, 0.2972, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.3900, 0.4000]]), gpi: tensor([[-0.1962, -0.1368, -0.1997]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2500, 0.2995, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4100, 0.4200]]), gpi: tensor([[-0.2069, -0.1483, -0.1915]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2500, 0.3007, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4600]]), gpi: tensor([[-0.2009, -0.1520, -0.1873]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2500, 0.3021, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.4700]]), gpi: tensor([[-0.2026, -0.1473, -0.1959]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2500, 0.3055, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4400]]), gpi: tensor([[-0.2016, -0.1474, -0.1959]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2500, 0.3086, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4100]]), gpi: tensor([[-0.1985, -0.1314, -0.1891]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2500, 0.3099, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4500, 0.4800]]), gpi: tensor([[-0.2084, -0.1505, -0.2009]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2500, 0.3095, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4400]]), gpi: tensor([[-0.1826, -0.1503, -0.1896]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2500, 0.3078, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3100, 0.4600]]), gpi: tensor([[-0.1962, -0.1032, -0.2211]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2500, 0.3071, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3900, 0.5200]]), gpi: tensor([[-0.1836, -0.1288, -0.2069]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2500, 0.3044, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4900, 0.5000]]), gpi: tensor([[-0.1994, -0.1425, -0.2069]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2500, 0.3026, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4200, 0.4200]]), gpi: tensor([[-0.1958, -0.1550, -0.1857]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2500, 0.3009, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4300, 0.4200]]), gpi: tensor([[-0.1993, -0.1309, -0.2107]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2500, 0.2976, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4200, 0.4200]]), gpi: tensor([[-0.1889, -0.1657, -0.2016]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2500, 0.2943, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.3900]]), gpi: tensor([[-0.2007, -0.1619, -0.1892]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2500, 0.2919, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4300, 0.4800]]), gpi: tensor([[-0.2253, -0.1568, -0.1850]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2500, 0.2897, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4100, 0.4600]]), gpi: tensor([[-0.1966, -0.1510, -0.2053]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2500, 0.2882, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.5100]]), gpi: tensor([[-0.1955, -0.1717, -0.2096]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2500, 0.2866, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4200, 0.5100]]), gpi: tensor([[-0.2030, -0.1564, -0.2152]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2500, 0.2862, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.3900, 0.4300]]), gpi: tensor([[-0.1944, -0.1712, -0.1922]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2500, 0.2857, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4500, 0.4100]]), gpi: tensor([[-0.1947, -0.1681, -0.1977]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2500, 0.2869, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3900, 0.4600]]), gpi: tensor([[-0.1832, -0.1593, -0.1891]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2500, 0.2896, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.3700, 0.4800]]), gpi: tensor([[-0.1846, -0.1655, -0.2147]], grad_fn=<NegBackward0>), arm_chosen:1
# 94: dp: tensor([[0.2500, 0.2927, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4300, 0.4600]]), gpi: tensor([[-0.1958, -0.1525, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2500, 0.2979, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.3700, 0.3900]]), gpi: tensor([[-0.2008, -0.1354, -0.2046]], grad_fn=<NegBackward0>), arm_chosen:1
# 96: dp: tensor([[0.2500, 0.3036, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.5400, 0.4200]]), gpi: tensor([[-0.2158, -0.1533, -0.2004]], grad_fn=<NegBackward0>), arm_chosen:1
# 97: dp: tensor([[0.2500, 0.3079, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.3400]]), gpi: tensor([[-0.1896, -0.1552, -0.1765]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2500, 0.3133, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4700]]), gpi: tensor([[-0.1983, -0.1348, -0.2038]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2500, 0.3135, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4000, 0.4900]]), gpi: tensor([[-0.2187, -0.1406, -0.2136]], grad_fn=<NegBackward0>), arm_chosen:1
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.3800]]), gpi: tensor([[-0.1998, -0.1986, -0.1891]], grad_fn=<NegBackward0>), arm_chosen:2
# 1: dp: tensor([[0.2503, 0.2503, 0.2850]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4200, 0.4400]]), gpi: tensor([[-0.2181, -0.1872, -0.1595]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2503, 0.2503, 0.2630]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5100, 0.4200]]), gpi: tensor([[-0.1765, -0.2081, -0.2009]], grad_fn=<NegBackward0>), arm_chosen:0
# 3: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5400, 0.4900]]), gpi: tensor([[-0.1991, -0.1963, -0.2067]], grad_fn=<NegBackward0>), arm_chosen:1
# 4: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4300, 0.4600]]), gpi: tensor([[-0.2001, -0.1965, -0.1756]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4900, 0.5100]]), gpi: tensor([[-0.2047, -0.1920, -0.2089]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.3900]]), gpi: tensor([[-0.2023, -0.2254, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:2
# 7: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4200]]), gpi: tensor([[-0.1972, -0.1864, -0.1909]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3600, 0.4500]]), gpi: tensor([[-0.2069, -0.1886, -0.1945]], grad_fn=<NegBackward0>), arm_chosen:1
# 9: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.3900, 0.4000]]), gpi: tensor([[-0.1976, -0.1839, -0.1819]], grad_fn=<NegBackward0>), arm_chosen:2
# 10: dp: tensor([[0.2500, 0.2503, 0.2537]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.3900]]), gpi: tensor([[-0.2028, -0.1804, -0.1925]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.2503, 0.2570]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.5100]]), gpi: tensor([[-0.2085, -0.1866, -0.1982]], grad_fn=<NegBackward0>), arm_chosen:1
# 12: dp: tensor([[0.2500, 0.2503, 0.2600]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4800, 0.4500]]), gpi: tensor([[-0.1963, -0.2013, -0.1916]], grad_fn=<NegBackward0>), arm_chosen:2
# 13: dp: tensor([[0.2500, 0.2503, 0.2644]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.5700, 0.4200]]), gpi: tensor([[-0.2106, -0.2121, -0.1895]], grad_fn=<NegBackward0>), arm_chosen:2
# 14: dp: tensor([[0.2500, 0.2503, 0.2630]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3800, 0.4500]]), gpi: tensor([[-0.2092, -0.2015, -0.1937]], grad_fn=<NegBackward0>), arm_chosen:2
# 15: dp: tensor([[0.2500, 0.2503, 0.2662]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4300]]), gpi: tensor([[-0.2110, -0.1988, -0.1827]], grad_fn=<NegBackward0>), arm_chosen:2
# 16: dp: tensor([[0.2500, 0.2503, 0.2646]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4500]]), gpi: tensor([[-0.1966, -0.2183, -0.1851]], grad_fn=<NegBackward0>), arm_chosen:2
# 17: dp: tensor([[0.2500, 0.2503, 0.2583]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4400]]), gpi: tensor([[-0.1860, -0.2109, -0.1976]], grad_fn=<NegBackward0>), arm_chosen:0
# 18: dp: tensor([[0.2500, 0.2503, 0.2526]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4600]]), gpi: tensor([[-0.1986, -0.1885, -0.1942]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.2503, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4300, 0.5200]]), gpi: tensor([[-0.1889, -0.1837, -0.2029]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.4600]]), gpi: tensor([[-0.2081, -0.2043, -0.2170]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.5300]]), gpi: tensor([[-0.2039, -0.2039, -0.1987]], grad_fn=<NegBackward0>), arm_chosen:2
# 22: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4600, 0.3600]]), gpi: tensor([[-0.2008, -0.1842, -0.1923]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4800]]), gpi: tensor([[-0.1940, -0.2045, -0.1888]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.5000, 0.4100]]), gpi: tensor([[-0.1873, -0.1894, -0.1909]], grad_fn=<NegBackward0>), arm_chosen:0
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4600, 0.4300]]), gpi: tensor([[-0.1921, -0.2160, -0.1948]], grad_fn=<NegBackward0>), arm_chosen:0
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4100]]), gpi: tensor([[-0.1978, -0.1998, -0.1879]], grad_fn=<NegBackward0>), arm_chosen:2
# 27: dp: tensor([[0.2500, 0.2503, 0.2558]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4800, 0.4600]]), gpi: tensor([[-0.1825, -0.1927, -0.1979]], grad_fn=<NegBackward0>), arm_chosen:0
# 28: dp: tensor([[0.2500, 0.2503, 0.2611]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4600, 0.4700]]), gpi: tensor([[-0.1903, -0.2108, -0.1945]], grad_fn=<NegBackward0>), arm_chosen:0
# 29: dp: tensor([[0.2500, 0.2503, 0.2659]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4500, 0.4200]]), gpi: tensor([[-0.1896, -0.1845, -0.1914]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.2503, 0.2703]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4600]]), gpi: tensor([[-0.1963, -0.1979, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:0
# 31: dp: tensor([[0.2500, 0.2503, 0.2743]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5100, 0.4100]]), gpi: tensor([[-0.1845, -0.2086, -0.1660]], grad_fn=<NegBackward0>), arm_chosen:2
# 32: dp: tensor([[0.2500, 0.2503, 0.2851]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4200, 0.4400]]), gpi: tensor([[-0.1993, -0.1994, -0.1585]], grad_fn=<NegBackward0>), arm_chosen:2
# 33: dp: tensor([[0.2500, 0.2503, 0.2885]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4100]]), gpi: tensor([[-0.2035, -0.1850, -0.1515]], grad_fn=<NegBackward0>), arm_chosen:2
# 34: dp: tensor([[0.2500, 0.2503, 0.2768]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5000, 0.4300]]), gpi: tensor([[-0.2056, -0.2002, -0.1730]], grad_fn=<NegBackward0>), arm_chosen:2
# 35: dp: tensor([[0.2500, 0.2503, 0.2616]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4500, 0.4300]]), gpi: tensor([[-0.1803, -0.2143, -0.2004]], grad_fn=<NegBackward0>), arm_chosen:0
# 36: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4600]]), gpi: tensor([[-0.2029, -0.1851, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4100]]), gpi: tensor([[-0.2197, -0.1936, -0.1797]], grad_fn=<NegBackward0>), arm_chosen:2
# 38: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4100, 0.4900]]), gpi: tensor([[-0.2138, -0.1863, -0.1995]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.4800]]), gpi: tensor([[-0.1966, -0.1982, -0.1911]], grad_fn=<NegBackward0>), arm_chosen:2
# 40: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.3800, 0.4300]]), gpi: tensor([[-0.2128, -0.1883, -0.2071]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4200, 0.3600]]), gpi: tensor([[-0.2006, -0.1923, -0.1856]], grad_fn=<NegBackward0>), arm_chosen:2
# 42: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4800, 0.4700]]), gpi: tensor([[-0.2146, -0.1868, -0.2165]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4200]]), gpi: tensor([[-0.1881, -0.1931, -0.2100]], grad_fn=<NegBackward0>), arm_chosen:0
# 44: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4900, 0.4200]]), gpi: tensor([[-0.1905, -0.2089, -0.2017]], grad_fn=<NegBackward0>), arm_chosen:0
# 45: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4700]]), gpi: tensor([[-0.1967, -0.1867, -0.1927]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4800]]), gpi: tensor([[-0.1983, -0.1996, -0.2094]], grad_fn=<NegBackward0>), arm_chosen:0
# 47: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4700, 0.4700]]), gpi: tensor([[-0.2010, -0.1834, -0.1891]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.4300]]), gpi: tensor([[-0.2118, -0.1959, -0.1809]], grad_fn=<NegBackward0>), arm_chosen:2
# 49: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4600]]), gpi: tensor([[-0.1961, -0.1920, -0.1967]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4800, 0.4700]]), gpi: tensor([[-0.2061, -0.2019, -0.1923]], grad_fn=<NegBackward0>), arm_chosen:2
# 51: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4000, 0.4600]]), gpi: tensor([[-0.2042, -0.2020, -0.2126]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.2726, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.3800]]), gpi: tensor([[-0.1981, -0.1682, -0.1949]], grad_fn=<NegBackward0>), arm_chosen:1
# ...
# 16: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4700, 0.4700]]), gpi: tensor([[-0.1917, -0.2027, -0.2088]], grad_fn=<NegBackward0>), arm_chosen:0
# 17: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.3900, 0.5700]]), gpi: tensor([[-0.2053, -0.1590, -0.2092]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4100, 0.5300]]), gpi: tensor([[-0.1999, -0.1956, -0.2201]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5200, 0.4600]]), gpi: tensor([[-0.2002, -0.1980, -0.2056]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4200, 0.4200]]), gpi: tensor([[-0.1977, -0.1899, -0.1839]], grad_fn=<NegBackward0>), arm_chosen:2
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4800, 0.4700]]), gpi: tensor([[-0.2030, -0.2099, -0.1948]], grad_fn=<NegBackward0>), arm_chosen:2
# 22: dp: tensor([[0.2500, 0.2503, 0.2535]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4200]]), gpi: tensor([[-0.2096, -0.2076, -0.1927]], grad_fn=<NegBackward0>), arm_chosen:2
# 23: dp: tensor([[0.2500, 0.2503, 0.2501]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5100, 0.4100]]), gpi: tensor([[-0.2157, -0.2047, -0.1993]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.4500]]), gpi: tensor([[-0.2164, -0.1976, -0.1923]], grad_fn=<NegBackward0>), arm_chosen:2
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4500]]), gpi: tensor([[-0.1778, -0.1927, -0.2106]], grad_fn=<NegBackward0>), arm_chosen:0
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.5300, 0.5000]]), gpi: tensor([[-0.2074, -0.1977, -0.2167]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4500, 0.3800]]), gpi: tensor([[-0.1708, -0.2043, -0.1950]], grad_fn=<NegBackward0>), arm_chosen:0
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.5400, 0.4200]]), gpi: tensor([[-0.2019, -0.2010, -0.2186]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4800, 0.3500]]), gpi: tensor([[-0.1891, -0.2062, -0.1784]], grad_fn=<NegBackward0>), arm_chosen:2
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4400, 0.4500]]), gpi: tensor([[-0.1873, -0.1790, -0.1894]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.5100, 0.4500]]), gpi: tensor([[-0.2034, -0.2184, -0.1859]], grad_fn=<NegBackward0>), arm_chosen:2
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4300]]), gpi: tensor([[-0.2114, -0.2043, -0.1771]], grad_fn=<NegBackward0>), arm_chosen:2
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.4400]]), gpi: tensor([[-0.1922, -0.1944, -0.2078]], grad_fn=<NegBackward0>), arm_chosen:0
# 34: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.5100]]), gpi: tensor([[-0.1943, -0.1971, -0.2317]], grad_fn=<NegBackward0>), arm_chosen:0
# 35: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4400]]), gpi: tensor([[-0.1953, -0.2068, -0.2130]], grad_fn=<NegBackward0>), arm_chosen:0
# 36: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4900, 0.4600]]), gpi: tensor([[-0.1971, -0.2112, -0.1963]], grad_fn=<NegBackward0>), arm_chosen:2
# 37: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.5500, 0.4300]]), gpi: tensor([[-0.2187, -0.2006, -0.1933]], grad_fn=<NegBackward0>), arm_chosen:2
# 38: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4700, 0.4100]]), gpi: tensor([[-0.2082, -0.1952, -0.2098]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4100, 0.4300]]), gpi: tensor([[-0.1935, -0.1952, -0.1915]], grad_fn=<NegBackward0>), arm_chosen:2
# 40: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.3600]]), gpi: tensor([[-0.2003, -0.2030, -0.1842]], grad_fn=<NegBackward0>), arm_chosen:2
# 41: dp: tensor([[0.2500, 0.2503, 0.2533]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.4200, 0.4600]]), gpi: tensor([[-0.1956, -0.1762, -0.1843]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.2503, 0.2563]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4100, 0.3600]]), gpi: tensor([[-0.1821, -0.1880, -0.1760]], grad_fn=<NegBackward0>), arm_chosen:2
# 43: dp: tensor([[0.2500, 0.2503, 0.2584]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4900, 0.3900]]), gpi: tensor([[-0.1906, -0.2112, -0.1851]], grad_fn=<NegBackward0>), arm_chosen:2
# 44: dp: tensor([[0.2500, 0.2503, 0.2700]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.4300]]), gpi: tensor([[-0.2050, -0.1719, -0.1779]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.2504, 0.2817]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.3800]]), gpi: tensor([[-0.1861, -0.1966, -0.1667]], grad_fn=<NegBackward0>), arm_chosen:2
# 46: dp: tensor([[0.2500, 0.2503, 0.2815]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.4700, 0.4900]]), gpi: tensor([[-0.2003, -0.2004, -0.1767]], grad_fn=<NegBackward0>), arm_chosen:2
# 47: dp: tensor([[0.2500, 0.2503, 0.2741]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.3200]]), gpi: tensor([[-0.1990, -0.2070, -0.1637]], grad_fn=<NegBackward0>), arm_chosen:2
# 48: dp: tensor([[0.2500, 0.2503, 0.2627]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4100, 0.4600]]), gpi: tensor([[-0.1904, -0.1936, -0.1896]], grad_fn=<NegBackward0>), arm_chosen:2
# 49: dp: tensor([[0.2500, 0.2503, 0.2501]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4000, 0.5100]]), gpi: tensor([[-0.2120, -0.1869, -0.2108]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4600, 0.4200]]), gpi: tensor([[-0.2041, -0.2026, -0.1900]], grad_fn=<NegBackward0>), arm_chosen:2
# 51: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.5100, 0.4100]]), gpi: tensor([[-0.1879, -0.2050, -0.1991]], grad_fn=<NegBackward0>), arm_chosen:0
# 52: dp: tensor([[0.2514, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.4500]]), gpi: tensor([[-0.2057, -0.2011, -0.1965]], grad_fn=<NegBackward0>), arm_chosen:2
# 53: dp: tensor([[0.2527, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4600]]), gpi: tensor([[-0.1897, -0.1833, -0.2043]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2539, 0.2730, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4200, 0.4900]]), gpi: tensor([[-0.1907, -0.1771, -0.1960]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2550, 0.3032, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.3900, 0.3900]]), gpi: tensor([[-0.1856, -0.1339, -0.1827]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2560, 0.3308, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4200, 0.4400]]), gpi: tensor([[-0.2096, -0.1140, -0.1935]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2569, 0.3410, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.5000]]), gpi: tensor([[-0.1881, -0.1046, -0.2064]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2577, 0.3404, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5100, 0.4400]]), gpi: tensor([[-0.1796, -0.1217, -0.2038]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2584, 0.3321, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.5000, 0.4600]]), gpi: tensor([[-0.1854, -0.1329, -0.2036]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2591, 0.3203, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4700]]), gpi: tensor([[-0.1881, -0.1278, -0.2025]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2597, 0.3057, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4900, 0.4000]]), gpi: tensor([[-0.1788, -0.1497, -0.2082]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2602, 0.2878, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4300, 0.4200]]), gpi: tensor([[-0.1933, -0.1460, -0.1889]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2607, 0.2773, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4600, 0.4700]]), gpi: tensor([[-0.2056, -0.1723, -0.1939]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2612, 0.2765, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4600]]), gpi: tensor([[-0.1918, -0.1590, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2616, 0.2731, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4100, 0.5100]]), gpi: tensor([[-0.1845, -0.1647, -0.1917]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2619, 0.2740, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4900, 0.4900]]), gpi: tensor([[-0.1703, -0.1814, -0.2049]], grad_fn=<NegBackward0>), arm_chosen:0
# 67: dp: tensor([[0.2619, 0.2747, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4700]]), gpi: tensor([[-0.1905, -0.1813, -0.2131]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2618, 0.2831, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4000, 0.4200]]), gpi: tensor([[-0.1933, -0.1645, -0.1752]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2617, 0.2971, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4800, 0.5000]]), gpi: tensor([[-0.1735, -0.1566, -0.2117]], grad_fn=<NegBackward0>), arm_chosen:1
# 70: dp: tensor([[0.2618, 0.3190, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4900, 0.4100]]), gpi: tensor([[-0.1704, -0.1357, -0.2046]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2616, 0.3270, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4300, 0.4300]]), gpi: tensor([[-0.2026, -0.1295, -0.2007]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2616, 0.3281, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4100, 0.4100]]), gpi: tensor([[-0.1902, -0.1371, -0.1940]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2615, 0.3286, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4400]]), gpi: tensor([[-0.1947, -0.1293, -0.1941]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2615, 0.3231, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.5100, 0.4400]]), gpi: tensor([[-0.1882, -0.1469, -0.1997]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2615, 0.3090, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4300, 0.6000]]), gpi: tensor([[-0.2054, -0.1407, -0.2070]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2614, 0.2965, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4700]]), gpi: tensor([[-0.1917, -0.1453, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2614, 0.2873, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.3700]]), gpi: tensor([[-0.1811, -0.1692, -0.1995]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2614, 0.2828, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3900, 0.5000]]), gpi: tensor([[-0.1843, -0.1453, -0.2096]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2613, 0.2815, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.5300, 0.4000]]), gpi: tensor([[-0.1934, -0.1865, -0.2047]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2613, 0.2817, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.3600, 0.4700]]), gpi: tensor([[-0.1755, -0.1527, -0.2008]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2613, 0.2894, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4100, 0.4300]]), gpi: tensor([[-0.1792, -0.1625, -0.2037]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2613, 0.2972, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3500, 0.4500]]), gpi: tensor([[-0.1613, -0.1350, -0.1948]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2613, 0.3087, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4000, 0.5200]]), gpi: tensor([[-0.1728, -0.1466, -0.2047]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2613, 0.3134, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.3900]]), gpi: tensor([[-0.1972, -0.1207, -0.1968]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2612, 0.3161, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.3800, 0.4800]]), gpi: tensor([[-0.2056, -0.1470, -0.2120]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2612, 0.3152, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4700]]), gpi: tensor([[-0.2030, -0.1277, -0.1874]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2612, 0.3110, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5000, 0.4900]]), gpi: tensor([[-0.1927, -0.1321, -0.1993]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2612, 0.3046, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4100, 0.3700]]), gpi: tensor([[-0.2017, -0.1458, -0.1963]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2612, 0.2958, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.4300]]), gpi: tensor([[-0.1903, -0.1593, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2612, 0.2876, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4400]]), gpi: tensor([[-0.1860, -0.1734, -0.2036]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2612, 0.2812, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4500, 0.4500]]), gpi: tensor([[-0.1600, -0.1397, -0.1928]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2612, 0.2718, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5000, 0.4300]]), gpi: tensor([[-0.1708, -0.1689, -0.1793]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2612, 0.2718, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4800, 0.4000]]), gpi: tensor([[-0.1808, -0.1858, -0.1805]], grad_fn=<NegBackward0>), arm_chosen:2
# 94: dp: tensor([[0.2612, 0.2719, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5200, 0.5400]]), gpi: tensor([[-0.1753, -0.1721, -0.2165]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2612, 0.2813, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5200, 0.4300]]), gpi: tensor([[-0.1948, -0.1791, -0.2095]], grad_fn=<NegBackward0>), arm_chosen:1
# 96: dp: tensor([[0.2612, 0.2904, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.4000, 0.4200]]), gpi: tensor([[-0.1511, -0.1545, -0.1927]], grad_fn=<NegBackward0>), arm_chosen:0
# 97: dp: tensor([[0.2629, 0.2985, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.3800, 0.4200]]), gpi: tensor([[-0.1966, -0.1319, -0.1834]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2645, 0.3060, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4800, 0.4800]]), gpi: tensor([[-0.1764, -0.1504, -0.1852]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2660, 0.3097, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4000]]), gpi: tensor([[-0.1931, -0.1421, -0.1981]], grad_fn=<NegBackward0>), arm_chosen:1

# %% [markdown]
# ## Analysis

# %%
mean_picks = {key: torch.mean(avg_counts[key], dim = 0) for key in list(avg_counts.keys())}
IP_avg = {key: torch.mean(ip_monitor[key], dim =0).detach().numpy() for key in list(ip_monitor.keys())}
DP_avg = {key: torch.mean(dp_monitor[key], dim =0).detach().numpy() for key in list(dp_monitor.keys())}
IP_var = np.std(np.stack(list(IP_avg.values()), axis=0),axis = 0)[:,0]
arm_chosen_monitor = arm_chosen_monitor.to(torch.int)

# Computing Accuracy
optimal_probs_per_bin_all = torch.zeros((EPOCHS, BINS))

for i in range(BINS):
    start, end = i * BIN_SIZE, (i + 1) * BIN_SIZE
    correct_choices = torch.sum(arm_chosen_monitor[:, start:end] == BEST_ARM[:,start:end], axis = 1)
    optimal_probs_per_bin_all[:, i] = (correct_choices / BIN_SIZE)

optimal_prob_per_bin = torch.mean(optimal_probs_per_bin_all,axis = 0)
last_bin_prob = optimal_prob_per_bin[-1].item()
mean_prob = torch.mean(optimal_prob_per_bin).item()
mean_reward = torch.mean(reward_monitor, axis = 0)

# %%
BIN = np.arange(BINS)+1


plt.figure(figsize=(5,3))
plt.subplot(231)
for i in DP_avg.keys():
    plt.plot(np.arange(TRIALS), DP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('DP output')
plt.legend(loc = 'upper right')

plt.subplot(232)

for i in mean_picks.keys():
    plt.plot(BIN,mean_picks[i], label = i, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Avg card picks with trials')
plt.xlabel('bins')
plt.legend(loc = 'upper right')

plt.subplot(233)
plt.plot(BIN, optimal_prob_per_bin, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Accuracy')
plt.ylim(0,1.1)
plt.xlabel('bins')

plt.subplot(234)
for i in IP_avg.keys():
    plt.plot(np.arange(TRIALS), IP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('IP output')
plt.legend(loc = 'upper right')

plt.subplot(235)
plt.plot(np.arange(TRIALS), mean_reward)
# show std as shaded region around
plt.fill_between(np.arange(TRIALS), mean_reward - torch.std(reward_monitor, axis = 0), mean_reward + torch.std(reward_monitor, axis = 0), alpha=0.2)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('Mean reward')
plt.legend(loc = 'upper right')


print('Accuracy at last bin: ',optimal_prob_per_bin[-1].item())
print('Avg accuracy across bins: ',torch.mean(optimal_prob_per_bin).item())
# Out:
# Accuracy at last bin:  0.03100000135600567
# Avg accuracy across bins:  0.3542000353336334

# %%
random_epochs = np.random.choice(np.arange(EPOCHS), size = 2)
i = 1
plt.figure(figsize=(3,1))
for e in random_epochs:
    plt.subplot(1,2,i)
    colors = np.where(np.isin(arm_chosen_monitor[e],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRIALS), arm_chosen_monitor[e], marker = '|', s = 20)
    plt.ylim(-1,4)
    plt.xlabel('TRIALS')
    plt.title(f'Epoch {e}', fontsize = 4)
    i+=1
# plt.suptitle('Card picks in each epoch')
plt.tight_layout()

# %%
# data = {'DP_AVG': DP_avg,
#         'IP_AVG': IP_avg,
#         'AVG_CARD_PICKS_PER_BIN': mean_picks,
#         'ARM_CHOSEN_MONITOR': arm_chosen_monitor,
#         'REWARD_MONITOR': reward_monitor,
#         'OPTIMAL_PROBS_PER_BIN': optimal_prob_per_bin,
#         'LAST_BIN_PROBS': last_bin_prob,
#         'MEAN_PROB': mean_prob,
#         'MEAN_REWARD': mean_reward 
#         }

# # saving data as pkl file 
# with open('non_stationary_bandits_v2_PD_1.pkl', 'wb') as f:
#     pickle.dump(data, f)
