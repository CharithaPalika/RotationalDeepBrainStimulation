# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
import os, sys
import torch
from matplotlib.lines import Line2D
from tqdm.autonotebook import tqdm
from matplotlib.colors import LinearSegmentedColormap
# Root project
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to sys.path:", project_root)

from envs import *
from basal_ganglia import *
from stn_gpe import *

# filter warnings
import warnings
warnings.filterwarnings("ignore")



plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman"],  # Times for publication
    "font.size": 8,                    # Base font size
    "axes.labelsize": 8,              # Axis label font size
    "axes.labelweight": "bold",
    "font.weight": "bold",   
    "axes.titlesize":8,              # Axis title (not fig title)
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize":8,              # Legend font size

    "figure.dpi": 300,                 # Display resolution
    "savefig.dpi": 300,                # Save resolution
    "figure.constrained_layout.use": True,  # Better spacing than tight_layout

    "axes.linewidth": 0.8,             # Thin but clear axes lines
    "lines.linewidth": 1.2,
    "lines.markersize": 5,

    "axes.spines.top": False,
    "axes.spines.right": False,

    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.major.size": 4,
    "ytick.major.size": 4,
    "xtick.minor.size": 2,
    "ytick.minor.size": 2,

    "legend.frameon": False,
    "legend.handlelength": 2.0,        # Slightly longer legend lines
    "legend.handletextpad": 0.5,

    "pdf.fonttype": 42,                # Embed editable fonts in PDF
    "ps.fonttype": 42
})
# Out:
# Project root added to sys.path: /Users/charithapalika/Desktop/Lab projects/Decision Making/Light_House_DBS/light_house_DBS_decision_making

# %%
yaml_path = os.path.join(project_root, 'params', 'decision_making_task_params', 'non_stationary_bandits', 'params.yaml')
params = load_yaml(yaml_path)
STN_DATA_path = os.path.join(project_root, 'params', 'stn_gpe_params', 'params_Normal.yaml')

# %%
TRIALS = params['TRIALS']
EPOCHS = params['EPOCHS']
BINS = params['NUM_BINS']
LR = params['LR'] 
NUM_ARMS =params['NUM_ARMS']
SCALING_FACTOR = params['SCALING_FACTOR']   
TIME_STAMP_CHANGE = params['TIME_STAMP_CHANGE']
BIN_SIZE = TRIALS//BINS
BIN_CHANGE = TIME_STAMP_CHANGE // BIN_SIZE

# %%
env = NonStationaryEnv(
    num_arms = NUM_ARMS, 
    mean_reward = np.array([20, 40, 25])/SCALING_FACTOR, #np.array([5,40,10])/SCALING_FACTOR, (20,40,10)
    std = np.array([2,2,2])/SCALING_FACTOR, 
    mean_rew_change = np.array([25, 35, 50])/SCALING_FACTOR, #np.array([10,20,60])/SCALING_FACTOR, (10,20,60)
    std_change = np.array([2,2,2])/SCALING_FACTOR, 
    time_stamp_change = TIME_STAMP_CHANGE)

BEST_ARM_BEFORE = 1
BEST_ARM_AFTER = 2

BEST_ARM = torch.zeros((EPOCHS,TRIALS), dtype=int)
BEST_ARM[:,:TIME_STAMP_CHANGE] = BEST_ARM_BEFORE
BEST_ARM[:,TIME_STAMP_CHANGE:] = BEST_ARM_AFTER

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor,ep_monitor, _= train(env, 
                                                      trails = TRIALS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = BINS,
                                                      STN_data = STN_DATA_path, #'rossler',
                                                      d1_amp=0.5, #0.5,
                                                      d2_amp=0.45, #0.0029, 
                                                      gpi_threshold=0.1,
                                                      max_gpi_iters=50,
                                                      del_lim=1, train_IP = False, 
                                                      del_med = None, printing = True,
                                                      gpi_mean= 1, ep_0 = 0.3,
                                                      alpha_ep = 0.0,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.0)
# Out:
# Running STN-GPe system
#   0%|          | 0/50000 [00:00<?, ?it/s]
# StdDev of STN: 0.3184151650567501, Mean of STN: 1.0
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.5700, 0.4200]]), gpi: tensor([[-0.1486, -0.1829, -0.1676]], grad_fn=<NegBackward0>), arm_chosen:0
# 1: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.2800, 0.1700]]), gpi: tensor([[-0.1835, -0.2029, -0.1448]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5100, 0.5900]]), gpi: tensor([[-0.1870, -0.2009, -0.1812]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.5100, 0.4100]]), gpi: tensor([[-0.1701, -0.2060, -0.2630]], grad_fn=<NegBackward0>), arm_chosen:0
# 4: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4700, 0.3200]]), gpi: tensor([[-0.2079, -0.2685, -0.2044]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.6400, 0.3600]]), gpi: tensor([[-0.2415, -0.2174, -0.2289]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2500, 0.2673, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.1900, 0.6200]]), gpi: tensor([[-0.1461, -0.1811, -0.2928]], grad_fn=<NegBackward0>), arm_chosen:0
# 7: dp: tensor([[0.2500, 0.2830, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.8000, 0.5200]]), gpi: tensor([[-0.2034, -0.1802, -0.2334]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.3059, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.3600, 0.4700]]), gpi: tensor([[-0.1366, -0.1719, -0.1735]], grad_fn=<NegBackward0>), arm_chosen:0
# 9: dp: tensor([[0.2500, 0.3269, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.4100, 0.7000]]), gpi: tensor([[-0.2345, -0.0900, -0.2088]], grad_fn=<NegBackward0>), arm_chosen:1
# 10: dp: tensor([[0.2500, 0.3529, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.4400, 0.4600]]), gpi: tensor([[-0.1102, -0.0958, -0.2138]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.3791, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6200, 0.4500, 0.5100]]), gpi: tensor([[-0.1759, -0.0343, -0.1863]], grad_fn=<NegBackward0>), arm_chosen:1
# 12: dp: tensor([[0.2500, 0.4026, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5600, 0.5500, 0.6400]]), gpi: tensor([[-0.1865, -0.0688, -0.2736]], grad_fn=<NegBackward0>), arm_chosen:1
# 13: dp: tensor([[0.2500, 0.4195, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.3800, 0.5400]]), gpi: tensor([[-0.1862, -0.0470, -0.1747]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.4335, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5700, 0.5800]]), gpi: tensor([[-0.2172, -0.0625, -0.2117]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.4417, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7300, 0.6200, 0.5700]]), gpi: tensor([[-0.2465, -0.0098, -0.1798]], grad_fn=<NegBackward0>), arm_chosen:1
# 16: dp: tensor([[0.2500, 0.4473, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4100, 0.3100]]), gpi: tensor([[-0.2173,  0.0279, -0.1670]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.4509, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4700]]), gpi: tensor([[-0.1958,  0.0188, -0.2014]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.4527, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5100, 0.6500]]), gpi: tensor([[-0.1703, -0.0096, -0.2468]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.4537, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.5000, 0.2400]]), gpi: tensor([[-0.2174,  0.0033, -0.2068]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.4539, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.3500, 0.3800]]), gpi: tensor([[-0.2157, -0.0172, -0.1902]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.4521, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1700, 0.7900, 0.5500]]), gpi: tensor([[-0.1496,  0.0161, -0.2744]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.4488, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.3000, 0.4900]]), gpi: tensor([[-0.1781,  0.0320, -0.1975]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.4453, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.6200, 0.2500]]), gpi: tensor([[-0.2162,  0.0266, -0.1658]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.4401, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.3800, 0.6000]]), gpi: tensor([[-0.1899, -0.0185, -0.1862]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.4330, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.2400, 0.3400]]), gpi: tensor([[-0.2071, -0.0231, -0.1683]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.4246, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.5800, 0.2900]]), gpi: tensor([[-0.2006, -0.0129, -0.1334]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.4146, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.2900]]), gpi: tensor([[-0.1640, -0.0043, -0.1338]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.4025, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1500, 0.6600, 0.5500]]), gpi: tensor([[-0.1959, -0.0568, -0.1757]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.3928, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6800, 0.3100, 0.5800]]), gpi: tensor([[-0.2028, -0.0681, -0.2347]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.3855, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7100, 0.6500, 0.5400]]), gpi: tensor([[-0.2072, -0.0506, -0.3197]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.3783, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.5000, 0.5600]]), gpi: tensor([[-0.2176, -0.1189, -0.1725]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.3741, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.2400, 0.5500]]), gpi: tensor([[-0.2177, -0.0678, -0.1830]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.3715, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7700, 0.2700, 0.3900]]), gpi: tensor([[-0.2486, -0.0847, -0.2344]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.3708, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4300, 0.4900]]), gpi: tensor([[-0.2342, -0.0788, -0.1870]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.3703, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.5300, 0.5700]]), gpi: tensor([[-0.1806, -0.1116, -0.1508]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.3735, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.2200, 0.5100]]), gpi: tensor([[-0.2307, -0.0831, -0.2147]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.3783, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.1100, 0.3600]]), gpi: tensor([[-0.1940, -0.0268, -0.1284]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3852, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5300, 0.0400]]), gpi: tensor([[-0.2021, -0.0506, -0.1362]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.3940, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.5500, 0.4700]]), gpi: tensor([[-0.2227, -0.0865, -0.2132]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.4041, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4100, 0.6100]]), gpi: tensor([[-0.2093, -0.0053, -0.2256]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.4150, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1900, 0.5200, 0.4900]]), gpi: tensor([[-0.1798, -0.0523, -0.1947]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4253, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5200, 0.5100]]), gpi: tensor([[-0.2327, -0.0876, -0.1818]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4310, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.6200, 0.4500]]), gpi: tensor([[-0.1765, -0.0503, -0.2034]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4344, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5400, 0.4200]]), gpi: tensor([[-0.1989, -0.0091, -0.1537]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4365, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.4700, 0.5100]]), gpi: tensor([[-0.2174, -0.0412, -0.2592]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4370, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.5000, 0.4500]]), gpi: tensor([[-0.2312, -0.0372, -0.2109]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4351, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6900, 0.6100, 0.3900]]), gpi: tensor([[-0.2672, -0.0390, -0.2375]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4315, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.6100, 0.4300]]), gpi: tensor([[-0.2161, -0.0348, -0.1975]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.4271, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4200, 0.4800]]), gpi: tensor([[-0.1815, -0.0339, -0.2227]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.4206, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6800, 0.3600, 0.3100]]), gpi: tensor([[-0.2202,  0.0033, -0.1824]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.4110, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1500, 0.6000, 0.6700]]), gpi: tensor([[-0.1635, -0.0711, -0.1929]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.3976, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.5700, 0.2800]]), gpi: tensor([[-0.2222, -0.0289, -0.2103]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3806, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5400, 0.2700]]), gpi: tensor([[-0.2188, -0.0684, -0.1334]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3612, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.4300, 0.6800]]), gpi: tensor([[-0.1793, -0.0980, -0.2172]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3449, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.4300, 0.3000]]), gpi: tensor([[-0.2039, -0.0706, -0.1611]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.3301, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4200, 0.4800]]), gpi: tensor([[-0.2234, -0.1376, -0.1788]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.3185, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6000, 0.4600, 0.4300]]), gpi: tensor([[-0.2567, -0.1425, -0.2094]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.3121, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2600, 0.4600, 0.4800]]), gpi: tensor([[-0.1911, -0.1638, -0.1912]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.3096, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.2500, 0.4400]]), gpi: tensor([[-0.1709, -0.1435, -0.1971]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.3123, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.3100, 0.3900]]), gpi: tensor([[-0.2200, -0.0893, -0.1603]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2500, 0.3163, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.5200, 0.7300]]), gpi: tensor([[-0.1942, -0.1462, -0.2241]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2500, 0.3229, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.2600, 0.0000]]), gpi: tensor([[-0.1787, -0.0985, -0.1546]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2500, 0.3326, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.4700, 0.4300]]), gpi: tensor([[-0.1957, -0.1440, -0.2164]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.3415, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.2100, 0.3500]]), gpi: tensor([[-0.1927, -0.0752, -0.2120]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.3519, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.3800, 0.5400]]), gpi: tensor([[-0.2041, -0.0820, -0.2007]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2500, 0.3634, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.4400, 0.2500]]), gpi: tensor([[-0.2289, -0.0801, -0.1984]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.3722, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5900, 0.7200, 0.4500]]), gpi: tensor([[-0.1864, -0.0722, -0.2017]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2500, 0.3769, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7900, 0.4600, 0.6300]]), gpi: tensor([[-0.2112, -0.0491, -0.1564]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.3797, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.5300, 0.6400]]), gpi: tensor([[-0.2166, -0.0708, -0.2283]], grad_fn=<NegBackward0>), arm_chosen:1
# 70: dp: tensor([[0.2500, 0.3797, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2200, 0.5600, 0.3900]]), gpi: tensor([[-0.1823, -0.1344, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2500, 0.3774, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6300, 0.6500, 0.3500]]), gpi: tensor([[-0.2047, -0.1265, -0.2397]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2500, 0.3728, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.3500, 0.2500]]), gpi: tensor([[-0.2124, -0.0467, -0.2041]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2500, 0.3671, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.0200, 0.3600]]), gpi: tensor([[-0.1650, -0.0023, -0.1490]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2500, 0.3633, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.2900, 0.2700]]), gpi: tensor([[-0.2500, -0.0624, -0.1670]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2500, 0.3599, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.4500, 0.4400]]), gpi: tensor([[-0.1610, -0.1325, -0.1593]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2500, 0.3568, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4600, 0.3700]]), gpi: tensor([[-0.2326, -0.1113, -0.2103]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2500, 0.3534, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1800, 0.5300, 0.4100]]), gpi: tensor([[-0.1826, -0.0962, -0.1945]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2500, 0.3500, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.8000, 0.6600]]), gpi: tensor([[-0.2713, -0.1185, -0.2507]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2500, 0.3478, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4400, 0.3700]]), gpi: tensor([[-0.2095, -0.1003, -0.1957]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2500, 0.3462, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.3900, 0.4400]]), gpi: tensor([[-0.2029, -0.1232, -0.1724]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2500, 0.3460, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.5400]]), gpi: tensor([[-0.1384, -0.1041, -0.1910]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2500, 0.3474, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.4100, 0.2200]]), gpi: tensor([[-0.1468, -0.0873, -0.1766]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2500, 0.3497, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3100, 0.4100]]), gpi: tensor([[-0.2225, -0.0867, -0.1762]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2500, 0.3506, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.3800, 0.6700]]), gpi: tensor([[-0.1597, -0.1102, -0.2060]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2500, 0.3504, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3000, 0.3800]]), gpi: tensor([[-0.2071, -0.1048, -0.2063]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2500, 0.3495, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.3800, 0.4500]]), gpi: tensor([[-0.1887, -0.1073, -0.1845]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2500, 0.3492, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.2600, 0.7700]]), gpi: tensor([[-0.1825, -0.0742, -0.2199]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2500, 0.3484, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.5700, 0.3300]]), gpi: tensor([[-0.2068, -0.1384, -0.2125]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2500, 0.3511, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6000, 0.5600, 0.4600]]), gpi: tensor([[-0.1948, -0.1293, -0.1813]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2500, 0.3520, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.4100, 0.2800]]), gpi: tensor([[-0.1102, -0.0787, -0.2276]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2500, 0.3512, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7400, 0.2200, 0.5300]]), gpi: tensor([[-0.2536, -0.1383, -0.2375]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2500, 0.3503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.3200, 0.3500]]), gpi: tensor([[-0.1746, -0.0775, -0.1309]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2500, 0.3498, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.4400, 0.6000]]), gpi: tensor([[-0.2103, -0.0595, -0.2175]], grad_fn=<NegBackward0>), arm_chosen:1
# 94: dp: tensor([[0.2500, 0.3505, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.6200, 0.3900]]), gpi: tensor([[-0.1657, -0.1377, -0.2235]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2500, 0.3491, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6900, 0.3400, 0.4300]]), gpi: tensor([[-0.2138, -0.1085, -0.2097]], grad_fn=<NegBackward0>), arm_chosen:1
# 96: dp: tensor([[0.2500, 0.3483, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4600, 0.6800]]), gpi: tensor([[-0.1511, -0.1084, -0.2342]], grad_fn=<NegBackward0>), arm_chosen:1
# 97: dp: tensor([[0.2500, 0.3482, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4700, 0.3400]]), gpi: tensor([[-0.1563, -0.1067, -0.2006]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2500, 0.3483, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.6700, 0.4300]]), gpi: tensor([[-0.1402, -0.0795, -0.1504]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2500, 0.3469, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5100, 0.5300]]), gpi: tensor([[-0.2117, -0.0850, -0.1879]], grad_fn=<NegBackward0>), arm_chosen:1
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5600, 0.5500, 0.3500]]), gpi: tensor([[-0.2007, -0.2647, -0.1723]], grad_fn=<NegBackward0>), arm_chosen:2
# 1: dp: tensor([[0.2503, 0.2503, 0.2851]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.5400, 0.5500]]), gpi: tensor([[-0.2122, -0.2849, -0.1756]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2503, 0.2503, 0.2829]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4100, 0.6000]]), gpi: tensor([[-0.2115, -0.2026, -0.1768]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2503, 0.2503, 0.2708]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5700, 0.4300]]), gpi: tensor([[-0.2067, -0.2886, -0.1147]], grad_fn=<NegBackward0>), arm_chosen:2
# 4: dp: tensor([[0.2503, 0.2503, 0.2521]], grad_fn=<MulBackward0>), ip: tensor([[0.7200, 0.3600, 0.4500]]), gpi: tensor([[-0.2257, -0.1812, -0.1955]], grad_fn=<NegBackward0>), arm_chosen:1
# 5: dp: tensor([[0.2503, 0.2673, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.1000, 0.2900]]), gpi: tensor([[-0.2339, -0.1460, -0.1892]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2503, 0.2902, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.6100, 0.3500]]), gpi: tensor([[-0.1612, -0.1764, -0.1682]], grad_fn=<NegBackward0>), arm_chosen:0
# 7: dp: tensor([[0.2500, 0.3107, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4700, 0.7000]]), gpi: tensor([[-0.2119, -0.1411, -0.2329]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.3348, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.6600, 0.4200]]), gpi: tensor([[-0.2080, -0.1237, -0.1948]], grad_fn=<NegBackward0>), arm_chosen:1
# 9: dp: tensor([[0.2500, 0.3625, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.5200, 0.4500]]), gpi: tensor([[-0.1947, -0.0537, -0.1855]], grad_fn=<NegBackward0>), arm_chosen:1
# 10: dp: tensor([[0.2500, 0.3880, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7200, 0.3400, 0.4100]]), gpi: tensor([[-0.2636, -0.0190, -0.1853]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.4090, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.2800]]), gpi: tensor([[-0.1732, -0.0726, -0.2155]], grad_fn=<NegBackward0>), arm_chosen:1
# 12: dp: tensor([[0.2500, 0.4244, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.2700, 0.2700]]), gpi: tensor([[-0.1778,  0.0247, -0.1745]], grad_fn=<NegBackward0>), arm_chosen:1
# 13: dp: tensor([[0.2500, 0.4367, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.5500, 0.2700]]), gpi: tensor([[-0.1878, -0.0115, -0.2417]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.4455, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5100, 0.3700]]), gpi: tensor([[-0.1955, -0.0382, -0.2265]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.4509, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4800, 0.4100]]), gpi: tensor([[-0.2229,  0.0171, -0.1923]], grad_fn=<NegBackward0>), arm_chosen:1
# 16: dp: tensor([[0.2500, 0.4551, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.3700, 0.4700]]), gpi: tensor([[-0.2467,  0.0078, -0.2349]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.4570, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5700, 0.3600]]), gpi: tensor([[-0.1850,  0.0154, -0.1349]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.4583, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.3200, 0.5700]]), gpi: tensor([[-0.2412,  0.0408, -0.2569]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.4587, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4300, 0.3400]]), gpi: tensor([[-0.2200, -0.0113, -0.2008]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.4577, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4000]]), gpi: tensor([[-0.1685,  0.0003, -0.2333]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.4550, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.2900, 0.4500]]), gpi: tensor([[-0.1773, -0.0165, -0.1913]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.4498, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.3900, 0.6400]]), gpi: tensor([[-0.1569, -0.0504, -0.2594]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.4428, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.4400, 0.4500]]), gpi: tensor([[-0.2423,  0.0288, -0.1856]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.4348, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5300, 0.4200]]), gpi: tensor([[-0.2395, -0.0503, -0.1773]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.4237, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.4100, 0.1700]]), gpi: tensor([[-0.2100, -0.0223, -0.2102]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.4098, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2900, 0.3300, 0.5000]]), gpi: tensor([[-0.1573, -0.0814, -0.1329]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.4007, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.3200]]), gpi: tensor([[-0.2243, -0.0083, -0.1880]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.3953, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4000]]), gpi: tensor([[-0.2069, -0.0518, -0.2334]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.3913, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.6200]]), gpi: tensor([[-0.1918, -0.0376, -0.2903]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.3882, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.3500]]), gpi: tensor([[-0.2445, -0.0222, -0.1499]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.3856, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2300, 0.4800, 0.4800]]), gpi: tensor([[-0.1714, -0.0615, -0.2299]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.3836, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.4500, 0.5200]]), gpi: tensor([[-0.1555, -0.0234, -0.2085]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.3833, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3400, 0.5500]]), gpi: tensor([[-0.1810, -0.0256, -0.1989]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.3833, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.5000, 0.4600]]), gpi: tensor([[-0.2294, -0.0792, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.3834, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.5600, 0.8100]]), gpi: tensor([[-0.2790, -0.0670, -0.2815]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.3858, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.2600]]), gpi: tensor([[-0.1952, -0.0714, -0.1728]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.3902, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5500, 0.3800]]), gpi: tensor([[-0.2001, -0.0606, -0.1784]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3979, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.2300, 0.2600]]), gpi: tensor([[-0.2599, -0.0239, -0.1901]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.4052, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.2700, 0.5600]]), gpi: tensor([[-0.1548, -0.0590, -0.1909]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.4124, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.8400, 0.3600, 0.4800]]), gpi: tensor([[-0.2104, -0.0142, -0.1715]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.4167, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.6600]]), gpi: tensor([[-0.2076, -0.0469, -0.1660]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4185, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.5400, 0.4300]]), gpi: tensor([[-0.2241, -0.0105, -0.1840]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4193, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.4900, 0.3000]]), gpi: tensor([[-0.1445, -0.0168, -0.1900]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4174, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.3600, 0.3900]]), gpi: tensor([[-0.2431, -0.0394, -0.2290]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4152, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.3300, 0.5800]]), gpi: tensor([[-0.1760,  0.0416, -0.2534]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4113, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.1800, 0.6000]]), gpi: tensor([[-0.1930, -0.0022, -0.1868]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4062, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2600, 0.4900, 0.4200]]), gpi: tensor([[-0.1508,  0.0152, -0.1970]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4023, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5900, 0.4700, 0.7300]]), gpi: tensor([[-0.2517, -0.0407, -0.1983]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.3981, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5300, 0.5300]]), gpi: tensor([[-0.1546, -0.1044, -0.2290]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.3966, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7400, 0.3100, 0.4500]]), gpi: tensor([[-0.2210, -0.0364, -0.1758]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.3925, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.2100, 0.6200]]), gpi: tensor([[-0.2129, -0.0578, -0.2167]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.3866, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.3700, 0.4600]]), gpi: tensor([[-0.2006, -0.0795, -0.2198]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3783, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4500, 0.2500]]), gpi: tensor([[-0.2069, -0.0463, -0.2050]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3724, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.1900, 0.3900]]), gpi: tensor([[-0.2738, -0.0364, -0.2167]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3659, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6500, 0.3100, 0.6500]]), gpi: tensor([[-0.2300, -0.0447, -0.1677]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.3575, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3900, 0.3900]]), gpi: tensor([[-0.1776, -0.1264, -0.1819]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.3512, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.2800, 0.7600]]), gpi: tensor([[-0.1381, -0.0803, -0.2167]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.3440, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.2400, 0.5400]]), gpi: tensor([[-0.2016, -0.0732, -0.2100]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.3394, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3500, 0.4900]]), gpi: tensor([[-0.2273, -0.0961, -0.1813]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.3381, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.2900, 0.4400]]), gpi: tensor([[-0.2271, -0.0885, -0.2017]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2500, 0.3367, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.6600, 0.4200]]), gpi: tensor([[-0.2009, -0.1933, -0.1747]], grad_fn=<NegBackward0>), arm_chosen:2
# 62: dp: tensor([[0.2500, 0.3353, 0.2739]], grad_fn=<MulBackward0>), ip: tensor([[0.2600, 0.5600, 0.5000]]), gpi: tensor([[-0.1155, -0.0698, -0.1627]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2500, 0.3360, 0.2952]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4900, 0.6000]]), gpi: tensor([[-0.2134, -0.1359, -0.1414]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.3399, 0.3141]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5400, 0.4800]]), gpi: tensor([[-0.1948, -0.1185, -0.1361]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.3471, 0.3315]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.3500]]), gpi: tensor([[-0.1980, -0.1262, -0.1165]], grad_fn=<NegBackward0>), arm_chosen:2
# 66: dp: tensor([[0.2500, 0.3568, 0.3614]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.2200, 0.5400]]), gpi: tensor([[-0.1843, -0.0733, -0.0874]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.3643, 0.3871]], grad_fn=<MulBackward0>), ip: tensor([[0.6200, 0.5600, 0.4600]]), gpi: tensor([[-0.1652, -0.1146, -0.0954]], grad_fn=<NegBackward0>), arm_chosen:2
# 68: dp: tensor([[0.2500, 0.3727, 0.4151]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3700, 0.5200]]), gpi: tensor([[-0.1924, -0.0360, -0.0542]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.3779, 0.4361]], grad_fn=<MulBackward0>), ip: tensor([[0.5600, 0.5000, 0.2600]]), gpi: tensor([[-0.1897, -0.0879, -0.0189]], grad_fn=<NegBackward0>), arm_chosen:2
# 70: dp: tensor([[0.2500, 0.3830, 0.4544]], grad_fn=<MulBackward0>), ip: tensor([[0.6500, 0.5300, 0.5200]]), gpi: tensor([[-0.2010, -0.0487,  0.0159]], grad_fn=<NegBackward0>), arm_chosen:2
# 71: dp: tensor([[0.2500, 0.3874, 0.4677]], grad_fn=<MulBackward0>), ip: tensor([[0.2300, 0.5900, 0.1300]]), gpi: tensor([[-0.2040, -0.0222,  0.0149]], grad_fn=<NegBackward0>), arm_chosen:2
# 72: dp: tensor([[0.2500, 0.3910, 0.4769]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.3000]]), gpi: tensor([[-0.1671, -0.0811,  0.0474]], grad_fn=<NegBackward0>), arm_chosen:2
# 73: dp: tensor([[0.2500, 0.3940, 0.4833]], grad_fn=<MulBackward0>), ip: tensor([[0.7100, 0.3300, 1.0700]]), gpi: tensor([[-0.2241, -0.1156, -0.0959]], grad_fn=<NegBackward0>), arm_chosen:2
# 74: dp: tensor([[0.2500, 0.3964, 0.4877]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.3700, 0.2700]]), gpi: tensor([[-0.1945, -0.0420,  0.1025]], grad_fn=<NegBackward0>), arm_chosen:2
# 75: dp: tensor([[0.2500, 0.3984, 0.4907]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.3100, 0.2400]]), gpi: tensor([[-0.2332, -0.0257,  0.1086]], grad_fn=<NegBackward0>), arm_chosen:2
# 76: dp: tensor([[0.2500, 0.4000, 0.4928]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.5600, 0.1400]]), gpi: tensor([[-0.1577, -0.0777,  0.1055]], grad_fn=<NegBackward0>), arm_chosen:2
# 77: dp: tensor([[0.2500, 0.4014, 0.4943]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.3900, 0.7500]]), gpi: tensor([[-0.1741, -0.0009,  0.0220]], grad_fn=<NegBackward0>), arm_chosen:2
# 78: dp: tensor([[0.2500, 0.4025, 0.4954]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.6600, 0.5400]]), gpi: tensor([[-0.2589, -0.0552,  0.0202]], grad_fn=<NegBackward0>), arm_chosen:2
# 79: dp: tensor([[0.2500, 0.4035, 0.4962]], grad_fn=<MulBackward0>), ip: tensor([[0.2900, 0.6100, 0.2700]]), gpi: tensor([[-0.0870, -0.0259,  0.1028]], grad_fn=<NegBackward0>), arm_chosen:2
# 80: dp: tensor([[0.2500, 0.4044, 0.4968]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.5100, 0.7600]]), gpi: tensor([[-0.1841, -0.0803,  0.0256]], grad_fn=<NegBackward0>), arm_chosen:2
# 81: dp: tensor([[0.2500, 0.4051, 0.4973]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.3700, 0.5800]]), gpi: tensor([[-0.1839, -0.0031,  0.0199]], grad_fn=<NegBackward0>), arm_chosen:2
# 82: dp: tensor([[0.2500, 0.4057, 0.4976]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4600, 0.4300]]), gpi: tensor([[-0.2266, -0.0409,  0.0554]], grad_fn=<NegBackward0>), arm_chosen:2
# 83: dp: tensor([[0.2500, 0.4063, 0.4979]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.5900, 0.4800]]), gpi: tensor([[-0.1792, -0.0549,  0.0548]], grad_fn=<NegBackward0>), arm_chosen:2
# 84: dp: tensor([[0.2500, 0.4067, 0.4981]], grad_fn=<MulBackward0>), ip: tensor([[0.2400, 0.4500, 0.3200]]), gpi: tensor([[-0.1660, -0.0554,  0.0782]], grad_fn=<NegBackward0>), arm_chosen:2
# 85: dp: tensor([[0.2500, 0.4072, 0.4983]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.4700, 0.3700]]), gpi: tensor([[-0.1938, -0.0809,  0.0571]], grad_fn=<NegBackward0>), arm_chosen:2
# 86: dp: tensor([[0.2500, 0.4076, 0.4985]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.3000, 0.2600]]), gpi: tensor([[-0.1370,  0.0066,  0.1000]], grad_fn=<NegBackward0>), arm_chosen:2
# 87: dp: tensor([[0.2500, 0.4079, 0.4986]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3300, 0.4800]]), gpi: tensor([[-0.2403, -0.0163,  0.0371]], grad_fn=<NegBackward0>), arm_chosen:2
# 88: dp: tensor([[0.2500, 0.4082, 0.4987]], grad_fn=<MulBackward0>), ip: tensor([[0.2500, 0.6000, 0.3700]]), gpi: tensor([[-0.2059, -0.0142,  0.0839]], grad_fn=<NegBackward0>), arm_chosen:2
# 89: dp: tensor([[0.2500, 0.4085, 0.4988]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.5000, 0.4200]]), gpi: tensor([[-0.2339, -0.0269,  0.0344]], grad_fn=<NegBackward0>), arm_chosen:2
# 90: dp: tensor([[0.2500, 0.4087, 0.4988]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.6600, 0.5300]]), gpi: tensor([[-0.2004, -0.0281,  0.0544]], grad_fn=<NegBackward0>), arm_chosen:2
# 91: dp: tensor([[0.2500, 0.4089, 0.4989]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.6400, 0.4800]]), gpi: tensor([[-0.2040, -0.1145,  0.0456]], grad_fn=<NegBackward0>), arm_chosen:2
# 92: dp: tensor([[0.2500, 0.4091, 0.4990]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.1900, 0.1600]]), gpi: tensor([[-0.2115, -0.0033,  0.0869]], grad_fn=<NegBackward0>), arm_chosen:2
# 93: dp: tensor([[0.2500, 0.4093, 0.4990]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.4200, 0.2200]]), gpi: tensor([[-0.2227, -0.0373,  0.1044]], grad_fn=<NegBackward0>), arm_chosen:2
# 94: dp: tensor([[0.2500, 0.4094, 0.4990]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.5200, 0.2600]]), gpi: tensor([[-0.2476, -0.0178,  0.0501]], grad_fn=<NegBackward0>), arm_chosen:2
# 95: dp: tensor([[0.2500, 0.4096, 0.4991]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.3100, 0.2100]]), gpi: tensor([[-0.1983, -0.0066,  0.1030]], grad_fn=<NegBackward0>), arm_chosen:2
# 96: dp: tensor([[0.2500, 0.4097, 0.4991]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5300, 0.0400]]), gpi: tensor([[-0.1979, -0.0269,  0.1099]], grad_fn=<NegBackward0>), arm_chosen:2
# 97: dp: tensor([[0.2500, 0.4098, 0.4991]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.5500, 0.0500]]), gpi: tensor([[-0.1565, -0.0137,  0.1075]], grad_fn=<NegBackward0>), arm_chosen:2
# 98: dp: tensor([[0.2500, 0.4099, 0.4992]], grad_fn=<MulBackward0>), ip: tensor([[0.5900, 0.3700, 0.5300]]), gpi: tensor([[-0.2136, -0.0345, -0.0108]], grad_fn=<NegBackward0>), arm_chosen:2
# 99: dp: tensor([[0.2500, 0.4100, 0.4992]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.5700, 0.3000]]), gpi: tensor([[-0.1600,  0.0205,  0.1089]], grad_fn=<NegBackward0>), arm_chosen:2
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3200, 0.6100, 0.2900]]), gpi: tensor([[-0.1170, -0.1626, -0.1556]], grad_fn=<NegBackward0>), arm_chosen:0
# 1: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3700, 0.4600]]), gpi: tensor([[-0.2147, -0.1630, -0.1576]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2500, 0.2503, 0.2735]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.3800, 0.6000]]), gpi: tensor([[-0.1899, -0.2073, -0.1629]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2500, 0.2503, 0.2584]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.7300, 0.3600]]), gpi: tensor([[-0.2081, -0.2036, -0.2491]], grad_fn=<NegBackward0>), arm_chosen:1
# 4: dp: tensor([[0.2500, 0.2684, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5300, 0.1000]]), gpi: tensor([[-0.1120, -0.1717, -0.1897]], grad_fn=<NegBackward0>), arm_chosen:0
# 5: dp: tensor([[0.2500, 0.2836, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.2500, 0.2700]]), gpi: tensor([[-0.1893, -0.1724, -0.1326]], grad_fn=<NegBackward0>), arm_chosen:2
# 6: dp: tensor([[0.2500, 0.2965, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.6000]]), gpi: tensor([[-0.2456, -0.1415, -0.2224]], grad_fn=<NegBackward0>), arm_chosen:1
# 7: dp: tensor([[0.2500, 0.3162, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1800, 0.5300, 0.4100]]), gpi: tensor([[-0.1826, -0.1332, -0.1945]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.3421, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.3000, 0.7000]]), gpi: tensor([[-0.1919, -0.1051, -0.1803]], grad_fn=<NegBackward0>), arm_chosen:1
# 9: dp: tensor([[0.2500, 0.3714, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2500, 0.4600, 0.6400]]), gpi: tensor([[-0.1919, -0.0534, -0.2521]], grad_fn=<NegBackward0>), arm_chosen:1
# 10: dp: tensor([[0.2500, 0.3981, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.5900, 0.3600]]), gpi: tensor([[-0.1721, -0.0965, -0.1655]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.4194, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.6200, 0.5100]]), gpi: tensor([[-0.2327, -0.0639, -0.1814]], grad_fn=<NegBackward0>), arm_chosen:1
# 12: dp: tensor([[0.2500, 0.4355, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4500, 0.4900]]), gpi: tensor([[-0.2046, -0.0011, -0.2002]], grad_fn=<NegBackward0>), arm_chosen:1
# 13: dp: tensor([[0.2500, 0.4456, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.7600, 0.3500, 0.4500]]), gpi: tensor([[-0.2113,  0.0145, -0.2016]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.4532, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3600, 0.5400, 0.5400]]), gpi: tensor([[-0.1525, -0.0360, -0.1904]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.4586, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1300, 0.3200, 0.2700]]), gpi: tensor([[-0.2151,  0.0514, -0.1969]], grad_fn=<NegBackward0>), arm_chosen:1
# 16: dp: tensor([[0.2500, 0.4620, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.2800, 0.5000]]), gpi: tensor([[-0.2041,  0.1037, -0.2053]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.4637, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.5900, 0.6500]]), gpi: tensor([[-0.1961, -0.0054, -0.1811]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.4642, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3200, 0.3800, 0.4000]]), gpi: tensor([[-0.2005, -0.0033, -0.1863]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.4636, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3900, 0.3300]]), gpi: tensor([[-0.2083,  0.0357, -0.1112]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.4622, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.4200, 0.2600]]), gpi: tensor([[-0.1811,  0.0689, -0.1510]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.4603, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1200, 0.4400, 0.2900]]), gpi: tensor([[-0.1857,  0.0141, -0.1943]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.4572, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2200, 0.5600, 0.3400]]), gpi: tensor([[-0.1718,  0.0285, -0.1725]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.4524, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.2800, 0.6700]]), gpi: tensor([[-0.1880, -0.0190, -0.1564]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.4463, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.4200, 0.3700]]), gpi: tensor([[-0.2161,  0.0090, -0.1888]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.4388, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.8200, 0.2600]]), gpi: tensor([[-0.1565, -0.0665, -0.1590]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.4304, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.0700, 0.5700]]), gpi: tensor([[-0.1503,  0.1107, -0.1976]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.4198, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4900, 0.4100]]), gpi: tensor([[-0.1463, -0.0534, -0.1856]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.4080, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.1700, 0.5000]]), gpi: tensor([[-0.2008, -0.0251, -0.1946]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.3957, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.2800, 0.6200]]), gpi: tensor([[-0.2283, -0.0903, -0.2160]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.3838, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3200, 0.5100, 0.3600]]), gpi: tensor([[-0.1706, -0.0272, -0.1940]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.3749, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.3500, 0.5500]]), gpi: tensor([[-0.1655, -0.1149, -0.1979]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.3694, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.1700, 0.5000]]), gpi: tensor([[-0.2008, -0.0635, -0.1946]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.3661, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4000, 0.2500]]), gpi: tensor([[-0.2206, -0.0823, -0.2091]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.3656, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.3800, 0.1600]]), gpi: tensor([[-0.1749, -0.1131, -0.1711]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.3670, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1900, 0.4700, 0.4300]]), gpi: tensor([[-0.2293, -0.0854, -0.2085]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.3706, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6800, 0.5100, 0.5500]]), gpi: tensor([[-0.2022, -0.0583, -0.2543]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.3760, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.4600, 0.3400]]), gpi: tensor([[-0.1480, -0.1014, -0.2251]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3823, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.7300, 0.5300]]), gpi: tensor([[-0.1578, -0.0982, -0.2477]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.3921, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.3000, 0.6100]]), gpi: tensor([[-0.2427, -0.0417, -0.2312]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.3999, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.3600, 0.5700]]), gpi: tensor([[-0.2060, -0.0216, -0.2281]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.4070, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.4000, 0.3100]]), gpi: tensor([[-0.1876, -0.0421, -0.1833]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4131, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.5600, 0.4900]]), gpi: tensor([[-0.2649, -0.0693, -0.2153]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4172, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.2800, 0.3300]]), gpi: tensor([[-0.2311, -0.0207, -0.1858]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4216, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4500, 0.3800]]), gpi: tensor([[-0.2269, -0.0529, -0.2130]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4241, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6500, 0.6600, 0.3400]]), gpi: tensor([[-0.2355, -0.0115, -0.1485]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4256, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.1800, 0.5500, 0.5300]]), gpi: tensor([[-0.1710, -0.0681, -0.1934]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4245, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.8200, 0.2600]]), gpi: tensor([[-0.1565, -0.0806, -0.1590]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4230, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.2100, 0.3800, 0.4600]]), gpi: tensor([[-0.1861,  0.0148, -0.1681]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.4233, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.6200, 0.3900, 0.2700]]), gpi: tensor([[-0.2380, -0.0153, -0.1617]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.4235, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.3600, 0.5400]]), gpi: tensor([[-0.1851, -0.0150, -0.2069]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.4187, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4100, 0.6200]]), gpi: tensor([[-0.2106, -0.0551, -0.2635]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.4104, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5400, 0.6000]]), gpi: tensor([[-0.1944, -0.0943, -0.2170]], grad_fn=<NegBackward0>), arm_chosen:1
# ...
# 16: dp: tensor([[0.2500, 0.4710, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.4000, 0.5500]]), gpi: tensor([[-0.1576, -0.0036, -0.2605]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.4702, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.6400, 0.4200, 0.2700]]), gpi: tensor([[-0.2224,  0.0058, -0.2079]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.4690, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.2500, 0.6000, 0.3700]]), gpi: tensor([[-0.2059,  0.0464, -0.1630]], grad_fn=<NegBackward0>), arm_chosen:1
# 19: dp: tensor([[0.2500, 0.4671, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.2200, 0.5200, 0.6300]]), gpi: tensor([[-0.1532, -0.0273, -0.2697]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.4649, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.6000, 0.4400, 0.2900]]), gpi: tensor([[-0.2017,  0.0103, -0.1960]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.4617, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.5300, 0.3400]]), gpi: tensor([[-0.2193,  0.0059, -0.2081]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.4575, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.4700, 0.4800]]), gpi: tensor([[-0.1977,  0.0691, -0.1916]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.4528, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.5500, 0.4900]]), gpi: tensor([[-0.1729, -0.0384, -0.2867]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.4475, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.2600, 0.4100]]), gpi: tensor([[-0.2733, -0.0113, -0.1884]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.4402, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.6300, 0.1600, 0.4600]]), gpi: tensor([[-0.2142,  0.0468, -0.2202]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.4321, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.7400, 0.4400]]), gpi: tensor([[-0.2045, -0.0438, -0.1855]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.4223, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2500, 0.3400, 0.5500]]), gpi: tensor([[-0.1811,  0.0064, -0.2022]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.4123, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.3900, 0.3900]]), gpi: tensor([[-0.2217, -0.0868, -0.2145]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.4023, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.2900, 0.4900]]), gpi: tensor([[-0.1805,  0.0167, -0.2057]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.3959, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.5400, 0.4500]]), gpi: tensor([[-0.1906, -0.0699, -0.2116]], grad_fn=<NegBackward0>), arm_chosen:1
# 31: dp: tensor([[0.2500, 0.3882, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2100, 0.4000, 0.4100]]), gpi: tensor([[-0.1795, -0.0307, -0.1704]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.3809, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.1300, 0.2900, 0.3300]]), gpi: tensor([[-0.1509, -0.0222, -0.1899]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.3744, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5500, 0.3600]]), gpi: tensor([[-0.2110, -0.1068, -0.2301]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.3696, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.3700, 0.3800]]), gpi: tensor([[-0.1861, -0.1050, -0.2282]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.3673, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3900, 0.3300]]), gpi: tensor([[-0.2438, -0.0877, -0.0924]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.3702, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5900, 0.3400]]), gpi: tensor([[-0.2055, -0.0723, -0.1540]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.3748, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.3200, 0.4100]]), gpi: tensor([[-0.2330, -0.0932, -0.1887]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3809, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4400, 0.5100]]), gpi: tensor([[-0.2287, -0.0727, -0.2218]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.3871, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.4100, 0.2200]]), gpi: tensor([[-0.1468, -0.0478, -0.1762]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.3944, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.5500, 0.4100]]), gpi: tensor([[-0.1720, -0.0495, -0.2201]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.4034, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.3000, 0.4600]]), gpi: tensor([[-0.1835, -0.0268, -0.2566]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4114, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.6100, 0.2200]]), gpi: tensor([[-0.2397, -0.0770, -0.2005]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4187, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.2800, 0.3100]]), gpi: tensor([[-0.1805, -0.0166, -0.2154]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4243, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.6000, 0.5400, 0.2700]]), gpi: tensor([[-0.1976, -0.0297, -0.1352]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4306, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.6600, 0.6800]]), gpi: tensor([[-0.1385,  0.0138, -0.2211]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4341, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2900, 0.6000, 0.3600]]), gpi: tensor([[-0.2146, -0.0252, -0.1949]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4358, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.2100, 0.7400, 0.4300]]), gpi: tensor([[-0.2452, -0.0474, -0.1876]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4354, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.3500, 0.6100, 0.5800]]), gpi: tensor([[-0.1448, -0.0456, -0.2725]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.4336, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.2000, 0.3700]]), gpi: tensor([[-0.1347,  0.0027, -0.2012]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.4306, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.7400, 0.4700, 0.3800]]), gpi: tensor([[-0.2290, -0.0065, -0.1615]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.4230, 0.2505]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4600, 0.6200]]), gpi: tensor([[-0.2140, -0.0115, -0.1894]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.4114, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5500, 0.4900, 0.5000]]), gpi: tensor([[-0.2545, -0.0317, -0.2175]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3995, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.7800, 0.3900, 0.6100]]), gpi: tensor([[-0.2285, -0.0443, -0.2541]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3848, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.2400, 0.5300]]), gpi: tensor([[-0.2272, -0.0342, -0.2434]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3674, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5700, 0.2500, 0.8300]]), gpi: tensor([[-0.2169,  0.0444, -0.2249]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.3536, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.2900, 0.3700, 0.6700]]), gpi: tensor([[-0.2549, -0.1295, -0.2099]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.3398, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.6400, 0.4600]]), gpi: tensor([[-0.2287, -0.0807, -0.2431]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.3301, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.3900, 0.4300]]), gpi: tensor([[-0.1830, -0.1155, -0.2038]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.3188, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.3400, 0.8000, 0.5800]]), gpi: tensor([[-0.1831, -0.1554, -0.2532]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.3130, 0.2504]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.6500, 0.5100]]), gpi: tensor([[-0.2380, -0.1940, -0.1694]], grad_fn=<NegBackward0>), arm_chosen:2
# 61: dp: tensor([[0.2500, 0.3082, 0.2797]], grad_fn=<MulBackward0>), ip: tensor([[0.1600, 0.5500, 0.5400]]), gpi: tensor([[-0.1922, -0.1686, -0.2012]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2500, 0.3081, 0.3048]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4700, 0.3100]]), gpi: tensor([[-0.1860, -0.1798, -0.1062]], grad_fn=<NegBackward0>), arm_chosen:2
# 63: dp: tensor([[0.2500, 0.3080, 0.3398]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.3000, 0.4800]]), gpi: tensor([[-0.1797, -0.1190, -0.0795]], grad_fn=<NegBackward0>), arm_chosen:2
# 64: dp: tensor([[0.2500, 0.3079, 0.3797]], grad_fn=<MulBackward0>), ip: tensor([[0.7000, 0.5000, 0.4000]]), gpi: tensor([[-0.2133, -0.1256, -0.0357]], grad_fn=<NegBackward0>), arm_chosen:2
# 65: dp: tensor([[0.2500, 0.3078, 0.4162]], grad_fn=<MulBackward0>), ip: tensor([[0.2800, 0.4500, 0.2100]]), gpi: tensor([[-0.2416, -0.1187, -0.0034]], grad_fn=<NegBackward0>), arm_chosen:2
# 66: dp: tensor([[0.2500, 0.3077, 0.4436]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4500, 0.6200]]), gpi: tensor([[-0.1905, -0.0955, -0.0126]], grad_fn=<NegBackward0>), arm_chosen:2
# 67: dp: tensor([[0.2500, 0.3077, 0.4619]], grad_fn=<MulBackward0>), ip: tensor([[0.6600, 0.2000, 0.4600]]), gpi: tensor([[-0.1860, -0.1152,  0.0177]], grad_fn=<NegBackward0>), arm_chosen:2
# 68: dp: tensor([[0.2500, 0.3076, 0.4740]], grad_fn=<MulBackward0>), ip: tensor([[0.6100, 0.4600, 0.2500]]), gpi: tensor([[-0.1798, -0.1183, -0.0250]], grad_fn=<NegBackward0>), arm_chosen:2
# 69: dp: tensor([[0.2500, 0.3076, 0.4819]], grad_fn=<MulBackward0>), ip: tensor([[0.7500, 0.7100, 0.1800]]), gpi: tensor([[-0.2346, -0.1413,  0.1001]], grad_fn=<NegBackward0>), arm_chosen:2
# 70: dp: tensor([[0.2500, 0.3075, 0.4871]], grad_fn=<MulBackward0>), ip: tensor([[0.2700, 0.4000, 0.5500]]), gpi: tensor([[-0.1576, -0.1662, -0.0250]], grad_fn=<NegBackward0>), arm_chosen:2
# 71: dp: tensor([[0.2500, 0.3075, 0.4906]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.7600]]), gpi: tensor([[-0.1406, -0.1526, -0.0194]], grad_fn=<NegBackward0>), arm_chosen:2
# 72: dp: tensor([[0.2500, 0.3075, 0.4930]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.4400, 0.3900]]), gpi: tensor([[-0.1369, -0.1918,  0.0036]], grad_fn=<NegBackward0>), arm_chosen:2
# 73: dp: tensor([[0.2500, 0.3074, 0.4946]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.3900, 0.6900]]), gpi: tensor([[-0.1974, -0.1392, -0.0110]], grad_fn=<NegBackward0>), arm_chosen:2
# 74: dp: tensor([[0.2500, 0.3074, 0.4957]], grad_fn=<MulBackward0>), ip: tensor([[0.7500, 0.3800, 0.1200]]), gpi: tensor([[-0.1664, -0.0622,  0.1082]], grad_fn=<NegBackward0>), arm_chosen:2
# 75: dp: tensor([[0.2500, 0.3074, 0.4966]], grad_fn=<MulBackward0>), ip: tensor([[0.3000, 0.0700, 0.3500]]), gpi: tensor([[-0.2510, -0.1415,  0.0135]], grad_fn=<NegBackward0>), arm_chosen:2
# 76: dp: tensor([[0.2500, 0.3073, 0.4972]], grad_fn=<MulBackward0>), ip: tensor([[0.3700, 0.5300, 0.5200]]), gpi: tensor([[-0.2329, -0.1400,  0.0187]], grad_fn=<NegBackward0>), arm_chosen:2
# 77: dp: tensor([[0.2500, 0.3073, 0.4976]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.3200, 0.1000]]), gpi: tensor([[-0.2008, -0.1036,  0.1197]], grad_fn=<NegBackward0>), arm_chosen:2
# 78: dp: tensor([[0.2500, 0.3073, 0.4980]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.4600, 0.6700]]), gpi: tensor([[-0.2067, -0.1670,  0.0219]], grad_fn=<NegBackward0>), arm_chosen:2
# 79: dp: tensor([[0.2500, 0.3073, 0.4982]], grad_fn=<MulBackward0>), ip: tensor([[0.3300, 0.4900, 0.2800]]), gpi: tensor([[-0.1689, -0.1452,  0.1015]], grad_fn=<NegBackward0>), arm_chosen:2
# 80: dp: tensor([[0.2500, 0.3073, 0.4985]], grad_fn=<MulBackward0>), ip: tensor([[0.3200, 0.3200, 0.4800]]), gpi: tensor([[-0.1774, -0.0722,  0.0515]], grad_fn=<NegBackward0>), arm_chosen:2
# 81: dp: tensor([[0.2500, 0.3072, 0.4986]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.3900, 0.3300]]), gpi: tensor([[-0.1372, -0.1639,  0.0835]], grad_fn=<NegBackward0>), arm_chosen:2
# 82: dp: tensor([[0.2500, 0.3072, 0.4988]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.6200]]), gpi: tensor([[-0.1918, -0.1213, -0.0428]], grad_fn=<NegBackward0>), arm_chosen:2
# 83: dp: tensor([[0.2500, 0.3072, 0.4989]], grad_fn=<MulBackward0>), ip: tensor([[0.2900, 0.2900, 0.1800]]), gpi: tensor([[-0.1764, -0.1063,  0.1052]], grad_fn=<NegBackward0>), arm_chosen:2
# 84: dp: tensor([[0.2500, 0.3072, 0.4990]], grad_fn=<MulBackward0>), ip: tensor([[0.0100, 0.5600, 0.2100]]), gpi: tensor([[-0.0780, -0.1187,  0.1023]], grad_fn=<NegBackward0>), arm_chosen:2
# 85: dp: tensor([[0.2500, 0.3072, 0.4991]], grad_fn=<MulBackward0>), ip: tensor([[0.2500, 0.4100, 0.2600]]), gpi: tensor([[-0.1511, -0.1017,  0.1050]], grad_fn=<NegBackward0>), arm_chosen:2
# 86: dp: tensor([[0.2500, 0.3072, 0.4991]], grad_fn=<MulBackward0>), ip: tensor([[0.3100, 0.3700, 0.2700]]), gpi: tensor([[-0.1737, -0.1202,  0.1048]], grad_fn=<NegBackward0>), arm_chosen:2
# 87: dp: tensor([[0.2500, 0.3072, 0.4992]], grad_fn=<MulBackward0>), ip: tensor([[0.6000, 0.5600, 0.2600]]), gpi: tensor([[-0.1752, -0.1957,  0.1047]], grad_fn=<NegBackward0>), arm_chosen:2
# 88: dp: tensor([[0.2500, 0.3072, 0.4992]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.3300, 0.5000]]), gpi: tensor([[-0.2614, -0.1472,  0.0626]], grad_fn=<NegBackward0>), arm_chosen:2
# 89: dp: tensor([[0.2500, 0.3072, 0.4993]], grad_fn=<MulBackward0>), ip: tensor([[0.1900, 0.4000, 0.2600]]), gpi: tensor([[-0.1999, -0.1575,  0.1028]], grad_fn=<NegBackward0>), arm_chosen:2
# 90: dp: tensor([[0.2500, 0.3072, 0.4993]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.5000, 0.1400]]), gpi: tensor([[-0.2046, -0.1856,  0.1057]], grad_fn=<NegBackward0>), arm_chosen:2
# 91: dp: tensor([[0.2500, 0.3072, 0.4993]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.5100, 0.1700]]), gpi: tensor([[-0.2358, -0.1360,  0.1009]], grad_fn=<NegBackward0>), arm_chosen:2
# 92: dp: tensor([[0.2500, 0.3071, 0.4993]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4100, 0.2100]]), gpi: tensor([[-0.2144, -0.1245,  0.0504]], grad_fn=<NegBackward0>), arm_chosen:2
# 93: dp: tensor([[0.2500, 0.3071, 0.4994]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4700, 0.4500]]), gpi: tensor([[-0.2074, -0.1430,  0.0508]], grad_fn=<NegBackward0>), arm_chosen:2
# 94: dp: tensor([[0.2500, 0.3071, 0.4994]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.1700, 0.4400]]), gpi: tensor([[-0.2232, -0.1102,  0.0426]], grad_fn=<NegBackward0>), arm_chosen:2
# 95: dp: tensor([[0.2500, 0.3071, 0.4994]], grad_fn=<MulBackward0>), ip: tensor([[0.5800, 0.4200, 0.2300]]), gpi: tensor([[-0.2405, -0.1574,  0.1049]], grad_fn=<NegBackward0>), arm_chosen:2
# 96: dp: tensor([[0.2500, 0.3071, 0.4994]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.6900, 0.3500]]), gpi: tensor([[-0.1925, -0.1474, -0.0231]], grad_fn=<NegBackward0>), arm_chosen:2
# 97: dp: tensor([[0.2500, 0.3071, 0.4994]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4000, 0.0500]]), gpi: tensor([[-0.1926, -0.0882,  0.1005]], grad_fn=<NegBackward0>), arm_chosen:2
# 98: dp: tensor([[0.2500, 0.3071, 0.4995]], grad_fn=<MulBackward0>), ip: tensor([[0.5400, 0.5100, 0.4400]]), gpi: tensor([[-0.2173, -0.2043,  0.0457]], grad_fn=<NegBackward0>), arm_chosen:2
# 99: dp: tensor([[0.2500, 0.3071, 0.4995]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.6300, 0.5100]]), gpi: tensor([[-0.2405, -0.1408,  0.0381]], grad_fn=<NegBackward0>), arm_chosen:2

# %% [markdown]
# ## Analysis

# %%
mean_picks = {key: torch.mean(avg_counts[key], dim = 0) for key in list(avg_counts.keys())}
IP_avg = {key: torch.mean(ip_monitor[key], dim =0).detach().numpy() for key in list(ip_monitor.keys())}
DP_avg = {key: torch.mean(dp_monitor[key], dim =0).detach().numpy() for key in list(dp_monitor.keys())}
IP_var = np.std(np.stack(list(IP_avg.values()), axis=0),axis = 0)[:,0]
arm_chosen_monitor = arm_chosen_monitor.to(torch.int)

# Computing Accuracy
accuracy_percentages = torch.zeros((EPOCHS, BINS))

for i in range(BINS):
    start, end = i * BIN_SIZE, (i + 1) * BIN_SIZE
    correct_choices = torch.sum(arm_chosen_monitor[:, start:end] == BEST_ARM[:,start:end], axis = 1)
    accuracy_percentages[:, i] = (correct_choices / BIN_SIZE) * 100

accuracy_per_bin = torch.mean(accuracy_percentages,axis = 0)

# %%
BIN = np.arange(BINS)+1


plt.figure(figsize=(5,1.5))
plt.subplot(131)
for i in DP_avg.keys():
    plt.plot(np.arange(TRIALS), DP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('DP output')
plt.legend(loc = 'upper right')

plt.subplot(132)

for i in mean_picks.keys():
    plt.plot(BIN,mean_picks[i], label = i, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Avg card picks with trials')
plt.xlabel('bins')
plt.legend(loc = 'upper right')

plt.subplot(133)
plt.plot(BIN, accuracy_per_bin, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Accuracy')
plt.ylim(0,105)
plt.xlabel('bins')

print('Accuracy at last bin: ',accuracy_per_bin[-1].item())
print('Avg accuracy across bins: ',torch.mean(accuracy_per_bin).item())
# Out:
# Accuracy at last bin:  56.099998474121094
# Avg accuracy across bins:  63.86000442504883

# %%
plt.figure(figsize=(2,1.5))
for i in IP_avg.keys():
    plt.plot(np.arange(TRIALS), IP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('IP output')
plt.legend(loc = 'upper right')

# %%
random_epochs = np.random.choice(np.arange(EPOCHS), size = 2)
i = 1
plt.figure(figsize=(3,1))
for e in random_epochs:
    plt.subplot(1,2,i)
    colors = np.where(np.isin(arm_chosen_monitor[e],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRIALS), arm_chosen_monitor[e], marker = '|', s = 20)
    plt.ylim(-1,4)
    plt.xlabel('TRIALS')
    i+=1

# plt.suptitle('Card picks in each epoch')
plt.tight_layout()
