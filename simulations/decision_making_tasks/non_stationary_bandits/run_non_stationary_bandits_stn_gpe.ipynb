# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
import os, sys
import torch
from matplotlib.lines import Line2D
from tqdm.autonotebook import tqdm
from matplotlib.colors import LinearSegmentedColormap
# Root project
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to sys.path:", project_root)

from envs import *
from basal_ganglia import *
from stn_gpe import *

# filter warnings
import warnings
warnings.filterwarnings("ignore")



plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman"],  # Times for publication
    "font.size": 8,                    # Base font size
    "axes.labelsize": 8,              # Axis label font size
    "axes.labelweight": "bold",
    "font.weight": "bold",   
    "axes.titlesize":8,              # Axis title (not fig title)
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize":8,              # Legend font size

    "figure.dpi": 300,                 # Display resolution
    "savefig.dpi": 300,                # Save resolution
    "figure.constrained_layout.use": True,  # Better spacing than tight_layout

    "axes.linewidth": 0.8,             # Thin but clear axes lines
    "lines.linewidth": 1.2,
    "lines.markersize": 5,

    "axes.spines.top": False,
    "axes.spines.right": False,

    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.major.size": 4,
    "ytick.major.size": 4,
    "xtick.minor.size": 2,
    "ytick.minor.size": 2,

    "legend.frameon": False,
    "legend.handlelength": 2.0,        # Slightly longer legend lines
    "legend.handletextpad": 0.5,

    "pdf.fonttype": 42,                # Embed editable fonts in PDF
    "ps.fonttype": 42
})
# Out:
# /var/folders/9v/hs9qlpdx4791kpqgpt09stch0000gn/T/ipykernel_3304/1253422274.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Project root added to sys.path: /Users/charithapalika/Desktop/Lab projects/Decision Making/light_house_DBS_decision_making

# %%
yaml_path = os.path.join(project_root, 'params', 'decision_making_task_params', 'non_stationary_bandits', 'params.yaml')
params = load_yaml(yaml_path)
STN_DATA_path = os.path.join(project_root, 'params', 'stn_gpe_params', 'params_PD.yaml')

# %%
TRIALS = params['TRIALS']
EPOCHS = params['EPOCHS']
BINS = params['NUM_BINS']
LR = params['LR'] 
NUM_ARMS =params['NUM_ARMS']
SCALING_FACTOR = params['SCALING_FACTOR']   
TIME_STAMP_CHANGE = params['TIME_STAMP_CHANGE']
BIN_SIZE = TRIALS//BINS
BIN_CHANGE = TIME_STAMP_CHANGE // BIN_SIZE

# %%
env = NonStationaryEnv(
    num_arms = NUM_ARMS, 
    mean_reward = np.array([20, 40, 25])/SCALING_FACTOR, #np.array([5,40,10])/SCALING_FACTOR, (20,40,10)
    std = np.array([2,2,2])/SCALING_FACTOR, 
    mean_rew_change = np.array([25, 30, 50])/SCALING_FACTOR, #np.array([10,20,60])/SCALING_FACTOR, (10,20,60)
    std_change = np.array([2,2,2])/SCALING_FACTOR, 
    time_stamp_change = TIME_STAMP_CHANGE)

BEST_ARM_BEFORE = 1
BEST_ARM_AFTER = 2

BEST_ARM = torch.zeros((EPOCHS,TRIALS), dtype=int)
BEST_ARM[:,:TIME_STAMP_CHANGE] = BEST_ARM_BEFORE
BEST_ARM[:,TIME_STAMP_CHANGE:] = BEST_ARM_AFTER

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor,ep_monitor, _= train(env, 
                                                      trails = TRIALS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = BINS,
                                                      STN_data = STN_DATA_path, #'rossler',
                                                      d1_amp=0.5, #0.5,
                                                      d2_amp=0.45, #0.0029, 
                                                      gpi_threshold=0.1,
                                                      max_gpi_iters=50,
                                                      del_lim=0.1, train_IP = False, 
                                                      del_med = None, printing = True,
                                                      gpi_mean= 1, ep_0 = 0.3,
                                                      alpha_ep = 0.0,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.0)
# Out:
# Running STN-GPe system
#   0%|          | 0/50000 [00:00<?, ?it/s]
# StdDev of STN: 0.05947437958575068, Mean of STN: 1.0
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4400, 0.4600]]), gpi: tensor([[-0.1983, -0.1985, -0.1929]], grad_fn=<NegBackward0>), arm_chosen:2
# 1: dp: tensor([[0.2503, 0.2503, 0.2850]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4100]]), gpi: tensor([[-0.1884, -0.1870, -0.1647]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2503, 0.2503, 0.2608]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4400]]), gpi: tensor([[-0.1973, -0.1951, -0.1866]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4600]]), gpi: tensor([[-0.1986, -0.2015, -0.2002]], grad_fn=<NegBackward0>), arm_chosen:0
# 4: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.3800]]), gpi: tensor([[-0.1970, -0.1979, -0.1895]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4400]]), gpi: tensor([[-0.1994, -0.1952, -0.1998]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4800, 0.4500]]), gpi: tensor([[-0.1949, -0.2155, -0.1998]], grad_fn=<NegBackward0>), arm_chosen:0
# 7: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4500]]), gpi: tensor([[-0.1979, -0.1915, -0.2000]], grad_fn=<NegBackward0>), arm_chosen:1
# 8: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.5100]]), gpi: tensor([[-0.1979, -0.1986, -0.2043]], grad_fn=<NegBackward0>), arm_chosen:0
# 9: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4500, 0.4600]]), gpi: tensor([[-0.1922, -0.1986, -0.1951]], grad_fn=<NegBackward0>), arm_chosen:0
# 10: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4600]]), gpi: tensor([[-0.1981, -0.2062, -0.1858]], grad_fn=<NegBackward0>), arm_chosen:2
# 11: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4000, 0.4600]]), gpi: tensor([[-0.2046, -0.1973, -0.1972]], grad_fn=<NegBackward0>), arm_chosen:2
# 12: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4600, 0.4400]]), gpi: tensor([[-0.1967, -0.2008, -0.2015]], grad_fn=<NegBackward0>), arm_chosen:0
# 13: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4700]]), gpi: tensor([[-0.1919, -0.1991, -0.1929]], grad_fn=<NegBackward0>), arm_chosen:0
# 14: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.4300]]), gpi: tensor([[-0.1937, -0.2010, -0.1921]], grad_fn=<NegBackward0>), arm_chosen:2
# 15: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4300]]), gpi: tensor([[-0.1987, -0.2016, -0.2000]], grad_fn=<NegBackward0>), arm_chosen:0
# 16: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4400]]), gpi: tensor([[-0.2045, -0.2086, -0.2028]], grad_fn=<NegBackward0>), arm_chosen:2
# 17: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4400]]), gpi: tensor([[-0.1985, -0.2078, -0.1981]], grad_fn=<NegBackward0>), arm_chosen:2
# 18: dp: tensor([[0.2500, 0.2503, 0.2501]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4800]]), gpi: tensor([[-0.2027, -0.2004, -0.1953]], grad_fn=<NegBackward0>), arm_chosen:2
# 19: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.4800]]), gpi: tensor([[-0.2064, -0.1968, -0.2054]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4300, 0.4600]]), gpi: tensor([[-0.1913, -0.2056, -0.1934]], grad_fn=<NegBackward0>), arm_chosen:0
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4600]]), gpi: tensor([[-0.1991, -0.1934, -0.1949]], grad_fn=<NegBackward0>), arm_chosen:1
# 22: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4600, 0.4500]]), gpi: tensor([[-0.1975, -0.2039, -0.1925]], grad_fn=<NegBackward0>), arm_chosen:2
# 23: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4800]]), gpi: tensor([[-0.1965, -0.1968, -0.1955]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4800]]), gpi: tensor([[-0.1933, -0.1912, -0.1954]], grad_fn=<NegBackward0>), arm_chosen:1
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4400]]), gpi: tensor([[-0.1986, -0.1928, -0.1926]], grad_fn=<NegBackward0>), arm_chosen:2
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4800, 0.4700]]), gpi: tensor([[-0.2068, -0.2122, -0.1893]], grad_fn=<NegBackward0>), arm_chosen:2
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4900, 0.4600]]), gpi: tensor([[-0.2008, -0.1987, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:1
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5300, 0.4400, 0.4400]]), gpi: tensor([[-0.2080, -0.1961, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:2
# 29: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4600]]), gpi: tensor([[-0.2011, -0.1990, -0.1952]], grad_fn=<NegBackward0>), arm_chosen:2
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4500, 0.4200]]), gpi: tensor([[-0.2000, -0.2094, -0.1968]], grad_fn=<NegBackward0>), arm_chosen:2
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4400]]), gpi: tensor([[-0.2091, -0.1934, -0.2024]], grad_fn=<NegBackward0>), arm_chosen:1
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4500, 0.4200]]), gpi: tensor([[-0.1894, -0.2172, -0.1902]], grad_fn=<NegBackward0>), arm_chosen:0
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4800]]), gpi: tensor([[-0.1952, -0.2032, -0.2001]], grad_fn=<NegBackward0>), arm_chosen:0
# 34: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4800, 0.4300]]), gpi: tensor([[-0.1921, -0.2025, -0.1966]], grad_fn=<NegBackward0>), arm_chosen:0
# 35: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4400]]), gpi: tensor([[-0.1977, -0.1935, -0.2007]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.2693, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.4400]]), gpi: tensor([[-0.2041, -0.1803, -0.1919]], grad_fn=<NegBackward0>), arm_chosen:1
# 37: dp: tensor([[0.2500, 0.2864, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.4400]]), gpi: tensor([[-0.1975, -0.1617, -0.1956]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.3017, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4600]]), gpi: tensor([[-0.1953, -0.1510, -0.2061]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.3287, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4300]]), gpi: tensor([[-0.2011, -0.1280, -0.1976]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.3610, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.4400]]), gpi: tensor([[-0.1976, -0.0922, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.3923, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4600, 0.4600]]), gpi: tensor([[-0.2045, -0.0524, -0.1937]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.4183, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4200]]), gpi: tensor([[-0.2052, -0.0258, -0.1848]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.4374, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4400]]), gpi: tensor([[-0.1937, -0.0134, -0.2001]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.4471, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4600, 0.4500]]), gpi: tensor([[-0.2024, -0.0117, -0.1951]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.4514, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3900, 0.4300]]), gpi: tensor([[-0.2028,  0.0066, -0.1984]], grad_fn=<NegBackward0>), arm_chosen:1
# 46: dp: tensor([[0.2500, 0.4535, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4800, 0.4400]]), gpi: tensor([[-0.2046,  0.0092, -0.1960]], grad_fn=<NegBackward0>), arm_chosen:1
# 47: dp: tensor([[0.2500, 0.4537, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.4700]]), gpi: tensor([[-0.1971,  0.0023, -0.2030]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.4510, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4900, 0.4700]]), gpi: tensor([[-0.1999, -0.0020, -0.2065]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.4473, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.4500]]), gpi: tensor([[-0.1954, -0.0011, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 50: dp: tensor([[0.2500, 0.4389, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4300]]), gpi: tensor([[-0.1963, -0.0176, -0.1893]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.4214, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3900, 0.4800]]), gpi: tensor([[-0.1994, -0.0362, -0.2091]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.3945, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4900]]), gpi: tensor([[-0.2059, -0.0574, -0.2008]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3692, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4600]]), gpi: tensor([[-0.2011, -0.0724, -0.2004]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3462, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4900, 0.4100]]), gpi: tensor([[-0.1968, -0.1012, -0.1966]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3194, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4600]]), gpi: tensor([[-0.2018, -0.1419, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.2952, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4500]]), gpi: tensor([[-0.1813, -0.1571, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.2757, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4200]]), gpi: tensor([[-0.2023, -0.1711, -0.1874]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.2697, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4500]]), gpi: tensor([[-0.1948, -0.1828, -0.2081]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.2669, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.4600]]), gpi: tensor([[-0.1984, -0.1820, -0.2031]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.2661, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4500]]), gpi: tensor([[-0.1965, -0.1824, -0.2036]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2500, 0.2671, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4400]]), gpi: tensor([[-0.1966, -0.1760, -0.2064]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2500, 0.2686, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4600, 0.4600]]), gpi: tensor([[-0.1979, -0.1839, -0.2075]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2500, 0.2734, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4600, 0.4200]]), gpi: tensor([[-0.2041, -0.1695, -0.1950]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.2782, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4100]]), gpi: tensor([[-0.1926, -0.1782, -0.1954]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.2833, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4300]]), gpi: tensor([[-0.1980, -0.1571, -0.2029]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2500, 0.2879, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4600]]), gpi: tensor([[-0.1990, -0.1592, -0.1980]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.2918, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4700]]), gpi: tensor([[-0.1985, -0.1470, -0.2111]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2500, 0.2930, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4700, 0.4400]]), gpi: tensor([[-0.2011, -0.1626, -0.1965]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.2958, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4000]]), gpi: tensor([[-0.2062, -0.1502, -0.1998]], grad_fn=<NegBackward0>), arm_chosen:1
# 70: dp: tensor([[0.2500, 0.2973, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.4500]]), gpi: tensor([[-0.2017, -0.1485, -0.2023]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2500, 0.2960, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4500]]), gpi: tensor([[-0.2034, -0.1592, -0.2034]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2500, 0.2919, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4400]]), gpi: tensor([[-0.1902, -0.1617, -0.1939]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2500, 0.2941, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4100, 0.4400]]), gpi: tensor([[-0.1971, -0.1482, -0.1905]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2500, 0.2959, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.4200]]), gpi: tensor([[-0.2058, -0.1536, -0.1847]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2500, 0.2996, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4200, 0.4100]]), gpi: tensor([[-0.2071, -0.1462, -0.1943]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2500, 0.3075, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4400, 0.4200]]), gpi: tensor([[-0.1939, -0.1303, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2500, 0.3112, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.4300]]), gpi: tensor([[-0.1872, -0.1452, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2500, 0.3136, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4200]]), gpi: tensor([[-0.2057, -0.1356, -0.1998]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2500, 0.3151, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4600, 0.4600]]), gpi: tensor([[-0.1937, -0.1216, -0.1952]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2500, 0.3176, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4500, 0.4400]]), gpi: tensor([[-0.2018, -0.1372, -0.2021]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2500, 0.3180, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4700]]), gpi: tensor([[-0.1978, -0.1196, -0.1888]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2500, 0.3169, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.4900]]), gpi: tensor([[-0.1933, -0.1293, -0.2069]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2500, 0.3139, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.4600]]), gpi: tensor([[-0.2032, -0.1280, -0.1985]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2500, 0.3089, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4300]]), gpi: tensor([[-0.1993, -0.1321, -0.1941]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2500, 0.3030, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4100, 0.4200]]), gpi: tensor([[-0.1994, -0.1362, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2500, 0.2912, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4100, 0.4900]]), gpi: tensor([[-0.2063, -0.1538, -0.1898]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2500, 0.2839, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.4100]]), gpi: tensor([[-0.2041, -0.1751, -0.1926]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2500, 0.2837, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4500]]), gpi: tensor([[-0.2059, -0.1635, -0.2126]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2500, 0.2855, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4700]]), gpi: tensor([[-0.2104, -0.1633, -0.2111]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2500, 0.2905, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4400]]), gpi: tensor([[-0.1927, -0.1618, -0.1905]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2500, 0.2980, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4900]]), gpi: tensor([[-0.2099, -0.1528, -0.2110]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2500, 0.3038, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4300, 0.4400]]), gpi: tensor([[-0.1985, -0.1405, -0.2015]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2500, 0.3076, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4800, 0.4200]]), gpi: tensor([[-0.2013, -0.1331, -0.1944]], grad_fn=<NegBackward0>), arm_chosen:1
# 94: dp: tensor([[0.2500, 0.3094, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4800]]), gpi: tensor([[-0.1950, -0.1413, -0.1963]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2500, 0.3105, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4700, 0.4400]]), gpi: tensor([[-0.2147, -0.1524, -0.1988]], grad_fn=<NegBackward0>), arm_chosen:1
# 96: dp: tensor([[0.2500, 0.3089, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4200, 0.4500]]), gpi: tensor([[-0.1980, -0.1376, -0.2005]], grad_fn=<NegBackward0>), arm_chosen:1
# 97: dp: tensor([[0.2500, 0.3059, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4800]]), gpi: tensor([[-0.1987, -0.1507, -0.1982]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2500, 0.3013, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4500]]), gpi: tensor([[-0.1915, -0.1584, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2500, 0.2992, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4500]]), gpi: tensor([[-0.1982, -0.1515, -0.2042]], grad_fn=<NegBackward0>), arm_chosen:1
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4900, 0.4700]]), gpi: tensor([[-0.2076, -0.1997, -0.2061]], grad_fn=<NegBackward0>), arm_chosen:1
# 1: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4200]]), gpi: tensor([[-0.1972, -0.1938, -0.1876]], grad_fn=<NegBackward0>), arm_chosen:2
# 2: dp: tensor([[0.2503, 0.2503, 0.2756]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4000, 0.4200]]), gpi: tensor([[-0.1930, -0.1943, -0.1726]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2503, 0.2503, 0.2727]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4600]]), gpi: tensor([[-0.2033, -0.2058, -0.1836]], grad_fn=<NegBackward0>), arm_chosen:2
# 4: dp: tensor([[0.2503, 0.2503, 0.2576]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.4500]]), gpi: tensor([[-0.1992, -0.2124, -0.1903]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4100, 0.4800]]), gpi: tensor([[-0.1912, -0.1881, -0.1917]], grad_fn=<NegBackward0>), arm_chosen:1
# 6: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.4200]]), gpi: tensor([[-0.2036, -0.2031, -0.1973]], grad_fn=<NegBackward0>), arm_chosen:2
# 7: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4400, 0.4600]]), gpi: tensor([[-0.1983, -0.1985, -0.1932]], grad_fn=<NegBackward0>), arm_chosen:2
# 8: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.3800, 0.4300]]), gpi: tensor([[-0.2029, -0.1874, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 9: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4800, 0.4200]]), gpi: tensor([[-0.2014, -0.2010, -0.1923]], grad_fn=<NegBackward0>), arm_chosen:2
# 10: dp: tensor([[0.2503, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4800]]), gpi: tensor([[-0.1951, -0.1954, -0.2053]], grad_fn=<NegBackward0>), arm_chosen:0
# 11: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4300]]), gpi: tensor([[-0.1899, -0.1958, -0.2014]], grad_fn=<NegBackward0>), arm_chosen:0
# 12: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4900, 0.4600]]), gpi: tensor([[-0.2037, -0.2082, -0.2020]], grad_fn=<NegBackward0>), arm_chosen:2
# 13: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4700]]), gpi: tensor([[-0.1973, -0.1963, -0.1994]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4200]]), gpi: tensor([[-0.1925, -0.1893, -0.1954]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4700]]), gpi: tensor([[-0.1923, -0.1987, -0.2024]], grad_fn=<NegBackward0>), arm_chosen:0
# 16: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4700]]), gpi: tensor([[-0.2037, -0.1945, -0.1963]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4600]]), gpi: tensor([[-0.1890, -0.1887, -0.2000]], grad_fn=<NegBackward0>), arm_chosen:1
# 18: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.4500]]), gpi: tensor([[-0.1974, -0.2037, -0.1933]], grad_fn=<NegBackward0>), arm_chosen:2
# 19: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.3800]]), gpi: tensor([[-0.1931, -0.1936, -0.1914]], grad_fn=<NegBackward0>), arm_chosen:2
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4000, 0.4700]]), gpi: tensor([[-0.2011, -0.1934, -0.2041]], grad_fn=<NegBackward0>), arm_chosen:1
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4400, 0.4100]]), gpi: tensor([[-0.1922, -0.1964, -0.1985]], grad_fn=<NegBackward0>), arm_chosen:0
# 22: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4200]]), gpi: tensor([[-0.1996, -0.2139, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:0
# 23: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.4500]]), gpi: tensor([[-0.2147, -0.2005, -0.1994]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4400]]), gpi: tensor([[-0.2041, -0.2046, -0.1921]], grad_fn=<NegBackward0>), arm_chosen:2
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4400]]), gpi: tensor([[-0.1940, -0.2017, -0.2004]], grad_fn=<NegBackward0>), arm_chosen:0
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4300]]), gpi: tensor([[-0.2032, -0.2020, -0.2027]], grad_fn=<NegBackward0>), arm_chosen:1
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4300]]), gpi: tensor([[-0.1920, -0.1985, -0.2014]], grad_fn=<NegBackward0>), arm_chosen:0
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4200]]), gpi: tensor([[-0.2060, -0.1962, -0.1961]], grad_fn=<NegBackward0>), arm_chosen:2
# 29: dp: tensor([[0.2500, 0.2503, 0.2523]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4200]]), gpi: tensor([[-0.2033, -0.2044, -0.1836]], grad_fn=<NegBackward0>), arm_chosen:2
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4600, 0.4500]]), gpi: tensor([[-0.1919, -0.2003, -0.1842]], grad_fn=<NegBackward0>), arm_chosen:2
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4600]]), gpi: tensor([[-0.1939, -0.2063, -0.1995]], grad_fn=<NegBackward0>), arm_chosen:0
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.4400]]), gpi: tensor([[-0.1927, -0.1880, -0.2097]], grad_fn=<NegBackward0>), arm_chosen:1
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4400]]), gpi: tensor([[-0.2000, -0.1956, -0.2005]], grad_fn=<NegBackward0>), arm_chosen:1
# 34: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4700, 0.4500]]), gpi: tensor([[-0.2000, -0.2029, -0.1934]], grad_fn=<NegBackward0>), arm_chosen:2
# 35: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4900, 0.5100]]), gpi: tensor([[-0.2115, -0.1992, -0.2107]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.5000, 0.4500]]), gpi: tensor([[-0.1934, -0.2097, -0.1956]], grad_fn=<NegBackward0>), arm_chosen:0
# 37: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4700]]), gpi: tensor([[-0.1993, -0.2081, -0.2019]], grad_fn=<NegBackward0>), arm_chosen:0
# 38: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.4500]]), gpi: tensor([[-0.1869, -0.2100, -0.1900]], grad_fn=<NegBackward0>), arm_chosen:0
# 39: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4700, 0.5000]]), gpi: tensor([[-0.1998, -0.1976, -0.2172]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4300, 0.4600]]), gpi: tensor([[-0.1934, -0.1955, -0.2042]], grad_fn=<NegBackward0>), arm_chosen:0
# 41: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4200, 0.4200]]), gpi: tensor([[-0.1874, -0.1933, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:0
# 42: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.3900]]), gpi: tensor([[-0.2055, -0.2003, -0.1831]], grad_fn=<NegBackward0>), arm_chosen:2
# 43: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4600, 0.4300]]), gpi: tensor([[-0.2013, -0.2027, -0.1931]], grad_fn=<NegBackward0>), arm_chosen:2
# 44: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.5100]]), gpi: tensor([[-0.2044, -0.1996, -0.2101]], grad_fn=<NegBackward0>), arm_chosen:1
# 45: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.5100, 0.4500]]), gpi: tensor([[-0.1950, -0.1974, -0.1968]], grad_fn=<NegBackward0>), arm_chosen:0
# 46: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4300]]), gpi: tensor([[-0.1920, -0.1985, -0.2014]], grad_fn=<NegBackward0>), arm_chosen:0
# 47: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.4000]]), gpi: tensor([[-0.2041, -0.1988, -0.1903]], grad_fn=<NegBackward0>), arm_chosen:2
# 48: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4700]]), gpi: tensor([[-0.1923, -0.1903, -0.2075]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4500]]), gpi: tensor([[-0.2003, -0.1973, -0.1907]], grad_fn=<NegBackward0>), arm_chosen:2
# 50: dp: tensor([[0.2500, 0.2503, 0.2543]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4400]]), gpi: tensor([[-0.1990, -0.1861, -0.1837]], grad_fn=<NegBackward0>), arm_chosen:2
# 51: dp: tensor([[0.2500, 0.2503, 0.2582]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4200, 0.4200]]), gpi: tensor([[-0.1881, -0.1979, -0.1876]], grad_fn=<NegBackward0>), arm_chosen:2
# 52: dp: tensor([[0.2500, 0.2503, 0.2617]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4500]]), gpi: tensor([[-0.1992, -0.2091, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:2
# 53: dp: tensor([[0.2500, 0.2503, 0.2649]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4800, 0.4300]]), gpi: tensor([[-0.2023, -0.2080, -0.1734]], grad_fn=<NegBackward0>), arm_chosen:2
# 54: dp: tensor([[0.2500, 0.2503, 0.2679]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.4400]]), gpi: tensor([[-0.1920, -0.1921, -0.1823]], grad_fn=<NegBackward0>), arm_chosen:2
# 55: dp: tensor([[0.2500, 0.2503, 0.2705]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4400]]), gpi: tensor([[-0.1940, -0.1964, -0.1853]], grad_fn=<NegBackward0>), arm_chosen:2
# 56: dp: tensor([[0.2500, 0.2503, 0.2729]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4200, 0.4500]]), gpi: tensor([[-0.1963, -0.1941, -0.1799]], grad_fn=<NegBackward0>), arm_chosen:2
# 57: dp: tensor([[0.2500, 0.2503, 0.2751]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4400]]), gpi: tensor([[-0.2122, -0.1894, -0.1740]], grad_fn=<NegBackward0>), arm_chosen:2
# 58: dp: tensor([[0.2500, 0.2503, 0.2770]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4500, 0.4500]]), gpi: tensor([[-0.1848, -0.1913, -0.1645]], grad_fn=<NegBackward0>), arm_chosen:2
# 59: dp: tensor([[0.2500, 0.2503, 0.2788]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4700]]), gpi: tensor([[-0.1997, -0.2004, -0.1720]], grad_fn=<NegBackward0>), arm_chosen:2
# 60: dp: tensor([[0.2500, 0.2503, 0.2804]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4500]]), gpi: tensor([[-0.1972, -0.1992, -0.1634]], grad_fn=<NegBackward0>), arm_chosen:2
# 61: dp: tensor([[0.2500, 0.2503, 0.2819]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4800]]), gpi: tensor([[-0.2006, -0.2022, -0.1659]], grad_fn=<NegBackward0>), arm_chosen:2
# 62: dp: tensor([[0.2500, 0.2503, 0.2832]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4400, 0.4300]]), gpi: tensor([[-0.1986, -0.1936, -0.1663]], grad_fn=<NegBackward0>), arm_chosen:2
# 63: dp: tensor([[0.2500, 0.2503, 0.2844]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4300]]), gpi: tensor([[-0.2041, -0.2015, -0.1632]], grad_fn=<NegBackward0>), arm_chosen:2
# 64: dp: tensor([[0.2500, 0.2503, 0.2855]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4000]]), gpi: tensor([[-0.1911, -0.1958, -0.1549]], grad_fn=<NegBackward0>), arm_chosen:2
# 65: dp: tensor([[0.2500, 0.2503, 0.2865]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4300, 0.4100]]), gpi: tensor([[-0.2051, -0.1953, -0.1681]], grad_fn=<NegBackward0>), arm_chosen:2
# 66: dp: tensor([[0.2500, 0.2503, 0.2874]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4300]]), gpi: tensor([[-0.1936, -0.1934, -0.1538]], grad_fn=<NegBackward0>), arm_chosen:2
# 67: dp: tensor([[0.2500, 0.2503, 0.2882]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4600]]), gpi: tensor([[-0.1996, -0.1973, -0.1609]], grad_fn=<NegBackward0>), arm_chosen:2
# 68: dp: tensor([[0.2500, 0.2503, 0.2889]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4400, 0.4800]]), gpi: tensor([[-0.2129, -0.1974, -0.1690]], grad_fn=<NegBackward0>), arm_chosen:2
# 69: dp: tensor([[0.2500, 0.2503, 0.2896]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4800]]), gpi: tensor([[-0.1972, -0.2022, -0.1611]], grad_fn=<NegBackward0>), arm_chosen:2
# 70: dp: tensor([[0.2500, 0.2503, 0.2902]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.4400]]), gpi: tensor([[-0.1915, -0.2008, -0.1648]], grad_fn=<NegBackward0>), arm_chosen:2
# 71: dp: tensor([[0.2500, 0.2503, 0.2907]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4800]]), gpi: tensor([[-0.2036, -0.1903, -0.1560]], grad_fn=<NegBackward0>), arm_chosen:2
# 72: dp: tensor([[0.2500, 0.2503, 0.2912]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4200]]), gpi: tensor([[-0.1934, -0.1969, -0.1553]], grad_fn=<NegBackward0>), arm_chosen:2
# 73: dp: tensor([[0.2500, 0.2503, 0.2917]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4000]]), gpi: tensor([[-0.1993, -0.1919, -0.1526]], grad_fn=<NegBackward0>), arm_chosen:2
# 74: dp: tensor([[0.2500, 0.2503, 0.2921]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4600]]), gpi: tensor([[-0.1992, -0.2048, -0.1568]], grad_fn=<NegBackward0>), arm_chosen:2
# 75: dp: tensor([[0.2500, 0.2503, 0.2925]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4200, 0.4500]]), gpi: tensor([[-0.2077, -0.1970, -0.1617]], grad_fn=<NegBackward0>), arm_chosen:2
# 76: dp: tensor([[0.2500, 0.2503, 0.2928]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4100]]), gpi: tensor([[-0.1940, -0.1955, -0.1475]], grad_fn=<NegBackward0>), arm_chosen:2
# 77: dp: tensor([[0.2500, 0.2503, 0.2931]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4400]]), gpi: tensor([[-0.2007, -0.1886, -0.1565]], grad_fn=<NegBackward0>), arm_chosen:2
# 78: dp: tensor([[0.2500, 0.2503, 0.2934]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4500]]), gpi: tensor([[-0.1949, -0.2039, -0.1651]], grad_fn=<NegBackward0>), arm_chosen:2
# 79: dp: tensor([[0.2500, 0.2503, 0.2936]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4500]]), gpi: tensor([[-0.2088, -0.1971, -0.1600]], grad_fn=<NegBackward0>), arm_chosen:2
# 80: dp: tensor([[0.2500, 0.2503, 0.2938]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4600]]), gpi: tensor([[-0.1980, -0.1894, -0.1523]], grad_fn=<NegBackward0>), arm_chosen:2
# 81: dp: tensor([[0.2500, 0.2503, 0.2940]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4600]]), gpi: tensor([[-0.2033, -0.1983, -0.1566]], grad_fn=<NegBackward0>), arm_chosen:2
# 82: dp: tensor([[0.2500, 0.2503, 0.2942]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4700]]), gpi: tensor([[-0.2016, -0.1972, -0.1514]], grad_fn=<NegBackward0>), arm_chosen:2
# 83: dp: tensor([[0.2500, 0.2503, 0.2944]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4500, 0.4400]]), gpi: tensor([[-0.1996, -0.2046, -0.1586]], grad_fn=<NegBackward0>), arm_chosen:2
# 84: dp: tensor([[0.2500, 0.2503, 0.2945]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4100]]), gpi: tensor([[-0.1970, -0.1963, -0.1514]], grad_fn=<NegBackward0>), arm_chosen:2
# 85: dp: tensor([[0.2500, 0.2503, 0.2947]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.4200]]), gpi: tensor([[-0.1905, -0.1962, -0.1518]], grad_fn=<NegBackward0>), arm_chosen:2
# 86: dp: tensor([[0.2500, 0.2503, 0.2948]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.5100]]), gpi: tensor([[-0.1916, -0.1964, -0.1581]], grad_fn=<NegBackward0>), arm_chosen:2
# 87: dp: tensor([[0.2500, 0.2503, 0.2949]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4500]]), gpi: tensor([[-0.1967, -0.1882, -0.1429]], grad_fn=<NegBackward0>), arm_chosen:2
# 88: dp: tensor([[0.2500, 0.2503, 0.2950]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4300, 0.4600]]), gpi: tensor([[-0.2056, -0.1978, -0.1543]], grad_fn=<NegBackward0>), arm_chosen:2
# 89: dp: tensor([[0.2500, 0.2503, 0.2951]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4600, 0.4300]]), gpi: tensor([[-0.2066, -0.2075, -0.1538]], grad_fn=<NegBackward0>), arm_chosen:2
# 90: dp: tensor([[0.2500, 0.2503, 0.2952]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4900, 0.4800]]), gpi: tensor([[-0.1953, -0.1994, -0.1608]], grad_fn=<NegBackward0>), arm_chosen:2
# 91: dp: tensor([[0.2500, 0.2503, 0.2953]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4600]]), gpi: tensor([[-0.1947, -0.2025, -0.1576]], grad_fn=<NegBackward0>), arm_chosen:2
# 92: dp: tensor([[0.2500, 0.2503, 0.2953]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.4200]]), gpi: tensor([[-0.1968, -0.1929, -0.1503]], grad_fn=<NegBackward0>), arm_chosen:2
# 93: dp: tensor([[0.2500, 0.2503, 0.2954]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4500, 0.4600]]), gpi: tensor([[-0.1959, -0.1935, -0.1498]], grad_fn=<NegBackward0>), arm_chosen:2
# 94: dp: tensor([[0.2500, 0.2503, 0.2954]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4500]]), gpi: tensor([[-0.2044, -0.1875, -0.1658]], grad_fn=<NegBackward0>), arm_chosen:2
# 95: dp: tensor([[0.2500, 0.2503, 0.2955]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4600, 0.4300]]), gpi: tensor([[-0.1926, -0.1950, -0.1582]], grad_fn=<NegBackward0>), arm_chosen:2
# 96: dp: tensor([[0.2500, 0.2503, 0.2955]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4900, 0.4500]]), gpi: tensor([[-0.2043, -0.2037, -0.1500]], grad_fn=<NegBackward0>), arm_chosen:2
# 97: dp: tensor([[0.2500, 0.2503, 0.2956]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4800]]), gpi: tensor([[-0.2104, -0.1834, -0.1532]], grad_fn=<NegBackward0>), arm_chosen:2
# 98: dp: tensor([[0.2500, 0.2503, 0.2956]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4800]]), gpi: tensor([[-0.1983, -0.1965, -0.1551]], grad_fn=<NegBackward0>), arm_chosen:2
# 99: dp: tensor([[0.2500, 0.2503, 0.2956]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4500]]), gpi: tensor([[-0.2017, -0.2005, -0.1597]], grad_fn=<NegBackward0>), arm_chosen:2
# 0: dp: tensor([[0.2503, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4100, 0.4300]]), gpi: tensor([[-0.1843, -0.1969, -0.1927]], grad_fn=<NegBackward0>), arm_chosen:0
# 1: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4600]]), gpi: tensor([[-0.2107, -0.1950, -0.2019]], grad_fn=<NegBackward0>), arm_chosen:1
# 2: dp: tensor([[0.2500, 0.2503, 0.2503]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4600]]), gpi: tensor([[-0.1977, -0.2064, -0.1971]], grad_fn=<NegBackward0>), arm_chosen:2
# 3: dp: tensor([[0.2500, 0.2503, 0.2702]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4200, 0.4500]]), gpi: tensor([[-0.1879, -0.1972, -0.1742]], grad_fn=<NegBackward0>), arm_chosen:2
# 4: dp: tensor([[0.2500, 0.2503, 0.2695]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4500]]), gpi: tensor([[-0.1867, -0.1995, -0.1829]], grad_fn=<NegBackward0>), arm_chosen:2
# 5: dp: tensor([[0.2500, 0.2503, 0.2683]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4400]]), gpi: tensor([[-0.1973, -0.1991, -0.1752]], grad_fn=<NegBackward0>), arm_chosen:2
# 6: dp: tensor([[0.2500, 0.2503, 0.2556]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4000]]), gpi: tensor([[-0.2039, -0.2030, -0.1818]], grad_fn=<NegBackward0>), arm_chosen:2
# 7: dp: tensor([[0.2500, 0.2503, 0.2548]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4700]]), gpi: tensor([[-0.2014, -0.2014, -0.1996]], grad_fn=<NegBackward0>), arm_chosen:2
# 8: dp: tensor([[0.2500, 0.2503, 0.2619]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4300, 0.4000]]), gpi: tensor([[-0.1947, -0.1931, -0.1753]], grad_fn=<NegBackward0>), arm_chosen:2
# 9: dp: tensor([[0.2500, 0.2503, 0.2600]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4600]]), gpi: tensor([[-0.2011, -0.1990, -0.1852]], grad_fn=<NegBackward0>), arm_chosen:2
# 10: dp: tensor([[0.2500, 0.2503, 0.2571]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4200, 0.4400]]), gpi: tensor([[-0.1890, -0.1844, -0.1956]], grad_fn=<NegBackward0>), arm_chosen:1
# 11: dp: tensor([[0.2500, 0.2503, 0.2545]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4500]]), gpi: tensor([[-0.1990, -0.1916, -0.1902]], grad_fn=<NegBackward0>), arm_chosen:2
# 12: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4300, 0.4400]]), gpi: tensor([[-0.2023, -0.2034, -0.2060]], grad_fn=<NegBackward0>), arm_chosen:0
# 13: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4900]]), gpi: tensor([[-0.2063, -0.1955, -0.2002]], grad_fn=<NegBackward0>), arm_chosen:1
# 14: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4600]]), gpi: tensor([[-0.2039, -0.1970, -0.1985]], grad_fn=<NegBackward0>), arm_chosen:1
# 15: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.4500]]), gpi: tensor([[-0.2039, -0.1957, -0.2028]], grad_fn=<NegBackward0>), arm_chosen:1
# 16: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4200]]), gpi: tensor([[-0.2060, -0.1962, -0.1961]], grad_fn=<NegBackward0>), arm_chosen:2
# 17: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.5100, 0.4000]]), gpi: tensor([[-0.1991, -0.2088, -0.1919]], grad_fn=<NegBackward0>), arm_chosen:2
# 18: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4300, 0.4400]]), gpi: tensor([[-0.1987, -0.1921, -0.1912]], grad_fn=<NegBackward0>), arm_chosen:2
# 19: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4100, 0.4300]]), gpi: tensor([[-0.2061, -0.1967, -0.1993]], grad_fn=<NegBackward0>), arm_chosen:1
# 20: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4500]]), gpi: tensor([[-0.1874, -0.1958, -0.2058]], grad_fn=<NegBackward0>), arm_chosen:0
# 21: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4700, 0.4400]]), gpi: tensor([[-0.1996, -0.1963, -0.1945]], grad_fn=<NegBackward0>), arm_chosen:2
# 22: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4600]]), gpi: tensor([[-0.1933, -0.1837, -0.2072]], grad_fn=<NegBackward0>), arm_chosen:1
# 23: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.4600]]), gpi: tensor([[-0.1936, -0.1919, -0.1984]], grad_fn=<NegBackward0>), arm_chosen:1
# 24: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4600, 0.4300]]), gpi: tensor([[-0.1932, -0.1999, -0.1933]], grad_fn=<NegBackward0>), arm_chosen:0
# 25: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4800, 0.4500]]), gpi: tensor([[-0.2012, -0.1892, -0.1978]], grad_fn=<NegBackward0>), arm_chosen:1
# 26: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4500, 0.4600]]), gpi: tensor([[-0.1895, -0.1925, -0.1970]], grad_fn=<NegBackward0>), arm_chosen:0
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.5000]]), gpi: tensor([[-0.2052, -0.2027, -0.1992]], grad_fn=<NegBackward0>), arm_chosen:2
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4800]]), gpi: tensor([[-0.2010, -0.1955, -0.1979]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4600]]), gpi: tensor([[-0.1929, -0.1984, -0.1971]], grad_fn=<NegBackward0>), arm_chosen:0
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4700]]), gpi: tensor([[-0.1978, -0.2018, -0.2053]], grad_fn=<NegBackward0>), arm_chosen:0
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.5000]]), gpi: tensor([[-0.1971, -0.2018, -0.2113]], grad_fn=<NegBackward0>), arm_chosen:0
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4500]]), gpi: tensor([[-0.2005, -0.1999, -0.1937]], grad_fn=<NegBackward0>), arm_chosen:2
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4200]]), gpi: tensor([[-0.2104, -0.1965, -0.1916]], grad_fn=<NegBackward0>), arm_chosen:2
# 34: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4400, 0.4600]]), gpi: tensor([[-0.1896, -0.1940, -0.1995]], grad_fn=<NegBackward0>), arm_chosen:0
# 35: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4700]]), gpi: tensor([[-0.1899, -0.1864, -0.1899]], grad_fn=<NegBackward0>), arm_chosen:1
# 36: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.3900]]), gpi: tensor([[-0.1907, -0.2052, -0.1944]], grad_fn=<NegBackward0>), arm_chosen:0
# 37: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4300]]), gpi: tensor([[-0.2013, -0.1950, -0.1933]], grad_fn=<NegBackward0>), arm_chosen:2
# 38: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.5300, 0.4400]]), gpi: tensor([[-0.1945, -0.2032, -0.2027]], grad_fn=<NegBackward0>), arm_chosen:0
# 39: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4800]]), gpi: tensor([[-0.1998, -0.1969, -0.2089]], grad_fn=<NegBackward0>), arm_chosen:1
# 40: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4700, 0.4700]]), gpi: tensor([[-0.2041, -0.1993, -0.2056]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4000, 0.4400]]), gpi: tensor([[-0.2019, -0.1962, -0.1967]], grad_fn=<NegBackward0>), arm_chosen:1
# 42: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4000, 0.4500]]), gpi: tensor([[-0.2007, -0.1914, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 43: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4400, 0.5100]]), gpi: tensor([[-0.1941, -0.1918, -0.2077]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4700, 0.4300]]), gpi: tensor([[-0.1911, -0.2014, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:0
# 45: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.5100, 0.4300]]), gpi: tensor([[-0.2007, -0.2074, -0.1936]], grad_fn=<NegBackward0>), arm_chosen:2
# 46: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3900, 0.4400, 0.4400]]), gpi: tensor([[-0.1988, -0.2084, -0.2018]], grad_fn=<NegBackward0>), arm_chosen:0
# 47: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4200, 0.4200]]), gpi: tensor([[-0.1988, -0.1955, -0.1848]], grad_fn=<NegBackward0>), arm_chosen:2
# 48: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4600, 0.4900]]), gpi: tensor([[-0.2011, -0.2029, -0.2049]], grad_fn=<NegBackward0>), arm_chosen:0
# 49: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4300, 0.4800]]), gpi: tensor([[-0.1877, -0.2021, -0.2060]], grad_fn=<NegBackward0>), arm_chosen:0
# 50: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.4500]]), gpi: tensor([[-0.1995, -0.1971, -0.2034]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.2724, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4300, 0.4300]]), gpi: tensor([[-0.2001, -0.1817, -0.1884]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.3021, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4900, 0.4600]]), gpi: tensor([[-0.1983, -0.1441, -0.1909]], grad_fn=<NegBackward0>), arm_chosen:1
# ...
# 16: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4100, 0.4100]]), gpi: tensor([[-0.2072, -0.1863, -0.1956]], grad_fn=<NegBackward0>), arm_chosen:1
# 17: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4500]]), gpi: tensor([[-0.1918, -0.2025, -0.2067]], grad_fn=<NegBackward0>), arm_chosen:0
# 18: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4100]]), gpi: tensor([[-0.2012, -0.2032, -0.1865]], grad_fn=<NegBackward0>), arm_chosen:2
# 19: dp: tensor([[0.2500, 0.2503, 0.2514]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4800, 0.4400]]), gpi: tensor([[-0.1936, -0.1969, -0.1908]], grad_fn=<NegBackward0>), arm_chosen:2
# 20: dp: tensor([[0.2500, 0.2503, 0.2557]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4200, 0.4500]]), gpi: tensor([[-0.1905, -0.1915, -0.1914]], grad_fn=<NegBackward0>), arm_chosen:0
# 21: dp: tensor([[0.2500, 0.2503, 0.2596]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4600]]), gpi: tensor([[-0.1977, -0.2017, -0.1899]], grad_fn=<NegBackward0>), arm_chosen:2
# 22: dp: tensor([[0.2500, 0.2503, 0.2658]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4600]]), gpi: tensor([[-0.1941, -0.2027, -0.1833]], grad_fn=<NegBackward0>), arm_chosen:2
# 23: dp: tensor([[0.2500, 0.2503, 0.2658]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4400, 0.4900]]), gpi: tensor([[-0.1965, -0.1963, -0.1912]], grad_fn=<NegBackward0>), arm_chosen:2
# 24: dp: tensor([[0.2500, 0.2503, 0.2635]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4300, 0.4700]]), gpi: tensor([[-0.2015, -0.1907, -0.1835]], grad_fn=<NegBackward0>), arm_chosen:2
# 25: dp: tensor([[0.2500, 0.2503, 0.2630]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4800]]), gpi: tensor([[-0.2036, -0.1944, -0.1819]], grad_fn=<NegBackward0>), arm_chosen:2
# 26: dp: tensor([[0.2500, 0.2503, 0.2592]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.4500]]), gpi: tensor([[-0.1904, -0.1894, -0.1875]], grad_fn=<NegBackward0>), arm_chosen:2
# 27: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4800, 0.4800]]), gpi: tensor([[-0.1945, -0.2023, -0.1952]], grad_fn=<NegBackward0>), arm_chosen:0
# 28: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4500]]), gpi: tensor([[-0.1948, -0.1913, -0.2040]], grad_fn=<NegBackward0>), arm_chosen:1
# 29: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5100, 0.4400, 0.4800]]), gpi: tensor([[-0.2019, -0.1917, -0.2081]], grad_fn=<NegBackward0>), arm_chosen:1
# 30: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4300]]), gpi: tensor([[-0.2011, -0.2060, -0.1976]], grad_fn=<NegBackward0>), arm_chosen:2
# 31: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4600, 0.4200]]), gpi: tensor([[-0.2008, -0.2050, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:2
# 32: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4500]]), gpi: tensor([[-0.1911, -0.2038, -0.1973]], grad_fn=<NegBackward0>), arm_chosen:0
# 33: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.3800, 0.4700, 0.4400]]), gpi: tensor([[-0.1918, -0.2013, -0.1934]], grad_fn=<NegBackward0>), arm_chosen:0
# 34: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.4500]]), gpi: tensor([[-0.2039, -0.1925, -0.2070]], grad_fn=<NegBackward0>), arm_chosen:1
# 35: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4400, 0.4500]]), gpi: tensor([[-0.1945, -0.2007, -0.1964]], grad_fn=<NegBackward0>), arm_chosen:0
# 36: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4300, 0.4400]]), gpi: tensor([[-0.1981, -0.1972, -0.1929]], grad_fn=<NegBackward0>), arm_chosen:2
# 37: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5200, 0.4600, 0.4800]]), gpi: tensor([[-0.2040, -0.1986, -0.1998]], grad_fn=<NegBackward0>), arm_chosen:1
# 38: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.4900]]), gpi: tensor([[-0.2060, -0.1945, -0.2044]], grad_fn=<NegBackward0>), arm_chosen:1
# 39: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4800, 0.4500]]), gpi: tensor([[-0.1911, -0.2113, -0.1947]], grad_fn=<NegBackward0>), arm_chosen:0
# 40: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4200, 0.4800]]), gpi: tensor([[-0.2004, -0.1919, -0.2020]], grad_fn=<NegBackward0>), arm_chosen:1
# 41: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4500]]), gpi: tensor([[-0.1985, -0.1994, -0.2074]], grad_fn=<NegBackward0>), arm_chosen:0
# 42: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4800, 0.4500]]), gpi: tensor([[-0.2105, -0.2003, -0.1999]], grad_fn=<NegBackward0>), arm_chosen:2
# 43: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4400]]), gpi: tensor([[-0.1987, -0.1861, -0.1920]], grad_fn=<NegBackward0>), arm_chosen:1
# 44: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4300, 0.4600]]), gpi: tensor([[-0.1884, -0.1978, -0.1985]], grad_fn=<NegBackward0>), arm_chosen:0
# 45: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4100]]), gpi: tensor([[-0.1959, -0.2057, -0.1984]], grad_fn=<NegBackward0>), arm_chosen:0
# 46: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4100, 0.4200, 0.4400]]), gpi: tensor([[-0.1907, -0.1981, -0.1993]], grad_fn=<NegBackward0>), arm_chosen:0
# 47: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4000, 0.3900]]), gpi: tensor([[-0.1989, -0.1865, -0.1887]], grad_fn=<NegBackward0>), arm_chosen:1
# 48: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4000, 0.4400]]), gpi: tensor([[-0.1952, -0.1879, -0.2076]], grad_fn=<NegBackward0>), arm_chosen:1
# 49: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4100, 0.4700]]), gpi: tensor([[-0.1985, -0.2011, -0.2031]], grad_fn=<NegBackward0>), arm_chosen:0
# 50: dp: tensor([[0.2500, 0.2503, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.4200]]), gpi: tensor([[-0.2017, -0.1955, -0.2006]], grad_fn=<NegBackward0>), arm_chosen:1
# 51: dp: tensor([[0.2500, 0.2724, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4700, 0.4700]]), gpi: tensor([[-0.1984, -0.1789, -0.2086]], grad_fn=<NegBackward0>), arm_chosen:1
# 52: dp: tensor([[0.2500, 0.2951, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4000, 0.4700]]), gpi: tensor([[-0.2025, -0.1357, -0.2093]], grad_fn=<NegBackward0>), arm_chosen:1
# 53: dp: tensor([[0.2500, 0.3240, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4900, 0.4400]]), gpi: tensor([[-0.2029, -0.1367, -0.1920]], grad_fn=<NegBackward0>), arm_chosen:1
# 54: dp: tensor([[0.2500, 0.3302, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4400, 0.4700]]), gpi: tensor([[-0.1967, -0.1158, -0.2027]], grad_fn=<NegBackward0>), arm_chosen:1
# 55: dp: tensor([[0.2500, 0.3311, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4600]]), gpi: tensor([[-0.2049, -0.1164, -0.1916]], grad_fn=<NegBackward0>), arm_chosen:1
# 56: dp: tensor([[0.2500, 0.3165, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.4400]]), gpi: tensor([[-0.1900, -0.1390, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:1
# 57: dp: tensor([[0.2500, 0.2956, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4700, 0.4500]]), gpi: tensor([[-0.1951, -0.1557, -0.1974]], grad_fn=<NegBackward0>), arm_chosen:1
# 58: dp: tensor([[0.2500, 0.2809, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4300]]), gpi: tensor([[-0.2077, -0.1707, -0.1979]], grad_fn=<NegBackward0>), arm_chosen:1
# 59: dp: tensor([[0.2500, 0.2794, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4300, 0.4200]]), gpi: tensor([[-0.2025, -0.1683, -0.1941]], grad_fn=<NegBackward0>), arm_chosen:1
# 60: dp: tensor([[0.2500, 0.2820, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4800]]), gpi: tensor([[-0.1948, -0.1644, -0.1870]], grad_fn=<NegBackward0>), arm_chosen:1
# 61: dp: tensor([[0.2500, 0.2908, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4100, 0.4500]]), gpi: tensor([[-0.1919, -0.1556, -0.2022]], grad_fn=<NegBackward0>), arm_chosen:1
# 62: dp: tensor([[0.2500, 0.2983, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4700, 0.4500]]), gpi: tensor([[-0.2012, -0.1552, -0.1905]], grad_fn=<NegBackward0>), arm_chosen:1
# 63: dp: tensor([[0.2500, 0.3054, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4500, 0.4900]]), gpi: tensor([[-0.1917, -0.1397, -0.1948]], grad_fn=<NegBackward0>), arm_chosen:1
# 64: dp: tensor([[0.2500, 0.3057, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4400, 0.4800]]), gpi: tensor([[-0.1995, -0.1361, -0.1935]], grad_fn=<NegBackward0>), arm_chosen:1
# 65: dp: tensor([[0.2500, 0.3071, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4100, 0.4100]]), gpi: tensor([[-0.2019, -0.1224, -0.1905]], grad_fn=<NegBackward0>), arm_chosen:1
# 66: dp: tensor([[0.2500, 0.3090, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4700, 0.4900]]), gpi: tensor([[-0.2033, -0.1352, -0.2087]], grad_fn=<NegBackward0>), arm_chosen:1
# 67: dp: tensor([[0.2500, 0.3040, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4500, 0.4400]]), gpi: tensor([[-0.2040, -0.1480, -0.1973]], grad_fn=<NegBackward0>), arm_chosen:1
# 68: dp: tensor([[0.2500, 0.2958, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4500, 0.3900]]), gpi: tensor([[-0.1938, -0.1564, -0.1930]], grad_fn=<NegBackward0>), arm_chosen:1
# 69: dp: tensor([[0.2500, 0.2856, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4000, 0.4500]]), gpi: tensor([[-0.2060, -0.1544, -0.1965]], grad_fn=<NegBackward0>), arm_chosen:1
# 70: dp: tensor([[0.2500, 0.2797, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4700, 0.4600]]), gpi: tensor([[-0.1998, -0.1706, -0.2026]], grad_fn=<NegBackward0>), arm_chosen:1
# 71: dp: tensor([[0.2500, 0.2772, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4600, 0.3900]]), gpi: tensor([[-0.2042, -0.1742, -0.1918]], grad_fn=<NegBackward0>), arm_chosen:1
# 72: dp: tensor([[0.2500, 0.2870, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4000, 0.4500]]), gpi: tensor([[-0.1898, -0.1622, -0.2045]], grad_fn=<NegBackward0>), arm_chosen:1
# 73: dp: tensor([[0.2500, 0.2954, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4200, 0.4800]]), gpi: tensor([[-0.1994, -0.1418, -0.2009]], grad_fn=<NegBackward0>), arm_chosen:1
# 74: dp: tensor([[0.2500, 0.3023, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.5000, 0.4100, 0.4200]]), gpi: tensor([[-0.2022, -0.1478, -0.1913]], grad_fn=<NegBackward0>), arm_chosen:1
# 75: dp: tensor([[0.2500, 0.3103, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4500]]), gpi: tensor([[-0.2041, -0.1385, -0.2048]], grad_fn=<NegBackward0>), arm_chosen:1
# 76: dp: tensor([[0.2500, 0.3134, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4100, 0.4300]]), gpi: tensor([[-0.2006, -0.1321, -0.2010]], grad_fn=<NegBackward0>), arm_chosen:1
# 77: dp: tensor([[0.2500, 0.3133, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4700, 0.4400]]), gpi: tensor([[-0.2109, -0.1256, -0.1985]], grad_fn=<NegBackward0>), arm_chosen:1
# 78: dp: tensor([[0.2500, 0.3123, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4500, 0.4800]]), gpi: tensor([[-0.2012, -0.1389, -0.2049]], grad_fn=<NegBackward0>), arm_chosen:1
# 79: dp: tensor([[0.2500, 0.3102, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4400, 0.4100]]), gpi: tensor([[-0.2088, -0.1383, -0.1986]], grad_fn=<NegBackward0>), arm_chosen:1
# 80: dp: tensor([[0.2500, 0.3010, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4600, 0.4500]]), gpi: tensor([[-0.2041, -0.1503, -0.1909]], grad_fn=<NegBackward0>), arm_chosen:1
# 81: dp: tensor([[0.2500, 0.2924, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.4500, 0.5000]]), gpi: tensor([[-0.2033, -0.1609, -0.2072]], grad_fn=<NegBackward0>), arm_chosen:1
# 82: dp: tensor([[0.2500, 0.2901, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4200, 0.4200, 0.4400]]), gpi: tensor([[-0.1946, -0.1610, -0.1955]], grad_fn=<NegBackward0>), arm_chosen:1
# 83: dp: tensor([[0.2500, 0.2966, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4500, 0.4300]]), gpi: tensor([[-0.1979, -0.1454, -0.1836]], grad_fn=<NegBackward0>), arm_chosen:1
# 84: dp: tensor([[0.2500, 0.2998, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4800]]), gpi: tensor([[-0.2041, -0.1483, -0.2113]], grad_fn=<NegBackward0>), arm_chosen:1
# 85: dp: tensor([[0.2500, 0.3006, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4400, 0.4700]]), gpi: tensor([[-0.2000, -0.1434, -0.2100]], grad_fn=<NegBackward0>), arm_chosen:1
# 86: dp: tensor([[0.2500, 0.3006, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4800, 0.4300, 0.4700]]), gpi: tensor([[-0.2155, -0.1565, -0.1925]], grad_fn=<NegBackward0>), arm_chosen:1
# 87: dp: tensor([[0.2500, 0.3001, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4100, 0.4700]]), gpi: tensor([[-0.2109, -0.1510, -0.2029]], grad_fn=<NegBackward0>), arm_chosen:1
# 88: dp: tensor([[0.2500, 0.2991, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4300, 0.3900, 0.4800]]), gpi: tensor([[-0.2118, -0.1517, -0.2043]], grad_fn=<NegBackward0>), arm_chosen:1
# 89: dp: tensor([[0.2500, 0.3010, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4700]]), gpi: tensor([[-0.1903, -0.1584, -0.1988]], grad_fn=<NegBackward0>), arm_chosen:1
# 90: dp: tensor([[0.2500, 0.2973, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4600]]), gpi: tensor([[-0.1964, -0.1526, -0.2100]], grad_fn=<NegBackward0>), arm_chosen:1
# 91: dp: tensor([[0.2500, 0.2929, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4400, 0.4600, 0.4400]]), gpi: tensor([[-0.1954, -0.1557, -0.1954]], grad_fn=<NegBackward0>), arm_chosen:1
# 92: dp: tensor([[0.2500, 0.2876, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4900, 0.4400, 0.4400]]), gpi: tensor([[-0.2008, -0.1639, -0.1970]], grad_fn=<NegBackward0>), arm_chosen:1
# 93: dp: tensor([[0.2500, 0.2882, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4700, 0.4900]]), gpi: tensor([[-0.1976, -0.1710, -0.2165]], grad_fn=<NegBackward0>), arm_chosen:1
# 94: dp: tensor([[0.2500, 0.2912, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4500, 0.4600]]), gpi: tensor([[-0.2006, -0.1617, -0.2039]], grad_fn=<NegBackward0>), arm_chosen:1
# 95: dp: tensor([[0.2500, 0.3004, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4600, 0.4600, 0.4500]]), gpi: tensor([[-0.2061, -0.1430, -0.1980]], grad_fn=<NegBackward0>), arm_chosen:1
# 96: dp: tensor([[0.2500, 0.3131, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4500, 0.4400, 0.4400]]), gpi: tensor([[-0.1908, -0.1258, -0.2004]], grad_fn=<NegBackward0>), arm_chosen:1
# 97: dp: tensor([[0.2500, 0.3284, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4000, 0.4800, 0.4200]]), gpi: tensor([[-0.1786, -0.1300, -0.1918]], grad_fn=<NegBackward0>), arm_chosen:1
# 98: dp: tensor([[0.2500, 0.3336, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4600, 0.4300]]), gpi: tensor([[-0.1993, -0.1143, -0.1898]], grad_fn=<NegBackward0>), arm_chosen:1
# 99: dp: tensor([[0.2500, 0.3365, 0.2500]], grad_fn=<MulBackward0>), ip: tensor([[0.4700, 0.4800, 0.4600]]), gpi: tensor([[-0.2037, -0.1229, -0.1947]], grad_fn=<NegBackward0>), arm_chosen:1

# %% [markdown]
# ## Analysis

# %%
mean_picks = {key: torch.mean(avg_counts[key], dim = 0) for key in list(avg_counts.keys())}
IP_avg = {key: torch.mean(ip_monitor[key], dim =0).detach().numpy() for key in list(ip_monitor.keys())}
DP_avg = {key: torch.mean(dp_monitor[key], dim =0).detach().numpy() for key in list(dp_monitor.keys())}
IP_var = np.std(np.stack(list(IP_avg.values()), axis=0),axis = 0)[:,0]
arm_chosen_monitor = arm_chosen_monitor.to(torch.int)

# Computing Accuracy
optimal_probs_per_bin_all = torch.zeros((EPOCHS, BINS))

for i in range(BINS):
    start, end = i * BIN_SIZE, (i + 1) * BIN_SIZE
    correct_choices = torch.sum(arm_chosen_monitor[:, start:end] == BEST_ARM[:,start:end], axis = 1)
    optimal_probs_per_bin_all[:, i] = (correct_choices / BIN_SIZE)

optimal_prob_per_bin = torch.mean(optimal_probs_per_bin_all,axis = 0)
last_bin_prob = optimal_prob_per_bin[-1].item()
mean_prob = torch.mean(optimal_prob_per_bin).item()
mean_reward = torch.mean(reward_monitor, axis = 0)

# %%
BIN = np.arange(BINS)+1


plt.figure(figsize=(5,3))
plt.subplot(231)
for i in DP_avg.keys():
    plt.plot(np.arange(TRIALS), DP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('DP output')
plt.legend(loc = 'upper right')

plt.subplot(232)

for i in mean_picks.keys():
    plt.plot(BIN,mean_picks[i], label = i, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Avg card picks with trials')
plt.xlabel('bins')
plt.legend(loc = 'upper right')

plt.subplot(233)
plt.plot(BIN, optimal_prob_per_bin, marker = '.', markersize = 5)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.title('Accuracy')
plt.ylim(0,1.1)
plt.xlabel('bins')

plt.subplot(234)
for i in IP_avg.keys():
    plt.plot(np.arange(TRIALS), IP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('IP output')
plt.legend(loc = 'upper right')

plt.subplot(235)
plt.plot(np.arange(TRIALS), mean_reward)
# show std as shaded region around
plt.fill_between(np.arange(TRIALS), mean_reward - torch.std(reward_monitor, axis = 0), mean_reward + torch.std(reward_monitor, axis = 0), alpha=0.2)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=0.5)
plt.xlabel('TRIALS')
plt.title('Mean reward')
plt.legend(loc = 'upper right')


print('Accuracy at last bin: ',optimal_prob_per_bin[-1].item())
print('Avg accuracy across bins: ',torch.mean(optimal_prob_per_bin).item())
# Out:
# Accuracy at last bin:  0.1080000028014183
# Avg accuracy across bins:  0.22019998729228973

# %%
random_epochs = np.random.choice(np.arange(EPOCHS), size = 2)
i = 1
plt.figure(figsize=(3,1))
for e in random_epochs:
    plt.subplot(1,2,i)
    colors = np.where(np.isin(arm_chosen_monitor[e],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRIALS), arm_chosen_monitor[e], marker = '|', s = 20)
    plt.ylim(-1,4)
    plt.xlabel('TRIALS')
    plt.title(f'Epoch {e}', fontsize = 4)
    i+=1
# plt.suptitle('Card picks in each epoch')
plt.tight_layout()

# %%
# data = {'DP_AVG': DP_avg,
#         'IP_AVG': IP_avg,
#         'AVG_CARD_PICKS_PER_BIN': mean_picks,
#         'ARM_CHOSEN_MONITOR': arm_chosen_monitor,
#         'REWARD_MONITOR': reward_monitor,
#         'OPTIMAL_PROBS_PER_BIN': optimal_prob_per_bin,
#         'LAST_BIN_PROBS': last_bin_prob,
#         'MEAN_PROB': mean_prob,
#         'MEAN_REWARD': mean_reward 
#         }

# # saving data as pkl file 
# with open('non_stationary_bandits_v2_PD_1.pkl', 'wb') as f:
#     pickle.dump(data, f)

# %%
dp_monitor[0].shape
# Out:
# torch.Size([100, 100, 1])

# %%
plt.figure(figsize=(4,1))
plt.subplot(1,2,1)
plt.plot(dp_monitor[0][0].squeeze().detach().numpy(), label = 'A')
plt.plot(dp_monitor[0][1].squeeze().detach().numpy(), label = 'B')
plt.plot(dp_monitor[0][2].squeeze().detach().numpy(), label = 'C')
plt.xlim(0,25)
plt.legend()
colors = np.where(np.isin(arm_chosen_monitor[e],[0,1]), 'r', 'g')
plt.subplot(1,2,2)
plt.scatter(np.arange(TRIALS), arm_chosen_monitor[e], marker = '|', s = 20)
plt.ylim(-1,4)
plt.xlim(0,25)
plt.xlabel('TRIALS')
plt.title(f'Epoch {e}', fontsize = 4)
i+=1
